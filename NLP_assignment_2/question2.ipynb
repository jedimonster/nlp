# %% [markdown]
# ## Choosing Features

# %% [raw]
# we used  the features  suggested in the assigment and few more

# %%
"""
Question 2
"""
import string
from nltk.corpus import conll2002

def word_feature(tagged_word):
    return tagged_word[0]

def pos_feature(tagged_word):
    return tagged_word[1]

def is_number(tagged_word):
    return tagged_word[0].isdigit()

def is_contains_digit(tagged_word):
    return any([x.isdigit() for x in tagged_word[0]])

def contains_hyphen(tagged_word):
    return any([x == '-' for x in tagged_word[0]])

def punctuation(tagged_word):
    return tagged_word[0] in string.punctuation


def capitalized(tagged_word):
    return tagged_word[0][0].isupper()


def all_capitals(tagged_word):
    return all([x.isupper() for x in tagged_word[0]])


def URL(tagged_word):
    return "//" in tagged_word[0]

def few_upper(tagged_word):
    res = [x for x in tagged_word[0] if x.isupper()]
    return len(res) > 1

# Additional features

ORT_methods = [is_number, is_contains_digit, contains_hyphen, punctuation, capitalized, all_capitals, URL, few_upper]
undefined_features = {"pref1", "pref2", "pref3", "suf1", "suf2", "suf3", "undefined_pos", "regular_feature",
                      "undefined_word",  'first_word', 'last_word', 'not_first_word'}

def is_regular(tagged_word):
    for method in ORT_methods:
        if method(tagged_word):
            return False
    return True

def feature_creator(data):
    """
    :param data:
    :return: vector of all features in data
    """
    all_features = undefined_features
    for method in ORT_methods:
        all_features.add(method.__name__)

    for sent in data:
        for tagged_word in sent:
            word = tagged_word[0]
            all_features.add(word)
            pos = tagged_word[1]
            all_features.add(pos)
            suf1 = tagged_word[0][-1]
            pref1 = tagged_word[0][0]
            all_features.add(suf1)
            all_features.add(pref1)
            if len(tagged_word[0]) > 1:
                suf2 = tagged_word[0][-2:len(tagged_word[0])]
                pref2 = tagged_word[0][0:2]
                all_features.add(suf2)
                all_features.add(pref2)
            if len(tagged_word[0]) > 2:
                suf3 = tagged_word[0][-3:len(tagged_word[0])]
                pref3 = tagged_word[0][0:3]
                all_features.add(suf3)
                all_features.add(pref3)

    print "Length Of Features:", len(all_features)
    numed_features = {x: index for x, index in zip(all_features, range(0, len(all_features)))}
    return numed_features

# %% [markdown]
# ## Encoding Training Data

# %%
train_data = conll2002.iob_sents('ned.train')
numed_features = feature_creator(train_data)

print '-------------------'
import operator
sorted_features = sorted(numed_features.items(), key=operator.itemgetter(1))
for x,y in sorted_features:
    print y, x
# Out:
# Length Of Features: 34417
# -------------------
# 0 scheuring
# 1 Eagle-Eye
# 2 gag
# 3 Larsen
# 4 Thuis
# 5 kwistig
# 6 éri
# 7 Zakelijk
# 8 Euro
# 9 halfvier
# 10 weerkaatsingen
# 11 vergasten
# 12 Senaat
# 13 Amerikaan
# 14 verdubbeling
# 15 begrotingen
# 16 digitaal
# 17 sigaret
# 18 4u42:05
# 19 regulier
# 20 kniesoor
# 21 zongebruinde
# 22 27-
# 23 mountainbike
# 24 270
# 25 274
# 26 49
# 27 276
# 28 opmerking
# 29 279
# 30 tehuis
# 31 zuidpunt
# 32 meedoet
# 33 rechterlijke
# 34 voorbehouden
# 35 Agfa
# 36 meedoen
# 37 liaanrozen
# 38 bestelde
# 39 Horen
# 40 Hetgeen
# 41 ingelicht
# 42 vervuiling
# 43 strookjes
# 44 Jewels
# 45 controverse
# 46 onderwerpen
# 47 toestel
# 48 Murs
# 49 rebel
# 50 antivoetbal
# 51 golden
# 52 Hooland
# 53 Kanievska
# 54 sierhaan
# 55 Lé
# 56 Lö
# 57 sterk
# 58 interkabinettenwerkgroep
# 59 halflange
# 60 sterf
# 61 e6
# 62 ontstaan
# 63 veranderlijke
# 64 constitutie
# 65 Vierdaagse
# 66 prospector
# 67 ontstaat
# 68 cynischer
# 69 Serveert
# 70 vlakken
# 71 onttrekken
# 72 oorlogsinspanningen
# 73 klankschalen
# 74 RLO
# 75 heuvellandschap
# 76 Pámpano
# 77 onderschrijft
# 78 onvrede
# 79 simpel
# 80 Lf
# 81 Lg
# 82 Ld
# 83 Le
# 84 Lb
# 85 Lc
# 86 wand
# 87 La
# 88 Lo
# 89 Ll
# 90 Iro
# 91 Lh
# 92 Li
# 93 Lt
# 94 Lu
# 95 want
# 96 Lx
# 97 Ly
# 98 LF
# 99 LD
# 100 LE
# 101 LB
# 102 LA
# 103 bewust
# 104 LO
# 105 LM
# 106 schokbestendigheid
# 107 LI
# 108 LV
# 109 LT
# 110 LU
# 111 Nussbaum
# 112 LS
# 113 LP
# 114 voorhand
# 115 Architectuur
# 116 troeven
# 117 kalenderjaar
# 118 L'
# 119 Gusta
# 120 L.
# 121 indrukken
# 122 geharmoniseerd
# 123 poëziezomer
# 124 .t.
# 125 puisten
# 126 procentpunten
# 127 Assimileren
# 128 CFD
# 129 capoeira
# 130 bobo's
# 131 CFU
# 132 vooropgesteld
# 133 Willy
# 134 hematocrietwaarde
# 135 weken
# 136 Spaanssprekend
# 137 626
# 138 fir
# 139 fis
# 140 Hir
# 141 His
# 142 Hit
# 143 fit
# 144 uoy
# 145 fic
# 146 fia
# 147 Hid
# 148 Hie
# 149 fid
# 150 fie
# 151 fij
# 152 fik
# 153 Hij
# 154 Hil
# 155 Him
# 156 fil
# 157 barrières
# 158 doctoraal
# 159 beroemde
# 160 effects
# 161 inleveren
# 162 overvalt
# 163 werkstation
# 164 schatrijk
# 165 broodschrijver
# 166 verstrooidheid
# 167 zuil
# 168 Enviro-Chem
# 169 zuid
# 170 39-
# 171 Middeleeuwen
# 172 bankrekeningen
# 173 zat
# 174 metselwerk
# 175 pensioenpijler
# 176 sleutels
# 177 gespeeld
# 178 tolwegen
# 179 weerde
# 180 huishoudelektronica
# 181 Safin
# 182 correcte
# 183 Bedreigt
# 184 Egi
# 185 Ego
# 186 lifestylebeurs
# 187 syr
# 188 afgebeld
# 189 achtste
# 190 19.15
# 191 jaarmarkt
# 192 Kristof
# 193 verstoren
# 194 VLD-gemeenteraadslid
# 195 Activity
# 196 getreuzel
# 197 bokser
# 198 flesschen
# 199 duidelijk
# 200 betwist
# 201 biefstukken
# 202 subsidiëring
# 203 nz.
# 204 Berlage
# 205 academieleerlingen
# 206 27.
# 207 gekleed
# 208 Daddy
# 209 Kerkhofstraat
# 210 efficiëntie
# 211 belangenvermenging
# 212 hysterisch
# 213 ontvingen
# 214 kevers
# 215 eerbiedig
# 216 nza
# 217 Terzake
# 218 nze
# 219 nzi
# 220 nzo
# 221 275
# 222 Chicago
# 223 Nummer
# 224 culinaire
# 225 Tobin-heffing
# 226 allerijl
# 227 dozen
# 228 Theo
# 229 knallen
# 230 ongelooflijker
# 231 Almanij
# 232 that
# 233 Coelingh
# 234 Thea
# 235 12de
# 236 z.t.
# 237 affaire
# 238 Oostende
# 239 daarna
# 240 commerciële
# 241 Pandora
# 242 Broer
# 243 Mahler
# 244 documentatie
# 245 platteland
# 246 15.800
# 247 getuigenis
# 248 Oud-bondskanselier
# 249 The1
# 250 thuiskomen
# 251 kortere
# 252 minimale
# 253 smu
# 254 Markt
# 255 tekenden
# 256 Wiltord
# 257 novicen
# 258 videoprojecties
# 259 thuisfront
# 260 groepje
# 261 baby's
# 262 iré
# 263 bliss
# 264 Octave
# 265 geschokt
# 266 Hamilton
# 267 onterecht
# 268 boeman
# 269 bankdirecteur
# 270 koetswerkniveau
# 271 joelt
# 272 Riv
# 273 leren
# 274 Rit
# 275 afraden
# 276 Riq
# 277 Rin
# 278 Rio
# 279 Rim
# 280 supermarktomvang
# 281 Rik
# 282 Rii
# 283 Senegalese
# 284 Rig
# 285 Rid
# 286 kapitaal
# 287 Rib
# 288 Ric
# 289 luchtspiegelingen
# 290 programmatie
# 291 eenmalig
# 292 Gewoon
# 293 vermanend
# 294 Roussillon
# 295 Anderson
# 296 Heren
# 297 .it
# 298 dertigtal
# 299 iry
# 300 terreinrijder
# 301 BPT-uren
# 302 irr
# 303 irs
# 304 irt
# 305 irk
# 306 adelbrieven
# 307 iro
# 308 ira
# 309 ird
# 310 ire
# 311 .i.
# 312 ZET
# 313 geëvalueerd
# 314 realbiljetten
# 315 .86
# 316 controlelijn
# 317 Simonet
# 318 Howard's
# 319 Grischa
# 320 rgt
# 321 qui-vive
# 322 verliefdheid
# 323 ploegenklassement
# 324 diarree
# 325 ondersteunt
# 326 landgoed
# 327 Estivales
# 328 Leman
# 329 weddetrekkenden
# 330 Laura
# 331 sleuf
# 332 veeg
# 333 veel
# 334 stuurfout
# 335 tornooien
# 336 deblokkeren
# 337 scènes
# 338 Nazon
# 339 actualiteit
# 340 Leugens
# 341 blonde
# 342 fra
# 343 fre
# 344 fri
# 345 gewoon
# 346 fro
# 347 restauratieplan
# 348 kasten
# 349 .
# 350 koepelstructuur
# 351 dertigster
# 352 fru
# 353 parochie
# 354 bemoeit
# 355 fry
# 356 doseren
# 357 Qat
# 358 modestudenten
# 359 kinderwagens
# 360 Lav
# 361 Donovan
# 362 vanavond
# 363 spil
# 364 TDI
# 365 technieken
# 366 fr.
# 367 gemanaged
# 368 onderhoudende
# 369 Scottie
# 370 smeerpijp
# 371 vergen
# 372 hoogstaand
# 373 13.15
# 374 13.10
# 375 Elders
# 376 strengere
# 377 provinciale
# 378 zondagavond
# 379 Hopelijk
# 380 plaats
# 381 gewestminister
# 382 Sercu
# 383 hartje
# 384 uitgeschreven
# 385 Pho
# 386 voorbereidingsfase
# 387 cineasten
# 388 afgeleverd
# 389 festijn
# 390 Lorono
# 391 gevoelens
# 392 zitje
# 393 corporate
# 394 terechtgesteld
# 395 toewijding
# 396 genoteerd
# 397 hai
# 398 Volgend
# 399 hak
# 400 hal
# 401 Ewing
# 402 han
# 403 eedaflegging
# 404 haa
# 405 hab
# 406 hac
# 407 had
# 408 hag
# 409 hay
# 410 vliegtuigje
# 411 Volgens
# 412 hap
# 413 losmakende
# 414 har
# 415 beloven
# 416 Preventie
# 417 hav
# 418 aangewend
# 419 Coppens
# 420 inging
# 421 elders
# 422 recensies
# 423 opduikt
# 424 novellen
# 425 Canadese
# 426 VT4-baas
# 427 Steven
# 428 weerhoudt
# 429 calorierijker
# 430 wereldmuziekfestivals
# 431 Swedish
# 432 Latere
# 433 Veiligheidsplan
# 434 ingeschakeld
# 435 ïne
# 436 tandje
# 437 vuile
# 438 Snick
# 439 medeweten
# 440 daaropvolgende
# 441 uitvoering
# 442 bezwaard
# 443 aanloop
# 444 afwaarderen
# 445 Gst
# 446 Gerrit
# 447 binden
# 448 Goossen
# 449 Calle
# 450 Gsc
# 451 herrie
# 452 heffingen
# 453 veelvuldig
# 454 gerekruteerd
# 455 migrantensector
# 456 hoogteniveaus
# 457 Ure
# 458 Populair
# 459 adem
# 460 stoken
# 461 eindeloos
# 462 zakken
# 463 mbo
# 464 staakt
# 465 veroordeeld
# 466 zélf
# 467 mba
# 468 Mannschaft
# 469 mbt
# 470 Indiër
# 471 bedraagt
# 472 rapen
# 473 Balmanion
# 474 worstelen
# 475 Versace
# 476 vriendinnen
# 477 Voltchkov
# 478 Yanomami-indianen
# 479 minimumaantal
# 480 Lapentti
# 481 onderbelicht
# 482 stadsarcheologie
# 483 initiatiefnemers
# 484 reu
# 485 gebannen
# 486 azi
# 487 duel
# 488 kantoorruimte
# 489 Deffense
# 490 aza
# 491 aze
# 492 stiekem
# 493 azy
# 494 azz
# 495 azu
# 496 discriminatie
# 497 moderne
# 498 weggetje
# 499 Mukamba
# 500 zondagochtend
# 501 voorstelt
# 502 paketten
# 503 tanen
# 504 sandalen
# 505 verbondenheid
# 506 E
# 507 Idr
# 508 mobilofoonbedrijf
# 509 intens
# 510 intent
# 511 Idi
# 512 Ide
# 513 gedroeg
# 514 beslagen
# 515 vettig
# 516 honderden
# 517 Agd
# 518 .B.
# 519 stijvere
# 520 toegevoegd
# 521 pover
# 522 osy
# 523 herdoopt
# 524 l'ombra
# 525 zuidelijke
# 526 leefomstandigheden
# 527 corps
# 528 volle
# 529 republikeinse
# 530 oss
# 531 Byr
# 532 ost
# 533 osh
# 534 osk
# 535 oso
# 536 osn
# 537 osa
# 538 osc
# 539 uitstapregelingen
# 540 ose
# 541 ongeduld
# 542 macht
# 543 Ta6
# 544 Ta1
# 545 freelance
# 546 Ta8
# 547 Frentzen
# 548 wetswijziging
# 549 CCOD
# 550 kankerverenigingen
# 551 deugt
# 552 Wüst
# 553 macho
# 554 vertwijfeld
# 555 Má
# 556 Confituur
# 557 Mí
# 558 Mé
# 559 aflevering
# 560 Mü
# 561 exact
# 562 minute
# 563 Dianda
# 564 Tat
# 565 Tau
# 566 Tav
# 567 opgericht
# 568 agenten
# 569 Tar
# 570 Tas
# 571 Warren
# 572 Tax
# 573 1.498
# 574 Tad
# 575 Taf
# 576 Tag
# 577 schoppen
# 578 Tan
# 579 Taj
# 580 Copernicus
# 581 hartelijke
# 582 26.004
# 583 meedelen
# 584 ogenblik
# 585 SF-film
# 586 osé
# 587 buur
# 588 Turnhout
# 589 Départ
# 590 natuurdocumentaire
# 591 daadwerkelijk
# 592 terroristische
# 593 Banksector
# 594 Magne
# 595 matras
# 596 geschiktste
# 597 vijftig
# 598 Me
# 599 Mg
# 600 oep
# 601 Ma
# 602 Mc
# 603 Mb
# 604 Pagina's
# 605 aftrekbaarheid
# 606 Mo
# 607 Mi
# 608 beslaat
# 609 Mu
# 610 Mp
# 611 Mr
# 612 My
# 613 gemakzucht
# 614 Webb
# 615 brandstofverbruik
# 616 MG
# 617 MF
# 618 MA
# 619 MC
# 620 MO
# 621 MI
# 622 oei
# 623 MU
# 624 MW
# 625 MV
# 626 MP
# 627 MS
# 628 MR
# 629 constructief
# 630 MX
# 631 aanwezigen
# 632 aërodynamische
# 633 Daidalos
# 634 oem
# 635 Bedrijfspensioenplannen
# 636 oel
# 637 vleesproducten
# 638 13,4
# 639 13,5
# 640 oud-kanselier
# 641 Davidson
# 642 wang
# 643 lichting
# 644 Baskenland
# 645 Wauwer
# 646 oef
# 647 boeren
# 648 religies
# 649 Iris
# 650 verraderlijke
# 651 21.000
# 652 bedrijfswagen
# 653 speedsnuivers
# 654 Borsbeekse
# 655 beoefent
# 656 pauselijk
# 657 rechtwege
# 658 www.ddc.dk
# 659 onnodig
# 660 behouden
# 661 predikaat
# 662 oprecht
# 663 douane
# 664 Humo
# 665 life-situatie
# 666 doorgelopen
# 667 jaarlijkse
# 668 dosis
# 669 Goossens
# 670 gebruik
# 671 galerij
# 672 Zaal
# 673 steken
# 674 symboliseren
# 675 steker
# 676 Leuvense
# 677 absolute
# 678 herbergt
# 679 STE
# 680 stapel
# 681 STA
# 682 opgevoed
# 683 Corporate
# 684 gebeurde
# 685 spannend
# 686 ingesnoeid
# 687 spaarde
# 688 rijkswacht
# 689 architectuur
# 690 bedraag
# 691 vijfentwintigjarige
# 692 Hoezeer
# 693 verificaties
# 694 fraai
# 695 Dürer
# 696 Sint-Michiels-parochie
# 697 beklimmen
# 698 LIB
# 699 years
# 700 LIT
# 701 geliefde
# 702 beletten
# 703 gebedsgenezers
# 704 wegmoffelen
# 705 Dockx
# 706 bescheiden
# 707 jin
# 708 jij
# 709 jit
# 710 vernieuwingsimpuls
# 711 Ville
# 712 Deutsche
# 713 schilder
# 714 4d
# 715 schilden
# 716 Sigaren
# 717 bedekt
# 718 virtueel
# 719 thalis
# 720 omtoverden
# 721 pleinen
# 722 onbevangen
# 723 Schandalen
# 724 Wegbelasten
# 725 01.40
# 726 Live
# 727 sponsor
# 728 keizer
# 729 wegen
# 730 Ongrijpbare
# 731 favoriete
# 732 790
# 733 nonnetjes
# 734 zendt
# 735 internet
# 736 vervat
# 737 Pfd7
# 738 uptempo
# 739 geërfd
# 740 homo-milieu
# 741 tiener
# 742 Tijdens
# 743 organisatoren
# 744 Venter
# 745 HEAT
# 746 Karagiannis
# 747 speculatie
# 748 relaxerende
# 749 klinken
# 750 Owens
# 751 vakanties
# 752 onk
# 753 onh
# 754 oni
# 755 onn
# 756 ono
# 757 onl
# 758 onm
# 759 onb
# 760 onc
# 761 ona
# 762 onf
# 763 ong
# 764 veertien
# 765 one
# 766 onz
# 767 speelgoedzaak
# 768 ony
# 769 opgeschreven
# 770 onr
# 771 ons
# 772 onp
# 773 onv
# 774 onw
# 775 ont
# 776 onu
# 777 zoë
# 778 migrantenwijken
# 779 zoö
# 780 interventie
# 781 zwakte
# 782 financierde
# 783 alledrie
# 784 on-
# 785 Peeters
# 786 besmetting
# 787 bewegingen
# 788 dierengeneticus
# 789 missiewerk
# 790 doorgevoerd
# 791 jongere
# 792 rza
# 793 Vanek
# 794 Dewinter
# 795 dwarszit
# 796 opmeten
# 797 wereldrecord
# 798 etnisch
# 799 zoa
# 800 Hals
# 801 zoc
# 802 zod
# 803 zoe
# 804 zog
# 805 zoi
# 806 zoj
# 807 zol
# 808 zom
# 809 zon
# 810 zoo
# 811 zop
# 812 zor
# 813 zou
# 814 afgelopen
# 815 zow
# 816 kledingstuk
# 817 zoz
# 818 Hall
# 819 printer
# 820 luchtiger
# 821 rock-'n-roll
# 822 maand
# 823 liepen
# 824 deftigs
# 825 Chet
# 826 Batselier
# 827 zo'
# 828 totstandgekomen
# 829 prikkels
# 830 prikkelt
# 831 projectiemethode
# 832 alepidotus
# 833 spionnen
# 834 Substitute
# 835 toplui
# 836 Barragáns
# 837 Sky
# 838 elan
# 839 Ska
# 840 verregaand
# 841 Ali's
# 842 regeerakkoord
# 843 mond-
# 844 Ski
# 845 verklaring
# 846 bondscoach
# 847 VRT-stations
# 848 Schumachers
# 849 Leadership
# 850 presse
# 851 nieuwkomers
# 852 mondt
# 853 vredige
# 854 etcetera
# 855 singer-songwriter
# 856 platte
# 857 VVKSO
# 858 supportersgeweld
# 859 Botervissen
# 860 êve
# 861 senatoren
# 862 Scieur
# 863 Santana
# 864 geraakten
# 865 Eames
# 866 Ethiopië
# 867 830
# 868 Frères
# 869 834
# 870 Enqvist
# 871 levende
# 872 riijdersduo
# 873 kilometer
# 874 Jonas
# 875 klimroos
# 876 83.
# 877 Awa
# 878 Hip
# 879 liter-motor
# 880 verlicht
# 881 verholpen
# 882 voedt
# 883 geknokt
# 884 toetredingsakte
# 885 Iljoesjin
# 886 4:25
# 887 s
# 888 frequenties
# 889 521.49.28
# 890 Duboc
# 891 aalmoes
# 892 Vuur
# 893 wetenschappers
# 894 Ocana
# 895 sacrosancte
# 896 afbouw
# 897 Horton
# 898 Verdrietig
# 899 schaalvoordeel
# 900 corrigeren
# 901 Kapellen
# 902 gelezen
# 903 etalagepoppen
# 904 farmacieconcern
# 905 onderzoekscommissie
# 906 fig
# 907 investeerders
# 908 Drouhin
# 909 willoze
# 910 impliceert
# 911 checkte
# 912 inschrijvende
# 913 dagschotel
# 914 ïl
# 915 motorfiets
# 916 zonnescherm
# 917 fin
# 918 metropool
# 919 Doordat
# 920 Hin
# 921 vogeltje
# 922 Siza
# 923 Loisy
# 924 boerderijtje
# 925 bondgenoot
# 926 vrolijker
# 927 4de
# 928 Winnend
# 929 Merkwaardig
# 930 Prez
# 931 voorbijgangers
# 932 Docent
# 933 technology
# 934 medewerker
# 935 psychedelisch
# 936 luxebus
# 937 Blijft
# 938 gedempt
# 939 466
# 940 Kübler
# 941 Neanderthal-tijd
# 942 Mas
# 943 Sabonis
# 944 Timmermans
# 945 rotzorg
# 946 kwijtgeraakt
# 947 IRA
# 948 Maouirine
# 949 jeugdrechter
# 950 ooit
# 951 Mat
# 952 Kaspische
# 953 Max
# 954 Mongools
# 955 Port
# 956 dorpsgenoten
# 957 berichten
# 958 telecomgebruikers
# 959 Ontex
# 960 acceleratie
# 961 fysicus
# 962 BOB
# 963 hoofdprijs
# 964 Tractebel-aandeelhouder
# 965 Voordeel
# 966 34-jarige
# 967 vriezen
# 968 ineens
# 969 Guesdon
# 970 pluisjes
# 971 Mad
# 972 categorie
# 973 ademt
# 974 Degroof
# 975 vinken
# 976 Gijzelnemer
# 977 Mai
# 978 Lammens
# 979 geruimd
# 980 geruime
# 981 Vitalicioploeg
# 982 world
# 983 installeren
# 984 Mam
# 985 Fritz
# 986 catamarans
# 987 Achievement
# 988 halfnegen
# 989 afdreigen
# 990 stadshaan
# 991 zakenvrouw
# 992 illusie
# 993 Montalvo
# 994 geleerde
# 995 ezi
# 996 Kristian
# 997 eze
# 998 adresjes
# 999 apekool
# 1000 toteen
# 1001 ongekende
# 1002 Soulor
# 1003 bedenkt
# 1004 Overal
# 1005 meisje
# 1006 919
# 1007 voorbereidde
# 1008 914
# 1009 druppel
# 1010 911
# 1011 910
# 1012 913
# 1013 912
# 1014 klokte
# 1015 Jeanine
# 1016 tv-
# 1017 tv.
# 1018 graaf
# 1019 graag
# 1020 graad
# 1021 graan
# 1022 bokspromotor
# 1023 4-w
# 1024 persbericht
# 1025 frigobox
# 1026 zangeres
# 1027 verkeerschaos
# 1028 Paine
# 1029 Ni
# 1030 bje
# 1031 jeugdbewegingen
# 1032 ronden
# 1033 Nm
# 1034 No
# 1035 Na
# 1036 Ne
# 1037 Ng
# 1038 kwijt
# 1039 Ny
# 1040 EK-finalist
# 1041 Nu
# 1042 NI
# 1043 NL
# 1044 NM
# 1045 NN
# 1046 NO
# 1047 ginds
# 1048 NA
# 1049 NB
# 1050 missers
# 1051 ND
# 1052 NE
# 1053 NG
# 1054 NR
# 1055 NS
# 1056 NT
# 1057 pompelmoes
# 1058 Kunzang
# 1059 kwalificatiewedstrijden
# 1060 Watersportbaan
# 1061 N'
# 1062 afgewaardeerd
# 1063 N3
# 1064 with
# 1065 Proactive
# 1066 Rodrigues
# 1067 Rodriguez
# 1068 partijfinanciering
# 1069 edellieden
# 1070 Taxi-stop
# 1071 zelfverzekerde
# 1072 Garzelli
# 1073 pulp
# 1074 rust
# 1075 worsten
# 1076 waterglaasjes
# 1077 Ní
# 1078 Redant
# 1079 humoristische
# 1080 waterzuiveringswereld
# 1081 kweeperen
# 1082 Nü
# 1083 inspanningen
# 1084 jargon
# 1085 Real
# 1086 stilaan
# 1087 yoga
# 1088 Verbrugghe
# 1089 partijen
# 1090 geschriften
# 1091 werknemersparticipatie
# 1092 1441
# 1093 sowieso
# 1094 kruidige
# 1095 uitgegaan
# 1096 bestaande
# 1097 Henk
# 1098 onderhand
# 1099 Censydiam
# 1100 kilogram
# 1101 Hoess
# 1102 Scherpschutter
# 1103 muziektheater
# 1104 opdat
# 1105 afschaffing
# 1106 maidenspeech
# 1107 Fir
# 1108 Fis
# 1109 sco
# 1110 sch
# 1111 mislukkingen
# 1112 sce
# 1113 verstelbare
# 1114 sca
# 1115 Fia
# 1116 verraad
# 1117 Fig
# 1118 Fid
# 1119 Fie
# 1120 Fij
# 1121 Fin
# 1122 Fio
# 1123 Fil
# 1124 scr
# 1125 scE
# 1126 dichterbij
# 1127 norm
# 1128 houtkapbedrijf
# 1129 kernwapens
# 1130 spectaculaire
# 1131 uniformiteit
# 1132 1-magazine
# 1133 examens
# 1134 acteursopleidingen
# 1135 bracht
# 1136 hierboven
# 1137 opgestuurd
# 1138 gezond
# 1139 199
# 1140 198
# 1141 19:
# 1142 195
# 1143 recepties
# 1144 197
# 1145 196
# 1146 191
# 1147 190
# 1148 193
# 1149 192
# 1150 19-
# 1151 19,
# 1152 Rogier
# 1153 19.
# 1154 ideeëngoed
# 1155 Reyes
# 1156 gedemocratiseerd
# 1157 Puydt
# 1158 delen
# 1159 voorspelbaarder
# 1160 productieve
# 1161 leid
# 1162 mobiele
# 1163 Baresi
# 1164 methodes
# 1165 Charlie
# 1166 tickets
# 1167 19d
# 1168 november
# 1169 tedere
# 1170 melancholie
# 1171 Justine
# 1172 Hutu-extremisten
# 1173 leven.
# 1174 Filip
# 1175 trapte
# 1176 ERHAALTJES
# 1177 spreidingsplan
# 1178 merkwaardiger
# 1179 wisseltransacties
# 1180 mori
# 1181 genotsgevoel
# 1182 blijven
# 1183 patio's
# 1184 Provence
# 1185 treinen
# 1186 levend
# 1187 door
# 1188 doos
# 1189 doop
# 1190 tester
# 1191 chemische
# 1192 dood
# 1193 Voc
# 1194 levens
# 1195 testen
# 1196 dook
# 1197 inzicht
# 1198 Sporen
# 1199 Capriati
# 1200 klasbak
# 1201 ëne
# 1202 sociale
# 1203 gxf5
# 1204 militair
# 1205 madammen
# 1206 nieuwste
# 1207 ënt
# 1208 pinotage
# 1209 bekent
# 1210 geantwoord
# 1211 confidentiële
# 1212 bekend
# 1213 Glasgow
# 1214 Kf6
# 1215 Kf7
# 1216 spiedt
# 1217 publicaties
# 1218 fysionomie
# 1219 Kf8
# 1220 appèl
# 1221 Fusion
# 1222 bajonet
# 1223 kadavermeel
# 1224 twaalfde
# 1225 trendsetter
# 1226 capituleren
# 1227 Halve
# 1228 multimediacomputers
# 1229 voorstelde
# 1230 variant
# 1231 woordenboek
# 1232 moedigt
# 1233 lichaam
# 1234 Emir
# 1235 tuin-
# 1236 versloeg
# 1237 weigeringen
# 1238 Kash
# 1239 l'A
# 1240 weeshuis
# 1241 communistische
# 1242 signo
# 1243 repliek
# 1244 jeugdige
# 1245 volwassenheid
# 1246 roots
# 1247 1-3-uitslag
# 1248 exportorgaan
# 1249 109,8
# 1250 Archeologische
# 1251 aanvaard
# 1252 Brussels
# 1253 schouders
# 1254 Banken
# 1255 focussen
# 1256 hoedje
# 1257 heroveren
# 1258 wereldvreemde
# 1259 reactie
# 1260 Evenzovele
# 1261 Authority
# 1262 sigaren
# 1263 Bild
# 1264 verstrengd
# 1265 dialoog
# 1266 Bergman
# 1267 ingeklemd
# 1268 16.352.050
# 1269 Schewebach
# 1270 uitermate
# 1271 spiritualiteit
# 1272 sektarisme
# 1273 Zuid-Koreanen
# 1274 Enkele
# 1275 zaaltjes
# 1276 35.777
# 1277 helikopter
# 1278 Integendeel
# 1279 kanaries
# 1280 Ardooie
# 1281 theatergebied
# 1282 Wolventocht
# 1283 Uefacup-winnaar
# 1284 Feira
# 1285 doelgroep
# 1286 ingenieurs
# 1287 Moeras
# 1288 Fra
# 1289 omvangrijker
# 1290 Fre
# 1291 vlekkeloze
# 1292 nodigden
# 1293 Fri
# 1294 Fro
# 1295 principes
# 1296 gedetineerden
# 1297 ADSL
# 1298 26-
# 1299 Hemmingway
# 1300 slanke
# 1301 noemen
# 1302 Pbd2
# 1303 voetbalbond
# 1304 Pbd7
# 1305 1.595
# 1306 boerenbond
# 1307 interviewer
# 1308 boomblaren
# 1309 Hoge
# 1310 Genome-project
# 1311 oranjekleurige
# 1312 dominantie
# 1313 Rozen
# 1314 zachtmoedig
# 1315 Waakzaamheid
# 1316 Loopbaan
# 1317 Vanfleteren
# 1318 veroverd
# 1319 krek
# 1320 Rushtob
# 1321 uitgebreide
# 1322 kraam
# 1323 tijdgeest
# 1324 Addis
# 1325 kraag
# 1326 klasgenootje
# 1327 langere-termijnprojecten
# 1328 gedegouteerd
# 1329 singles
# 1330 omzetten
# 1331 bevreemdend
# 1332 wandelpromenade
# 1333 beslissen
# 1334 populariteit
# 1335 beledigt
# 1336 flits
# 1337 opofferingen
# 1338 Defrancq
# 1339 plotse
# 1340 Agadir
# 1341 beledigd
# 1342 OTS
# 1343 Hah
# 1344 spelers
# 1345 Hak
# 1346 Hal
# 1347 Ham
# 1348 Han
# 1349 landweg
# 1350 Hab
# 1351 Had
# 1352 Hae
# 1353 Hag
# 1354 stuntelig
# 1355 ugs
# 1356 Har
# 1357 Has
# 1358 Hat
# 1359 Hau
# 1360 Hav
# 1361 Haw
# 1362 Cevallos
# 1363 flitsende
# 1364 hekelt
# 1365 onvriendelijke
# 1366 luchtvaart
# 1367 duidelijkheid
# 1368 Stedelijk
# 1369 ál
# 1370 lieten
# 1371 leverde
# 1372 hoeken
# 1373 Cactussen
# 1374 overlijdt
# 1375 marktpresteerder
# 1376 tanken
# 1377 Orb
# 1378 bytes
# 1379 lanceerplatform
# 1380 vierkant
# 1381 Brittens
# 1382 depressie
# 1383 boze
# 1384 tekeningen
# 1385 Haï
# 1386 312
# 1387 Ieperse
# 1388 EU-commissaris
# 1389 tegenover
# 1390 Tractebel
# 1391 Fiore
# 1392 Decoo
# 1393 spieren
# 1394 Peggy
# 1395 overheidsbemoeienis
# 1396 dorre
# 1397 schorpioenen
# 1398 Hostile
# 1399 31s
# 1400 raffinaderij
# 1401 31u
# 1402 Kisangani
# 1403 445
# 1404 regering-Verhofstadt
# 1405 waardering
# 1406 heldendaad
# 1407 tafeltje
# 1408 kunstencentrum
# 1409 integendeel
# 1410 last
# 1411 aanhoudt
# 1412 Wilde
# 1413 Zijzelf
# 1414 Boudewijn
# 1415 paaskuiken
# 1416 nr.
# 1417 strookje
# 1418 wedstrijd
# 1419 belt
# 1420 b0b
# 1421 geloofwaardig
# 1422 opgelet
# 1423 correcties
# 1424 satire
# 1425 plaatsje
# 1426 marginale
# 1427 scherp
# 1428 extravagant
# 1429 indiaanse
# 1430 Carl
# 1431 veeleer
# 1432 bedachten
# 1433 Stoute
# 1434 Card
# 1435 nri
# 1436 Vandaag
# 1437 ingespoten
# 1438 schouw
# 1439 Aparte
# 1440 nre
# 1441 ïst
# 1442 Vandaar
# 1443 nry
# 1444 drugsverslaafde
# 1445 Hiroshima
# 1446 Michel
# 1447 invalshoeken
# 1448 soeplepels
# 1449 budget
# 1450 Nesta
# 1451 Maystadt
# 1452 33
# 1453 runnen
# 1454 vod
# 1455 voe
# 1456 vog
# 1457 afwaardering
# 1458 vol
# 1459 von
# 1460 voo
# 1461 binding
# 1462 loopband
# 1463 vou
# 1464 omvergeworpen
# 1465 hooggeschoolden
# 1466 vor
# 1467 vos
# 1468 integratie
# 1469 gecodeerde
# 1470 illusoire
# 1471 beloftes
# 1472 Centuries
# 1473 roeping
# 1474 referenties
# 1475 mystère
# 1476 uitwijzingsprocedures
# 1477 noteert
# 1478 2748
# 1479 gelijk
# 1480 uitspreekt
# 1481 Ass
# 1482 tis
# 1483 kostuum
# 1484 diegene
# 1485 Raphael
# 1486 motor-
# 1487 kring
# 1488 giorno
# 1489 Quaden
# 1490 streefdatum
# 1491 kno
# 1492 Mbo
# 1493 gebleven
# 1494 kni
# 1495 Percussionist
# 1496 kne
# 1497 kna
# 1498 diversiteit
# 1499 knu
# 1500 ouwe
# 1501 Karl
# 1502 O.
# 1503 O-
# 1504 salvo
# 1505 O'
# 1506 joden
# 1507 tomatensaus
# 1508 leefden
# 1509 Zaventem-akkoord
# 1510 baseerden
# 1511 geschoven
# 1512 Brandi
# 1513 christendom
# 1514 Chéri
# 1515 2.953,28
# 1516 Brande
# 1517 Marino
# 1518 doelgerichte
# 1519 Pascual
# 1520 Brandt
# 1521 Oo
# 1522 On
# 1523 Om
# 1524 Ol
# 1525 Ok
# 1526 Oi
# 1527 Og
# 1528 Of
# 1529 Oe
# 1530 Od
# 1531 Oc
# 1532 Ob
# 1533 liberaal
# 1534 heilige
# 1535 afronden
# 1536 Oz
# 1537 werkloosheid
# 1538 Ox
# 1539 Ow
# 1540 Ov
# 1541 Louvain-la-Neuve
# 1542 Ot
# 1543 Os
# 1544 Or
# 1545 Op
# 1546 OO
# 1547 ON
# 1548 OM
# 1549 OL
# 1550 OK
# 1551 OG
# 1552 OF
# 1553 penetreert
# 1554 OD
# 1555 OC
# 1556 OB
# 1557 toegestane
# 1558 OW
# 1559 OT
# 1560 technologie
# 1561 OR
# 1562 OP
# 1563 ijp
# 1564 Jones
# 1565 ijs
# 1566 ijt
# 1567 ijv
# 1568 ijz
# 1569 methode
# 1570 Dendermondse
# 1571 ije
# 1572 ijf
# 1573 zonnig
# 1574 iji
# 1575 Zweedse
# 1576 geplukt
# 1577 ijl
# 1578 ijm
# 1579 ijn
# 1580 Peninou
# 1581 Frank
# 1582 1,71
# 1583 Witter
# 1584 Frans
# 1585 Siècle
# 1586 laden
# 1587 Franz
# 1588 Aviation
# 1589 ideologie
# 1590 gedrenkt
# 1591 klimmers
# 1592 besten
# 1593 Osa
# 1594 Osc
# 1595 verenigingen
# 1596 achterstand
# 1597 wéé
# 1598 deelnam
# 1599 heeft
# 1600 zwaar
# 1601 70-jarige
# 1602 .a.
# 1603 ontving
# 1604 °1945
# 1605 zwaan
# 1606 opent
# 1607 Rer
# 1608 opwinding
# 1609 spat
# 1610 opmerken
# 1611 fragmenten
# 1612 coachte
# 1613 ministerie
# 1614 eventueel
# 1615 witte-koolbladeren
# 1616 tradities
# 1617 charmes
# 1618 Hermanus
# 1619 bordpapier
# 1620 Fuchsiavrienden
# 1621 57.000
# 1622 wél
# 1623 diverse
# 1624 Kunsten
# 1625 Algerijn
# 1626 trossen
# 1627 ledertoets
# 1628 attracties
# 1629 wapens
# 1630 rennende
# 1631 afkoelen
# 1632 bediscussieerd
# 1633 aangetreden
# 1634 hotelschool
# 1635 strafschopstip
# 1636 materiële
# 1637 verhuisde
# 1638 doorgang
# 1639 wenst
# 1640 tendinitis
# 1641 lang
# 1642 land
# 1643 train
# 1644 verder
# 1645 pedagogie
# 1646 opstarten
# 1647 veroverde
# 1648 braaf
# 1649 Jid
# 1650 veiligheidscriteria
# 1651 Daarover
# 1652 Jin
# 1653 overdonderd
# 1654 braam
# 1655 Jim
# 1656 Jij
# 1657 grootmacht
# 1658 vakbondskringen
# 1659 detectives
# 1660 trainersstaf
# 1661 schakel
# 1662 praktijkgericht
# 1663 niets
# 1664 15:24
# 1665 raffinaderijen
# 1666 verleiden
# 1667 meemaken
# 1668 afwezigen
# 1669 Kampenhout
# 1670 Directeur-generaal
# 1671 staatsgreep
# 1672 familiesoap
# 1673 selecteert
# 1674 vliegtuig
# 1675 595
# 1676 video
# 1677 wereldvreemd
# 1678 gewillig
# 1679 multimedia
# 1680 onrustiger
# 1681 bronnen
# 1682 Dupont
# 1683 ,32
# 1684 ,33
# 1685 ,30
# 1686 vertrouwensmagistraat
# 1687 Ouyahia
# 1688 poëzie
# 1689 maken
# 1690 gastenbestand
# 1691 gezellig
# 1692 huwelijk
# 1693 verlichte
# 1694 grijsaards
# 1695 Krommestraat
# 1696 binnenkomt
# 1697 ploeg
# 1698 ploef
# 1699 Greenwich
# 1700 inwijding
# 1701 leeftijdsgenoten
# 1702 Tito
# 1703 nefast
# 1704 Ampoorter
# 1705 geschat
# 1706 ongeloof
# 1707 doorstaan
# 1708 bespaard
# 1709 next
# 1710 Arboretum
# 1711 cynisch
# 1712 georganiseerd
# 1713 werknemers
# 1714 pfc
# 1715 pff
# 1716 Rzo
# 1717 buitenlander
# 1718 pfl
# 1719 Borsbeek
# 1720 baby
# 1721 Gemeenschap
# 1722 Belgo-Katanga
# 1723 hieraan
# 1724 omgaat
# 1725 ruilen
# 1726 rode
# 1727 d'Aubisque
# 1728 verwachtte
# 1729 watergroen
# 1730 uitgeblazen
# 1731 omgaan
# 1732 Agricole
# 1733 ontploft
# 1734 Rosie
# 1735 hormonen
# 1736 vuil
# 1737 klachten
# 1738 palet
# 1739 comedy
# 1740 intelligent
# 1741 hoger
# 1742 Sych
# 1743 opmars
# 1744 kielzog
# 1745 gefocust
# 1746 textielen
# 1747 xc5
# 1748 Gospel
# 1749 toekomstige
# 1750 achttiende-eeuwse
# 1751 pastelle
# 1752 Onl
# 1753 Onm
# 1754 Onb
# 1755 Onc
# 1756 Ona
# 1757 Ong
# 1758 Ond
# 1759 One
# 1760 Onz
# 1761 leerling
# 1762 Ons
# 1763 Onv
# 1764 Onw
# 1765 Ont
# 1766 wereldfaam
# 1767 directe
# 1768 populair
# 1769 Rubiera
# 1770 gemeenplaats
# 1771 2.300
# 1772 perfect
# 1773 live-versie
# 1774 pitsstop
# 1775 stallen
# 1776 familieleden
# 1777 Ralchev
# 1778 goedgehumeurd
# 1779 morgen
# 1780 staat
# 1781 overal
# 1782 staal
# 1783 staan
# 1784 Gewicht
# 1785 1:58
# 1786 1:54
# 1787 Stort
# 1788 Raoux
# 1789 1:51
# 1790 eiste
# 1791 Emmanuel
# 1792 klimmen
# 1793 klimmer
# 1794 rashond
# 1795 Bleef
# 1796 protestparcours
# 1797 verraadt
# 1798 Staelens
# 1799 spirituele
# 1800 stadsmuren
# 1801 Grégory
# 1802 presteren
# 1803 Engeström
# 1804 uitbreken
# 1805 '
# 1806 overtocht
# 1807 boerderijen
# 1808 0-0-0
# 1809 telecommarkt
# 1810 danig
# 1811 aansleept
# 1812 theatermilieu
# 1813 Rij
# 1814 bekennen
# 1815 Vergouwen
# 1816 ych
# 1817 Henman
# 1818 precies
# 1819 CVP-dossier
# 1820 Kapitaal
# 1821 Rie
# 1822 verbaasde
# 1823 spiegelen
# 1824 Jesus
# 1825 fundamenten
# 1826 grensregio
# 1827 geplisseerd
# 1828 tentoonstellingsruimte
# 1829 priemen
# 1830 premie
# 1831 scene
# 1832 verzamelen
# 1833 verkeersminister
# 1834 Jú
# 1835 hoofdtakken
# 1836 23.25
# 1837 festival
# 1838 muilen
# 1839 sergeant
# 1840 Aromatisch
# 1841 muizenissen
# 1842 Roosevelt
# 1843 wrang
# 1844 Stanga
# 1845 Hastings
# 1846 temmen
# 1847 Himst
# 1848 futuristische
# 1849 mini-eilandjes
# 1850 winst
# 1851 Neneh
# 1852 stadscentrum
# 1853 Montreux
# 1854 Musée
# 1855 bemachtigde
# 1856 oplossen
# 1857 opzegperiode
# 1858 kunstenaarsechtpaar
# 1859 recuperatietijd
# 1860 Pierce
# 1861 milieuorganisatie
# 1862 terecht
# 1863 Zuid-Amerikaanse
# 1864 Mode
# 1865 Younes
# 1866 vaart
# 1867 leidende
# 1868 bres
# 1869 eindstanden
# 1870 plaatselijke
# 1871 220.000
# 1872 Impressionant
# 1873 interageren
# 1874 meesterwerken
# 1875 terugkomen
# 1876 Poetsen
# 1877 Pé
# 1878 preventiecontracten
# 1879 Kawara
# 1880 jaz
# 1881 jax
# 1882 jay
# 1883 jaw
# 1884 aardbevingingenieur
# 1885 jar
# 1886 jas
# 1887 nabeeld
# 1888 jan
# 1889 jal
# 1890 jam
# 1891 gestut
# 1892 jai
# 1893 jaf
# 1894 jag
# 1895 jad
# 1896 geregulariseerd
# 1897 jac
# 1898 jaa
# 1899 Unicef
# 1900 voordracht
# 1901 ACOD-man
# 1902 verzinnen
# 1903 samengesteld
# 1904 belast
# 1905 aes
# 1906 aer
# 1907 onderhandelingstalent
# 1908 aey
# 1909 voorkomt
# 1910 NMBS
# 1911 nieuwlichters
# 1912 ael
# 1913 Brent
# 1914 Pr
# 1915 Ps
# 1916 Pt
# 1917 Pu
# 1918 Px
# 1919 Py
# 1920 welgezind
# 1921 Joachim
# 1922 testosteron
# 1923 Moneypenny
# 1924 Pc
# 1925 samenwonenden
# 1926 Pf
# 1927 Pg
# 1928 Pd
# 1929 Pe
# 1930 Ph
# 1931 Pi
# 1932 Po
# 1933 Pl
# 1934 PR
# 1935 PS
# 1936 PP
# 1937 PV
# 1938 PC
# 1939 PA
# 1940 nauwkeurig
# 1941 PG
# 1942 challenger-
# 1943 PJ
# 1944 PI
# 1945 PN
# 1946 PM
# 1947 geslagen
# 1948 P6
# 1949 vertoefden
# 1950 gemoedelijke
# 1951 communisten
# 1952 Courbet
# 1953 vergund
# 1954 astmaproblemen
# 1955 Tour-parcours
# 1956 P.
# 1957 bevoegdheid
# 1958 associeert
# 1959 klassieke
# 1960 Sea
# 1961 Almeria
# 1962 dameslijnen
# 1963 euf
# 1964 geluidsoverlast
# 1965 paramedische
# 1966 gestudeerd
# 1967 sperma
# 1968 tsa
# 1969 kruisvaarster
# 1970 melanoomdag
# 1971 lichaamsbewegingen
# 1972 drukke
# 1973 Jay-Jay
# 1974 Zenuwachtig
# 1975 VU'ers
# 1976 verpleegsters
# 1977 vogelvangst
# 1978 hardrockgroep
# 1979 Bucky
# 1980 Tigres
# 1981 geplande
# 1982 Vicky
# 1983 vervoermiddelen
# 1984 tst
# 1985 jezelf
# 1986 Gistelsesteenweg
# 1987 4-2-zege
# 1988 bergop
# 1989 Tve
# 1990 rechtsbijstand
# 1991 buurtbewoonster
# 1992 rba
# 1993 kabinet-Vandenbroucke
# 1994 BRUNS
# 1995 uitdaging
# 1996 Centraal
# 1997 psychische
# 1998 Chess
# 1999 toorn
# 2000 veelschrijver
# 2001 werkelijkheid
# 2002 simplistisch
# 2003 l'Espace
# 2004 hoopte
# 2005 Azië
# 2006 opsporingsbericht
# 2007 of.
# 2008 A109-helikopter
# 2009 sliepen
# 2010 F1-team
# 2011 bakten
# 2012 Monica
# 2013 geboorteplaats
# 2014 kopen
# 2015 teksten
# 2016 Decker
# 2017 Lauri
# 2018 Mensenrechtengroepen
# 2019 gedenkplaatonthulling
# 2020 audit
# 2021 off
# 2022 ofd
# 2023 Bjo
# 2024 afgezette
# 2025 vergeet
# 2026 ofs
# 2027 ofw
# 2028 oft
# 2029 compromis
# 2030 omweg
# 2031 gebouwd
# 2032 Cocheteux
# 2033 milieuvriendelijker
# 2034 burgerwaarden
# 2035 web
# 2036 wea
# 2037 pensioenminister
# 2038 wee
# 2039 wed
# 2040 wek
# 2041 wei
# 2042 vooruit
# 2043 wen
# 2044 wel
# 2045 wes
# 2046 wer
# 2047 wev
# 2048 wet
# 2049 wez
# 2050 Vanzelfsprekend
# 2051 Verdi
# 2052 duren
# 2053 piek
# 2054 gelijkmatig
# 2055 elementaire
# 2056 Moerdijk
# 2057 Anoplopoma
# 2058 valabel
# 2059 Massaal
# 2060 we'
# 2061 kijkt
# 2062 berijdbaar
# 2063 dagverblijf
# 2064 ZUI
# 2065 desintegreert
# 2066 toeschouwers
# 2067 siskebab
# 2068 doodsvonnis
# 2069 klampte
# 2070 inhoud
# 2071 Moya
# 2072 herfst
# 2073 voelt
# 2074 maairobot
# 2075 neogotische
# 2076 Informatiesysteem
# 2077 Sco
# 2078 ritwinst
# 2079 Sch
# 2080 VOB
# 2081 VOC
# 2082 Vanwege
# 2083 Sca
# 2084 VOI
# 2085 langer
# 2086 verzekeraars
# 2087 CDU-zwartgeldaffaire
# 2088 basisprincipes
# 2089 Scr
# 2090 letters
# 2091 kronkelige
# 2092 aanhangt
# 2093 geschuif
# 2094 pareltjes
# 2095 veMENTS
# 2096 IFPI
# 2097 geluidsgolven
# 2098 briefschrijvers
# 2099 jze
# 2100 yre
# 2101 geroepen
# 2102 stadium
# 2103 Contract
# 2104 ambachtslui
# 2105 levercellen
# 2106 geile
# 2107 mediadebuut
# 2108 racistisch
# 2109 poolshoogte
# 2110 lummelen
# 2111 Daelemans
# 2112 tossen
# 2113 leesbaar
# 2114 monetaire
# 2115 vaderland
# 2116 geneesmiddelen
# 2117 Executive
# 2118 TRT-commentaar
# 2119 Château
# 2120 rekruteerde
# 2121 7,8
# 2122 7,9
# 2123 7,1
# 2124 effecten
# 2125 7,5
# 2126 7,6
# 2127 7,7
# 2128 details
# 2129 Dexia-participatie
# 2130 Peers
# 2131 IJs
# 2132 expansie
# 2133 magisch-realistisch
# 2134 U
# 2135 geloofden
# 2136 multinationals
# 2137 Breukink
# 2138 Desondanks
# 2139 IJD
# 2140 IJF
# 2141 frappant
# 2142 uitkraamt
# 2143 objectiviteit
# 2144 onvervalste
# 2145 Roche
# 2146 magnetron-cakevorm
# 2147 Buitenlandse
# 2148 opgeleverd
# 2149 creatief
# 2150 plezier
# 2151 Nirvana
# 2152 verschuiving
# 2153 sluit
# 2154 cm3
# 2155 systeem
# 2156 ingezet
# 2157 uitnodigends
# 2158 Shaughnessy
# 2159 Gritton
# 2160 golven
# 2161 psychisch
# 2162 Wijgmaal
# 2163 populairder
# 2164 cma
# 2165 verloop
# 2166 Terug
# 2167 respecteren
# 2168 geniep
# 2169 geniet
# 2170 creatieve
# 2171 Boats
# 2172 naslagwerk
# 2173 machines
# 2174 scherpschutter
# 2175 voorgezet
# 2176 subversief
# 2177 Mazda
# 2178 Game
# 2179 maffiapraktijken
# 2180 Gama
# 2181 Sedan
# 2182 Sally
# 2183 symbolisch
# 2184 oeroude
# 2185 cinemacomplex
# 2186 Brussel
# 2187 ès
# 2188 spiegelwanden
# 2189 ingehuurde
# 2190 legeroverheid
# 2191 èn
# 2192 èl
# 2193 antwoorden
# 2194 Aangezien
# 2195 verheffen
# 2196 Spruch
# 2197 Temmerman
# 2198 bru
# 2199 zesenzeventigste
# 2200 thuisland
# 2201 bro
# 2202 nagedaan
# 2203 bri
# 2204 bre
# 2205 gezicht
# 2206 bra
# 2207 dienstverlenende
# 2208 Bellini
# 2209 070
# 2210 Acht
# 2211 vorderden
# 2212 vernielen
# 2213 caissons
# 2214 ontsnapte
# 2215 20:36
# 2216 botteling
# 2217 Preud'homme
# 2218 er-
# 2219 er.
# 2220 Df8
# 2221 Calimero
# 2222 Df4
# 2223 Df7
# 2224 Df6
# 2225 jazzfestival
# 2226 verkend
# 2227 ert
# 2228 eru
# 2229 erv
# 2230 1992
# 2231 erp
# 2232 1994
# 2233 1997
# 2234 ers
# 2235 1999
# 2236 1998
# 2237 ery
# 2238 erd
# 2239 ere
# 2240 erf
# 2241 erg
# 2242 era
# 2243 erb
# 2244 erl
# 2245 erm
# 2246 Steels
# 2247 ero
# 2248 eri
# 2249 Waterman-tijdperk
# 2250 erk
# 2251 Abb
# 2252 Abd
# 2253 Abe
# 2254 Abi
# 2255 Gazette
# 2256 Abo
# 2257 Abr
# 2258 Abs
# 2259 bré
# 2260 trofeeën
# 2261 opslag
# 2262 verborgen
# 2263 ontwaarde
# 2264 burgerplicht
# 2265 Gebremeskel
# 2266 Agneta
# 2267 aanschaffen
# 2268 stralende
# 2269 licentiaatsverhandeling
# 2270 zinvol
# 2271 wraakzuchtige
# 2272 hond
# 2273 ladder
# 2274 goedkeuring
# 2275 millimeter
# 2276 gerestaureerd
# 2277 leermeester
# 2278 gelopen
# 2279 zweem
# 2280 aandrijving
# 2281 wanverhouding
# 2282 verrukkelijk
# 2283 rabbijn
# 2284 topmotor
# 2285 economische
# 2286 midden
# 2287 middel
# 2288 respectieve
# 2289 strategie
# 2290 gebruikt
# 2291 staande
# 2292 onverwachts
# 2293 mezzosopranen
# 2294 karakters
# 2295 extase
# 2296 pretentieus
# 2297 onverwachte
# 2298 spandoek
# 2299 Mercatone
# 2300 zweet
# 2301 l
# 2302 teleurstellingen
# 2303 volksgezondheid
# 2304 vochtig
# 2305 marktidee
# 2306 beraad
# 2307 Maes
# 2308 sportzomer
# 2309 Ondertussen
# 2310 projectverenigingen
# 2311 avondfietstocht
# 2312 koesterden
# 2313 18.35
# 2314 kleden
# 2315 Banesto
# 2316 jegens
# 2317 natuurschoon
# 2318 autoritten
# 2319 handelsbesprekingen
# 2320 Javascripts
# 2321 ballades
# 2322 bijhield
# 2323 Parade
# 2324 Jamain
# 2325 politiewagens
# 2326 mede-oprichter
# 2327 professionele
# 2328 toevallige
# 2329 inlichtingen
# 2330 galopperen
# 2331 wijnlanden
# 2332 stoomboten
# 2333 Futuroscope-Loudun
# 2334 wijnkaart
# 2335 kennissenkring
# 2336 Manfred
# 2337 meesten
# 2338 ontwikkelingssamenwerking
# 2339 genuanceerd
# 2340 slorpt
# 2341 meester
# 2342 huisdieren
# 2343 podiumactiviteiten
# 2344 anachronisme
# 2345 Besef
# 2346 ongepast
# 2347 spelsysteem
# 2348 opdringen
# 2349 primavera
# 2350 kwalvormige
# 2351 getiteld
# 2352 07:11.740
# 2353 aanleggen
# 2354 ontwikkeling
# 2355 krieken
# 2356 Duck-verzameling
# 2357 souplesse
# 2358 9,6
# 2359 9,5
# 2360 9,2
# 2361 9,3
# 2362 9,1
# 2363 BLIJF
# 2364 verdere
# 2365 2,72
# 2366 weerbaarder
# 2367 Kno
# 2368 Qu
# 2369 Kni
# 2370 gedane
# 2371 schurkt
# 2372 bindingsangstig
# 2373 Lucy
# 2374 Kna
# 2375 Qa
# 2376 Luca
# 2377 Verisj
# 2378 Knu
# 2379 adolescentenroman
# 2380 grave
# 2381 langzame
# 2382 QS
# 2383 doelpunten
# 2384 Djerba
# 2385 Efecot
# 2386 reserve
# 2387 PAP
# 2388 PAR
# 2389 exportland
# 2390 olieverf
# 2391 gelukkige
# 2392 taksen
# 2393 Santiago
# 2394 Nooit
# 2395 em.
# 2396 Wereldbank
# 2397 belemmering
# 2398 Nantes
# 2399 kortweg
# 2400 telefonisch
# 2401 geheel
# 2402 31-jarige
# 2403 gereputeerd
# 2404 Langella
# 2405 hoort
# 2406 hoorzitting
# 2407 fletse
# 2408 DC0
# 2409 eme
# 2410 emd
# 2411 ema
# 2412 BTW-listings
# 2413 emb
# 2414 emm
# 2415 emo
# 2416 Kröller-Müller
# 2417 emi
# 2418 emt
# 2419 cijfer
# 2420 rund
# 2421 ems
# 2422 Baert
# 2423 dommelden
# 2424 emy
# 2425 Colombiaanse
# 2426 Jackson
# 2427 reglementswijziging
# 2428 realiseerde
# 2429 MO(
# 2430 PCB-besmetting
# 2431 maaien
# 2432 brasserie
# 2433 AEL
# 2434 materialen
# 2435 stadsfestival
# 2436 mantels
# 2437 Hénin
# 2438 gezamenlijke
# 2439 natuurliefhebbers
# 2440 gecrispeerdheid
# 2441 klassiekers
# 2442 smaken
# 2443 eren
# 2444 geletterde
# 2445 Domingo
# 2446 Beltran
# 2447 spelende
# 2448 Ancien
# 2449 Battista
# 2450 ham
# 2451 Annink
# 2452 ecologie
# 2453 buurman
# 2454 vrouwengeluk
# 2455 Verzetsbeweging
# 2456 Oscar
# 2457 omstaanders
# 2458 Dawn
# 2459 MOD
# 2460 doorlopen
# 2461 tong
# 2462 Chiappucci
# 2463 Gestolde
# 2464 Standaard
# 2465 Auw
# 2466 maandag
# 2467 kwatongen
# 2468 haz
# 2469 Dolomieten
# 2470 aanwrijven
# 2471 noen
# 2472 kikkererwten
# 2473 bijeen
# 2474 Sulston
# 2475 verwijderen
# 2476 tegenargumenten
# 2477 schorsing
# 2478 tarwe
# 2479 doordrongen
# 2480 cultureel
# 2481 Pratonevoso
# 2482 grijzende
# 2483 Rijsselberghe
# 2484 piepklein
# 2485 gnt
# 2486 personeelsleden
# 2487 hat
# 2488 Hoop
# 2489 vage
# 2490 schriftelijk
# 2491 naderhand
# 2492 Barthez
# 2493 eitjes
# 2494 Lanoye
# 2495 gne
# 2496 haw
# 2497 Hoog
# 2498 succes
# 2499 internettechnologie
# 2500 gezamenlijk
# 2501 vogel
# 2502 minst
# 2503 appartement
# 2504 CVP
# 2505 verzekeringssector
# 2506 variatie
# 2507 haalbaarheid
# 2508 stopzette
# 2509 opteerde
# 2510 heupwiegt
# 2511 Graaf
# 2512 sommige
# 2513 Stof
# 2514 persagentschappen
# 2515 Volgende
# 2516 opvattingen
# 2517 Pröpper
# 2518 kijker
# 2519 hand
# 2520 schoolfeest
# 2521 verpletterende
# 2522 Vrijdagmarkt
# 2523 1608
# 2524 Parma
# 2525 Cohen-Aloro
# 2526 Portland
# 2527 Rinero
# 2528 musical
# 2529 gezet
# 2530 volstaat
# 2531 Mexicaans
# 2532 agressief
# 2533 geannuleerd
# 2534 Lorenzo
# 2535 Italië
# 2536 rondlopende
# 2537 kwade
# 2538 Zogeheten
# 2539 huiveren
# 2540 voetbalgoal
# 2541 uitvinder
# 2542 belangen
# 2543 groef
# 2544 diepgerimpelde
# 2545 groen
# 2546 groei
# 2547 kwartet
# 2548 groet
# 2549 lce
# 2550 groep
# 2551 oproep'-beleid
# 2552 Jansen
# 2553 aanpassen
# 2554 lectuur
# 2555 nauwe
# 2556 uithaalde
# 2557 triphopbeat
# 2558 bomen
# 2559 Ewi
# 2560 kunstwerk
# 2561 heupwiegend
# 2562 Italia
# 2563 langoest
# 2564 zonnestelsel
# 2565 bord
# 2566 verkondigd
# 2567 verschuilde
# 2568 mirakel
# 2569 asgrijs
# 2570 luchtmens
# 2571 verkondigt
# 2572 terugkeer
# 2573 uitgelokt
# 2574 genodigden
# 2575 universitairen
# 2576 slaagden
# 2577 aanbranden
# 2578 verantwoordelijk
# 2579 schoolreizen
# 2580 Gras
# 2581 trapezewerkers
# 2582 democratische
# 2583 Getuigen
# 2584 aangespannen
# 2585 schakelprogramma's
# 2586 ontslagen
# 2587 muzikale
# 2588 eerlijk
# 2589 29-jarige
# 2590 minderheden
# 2591 opstapte
# 2592 Consulta
# 2593 verasfalteerde
# 2594 22-jarige
# 2595 versleten
# 2596 voorval
# 2597 assimileren
# 2598 internet-tijdperk
# 2599 Abdullah
# 2600 Agalev-gemeenteraadslid
# 2601 obligate
# 2602 Wandeling
# 2603 zaterdag
# 2604 genietingen
# 2605 Pfd
# 2606 Pff
# 2607 sprekend
# 2608 kleurenplaatje
# 2609 cocommentator
# 2610 tocht
# 2611 portaal
# 2612 Presley
# 2613 BUCKMINSTER
# 2614 gestoord
# 2615 recordkanselier
# 2616 Mjä
# 2617 berekende
# 2618 vergemakkelijkt
# 2619 advertentie
# 2620 maximum
# 2621 Pf3
# 2622 Pf5
# 2623 stand-up
# 2624 Pf6
# 2625 vanmiddag
# 2626 fijne
# 2627 telefoondiensten
# 2628 afgewenteld
# 2629 tractoren
# 2630 chocolademerk
# 2631 functioneren
# 2632 Persagentschappen
# 2633 Bijnens
# 2634 Opnieuw
# 2635 gsm-modem
# 2636 Tigrean
# 2637 Falls
# 2638 test
# 2639 afkoeling
# 2640 relatieve
# 2641 Mja
# 2642 kleding
# 2643 hondjes
# 2644 Volksbeweging
# 2645 Soms
# 2646 Huurlingen
# 2647 Arusha
# 2648 Mexico-City
# 2649 Cosemans
# 2650 Chicken
# 2651 woordenboeken
# 2652 songs
# 2653 concept
# 2654 supplement
# 2655 toegelaten
# 2656 veranderingen
# 2657 cyclisch
# 2658 reclame-praalwagens
# 2659 Israëlisch
# 2660 vernietigingskost
# 2661 Burn
# 2662 750.000
# 2663 Vertrouwen
# 2664 Burt
# 2665 Gembersapjes
# 2666 a's
# 2667 Vooraan
# 2668 discussieprogramma
# 2669 Bekaa
# 2670 steentje
# 2671 1ste
# 2672 gua
# 2673 klagen
# 2674 gue
# 2675 afhandeling
# 2676 ór
# 2677 gui
# 2678 gun
# 2679 gul
# 2680 gus
# 2681 ón
# 2682 ruilwoning
# 2683 ód
# 2684 geschenkjes
# 2685 vergelijkt
# 2686 Vereniging
# 2687 ontzetten
# 2688 zedig
# 2689 zonodig
# 2690 CMW
# 2691 CMV
# 2692 verlevendigt
# 2693 CMP
# 2694 Strafschop
# 2695 inwippen
# 2696 maffe
# 2697 Ford
# 2698 kathedraal
# 2699 onweer
# 2700 Charpentier
# 2701 Dario
# 2702 dopingproces
# 2703 allerhande
# 2704 boter
# 2705 diensten
# 2706 2:33
# 2707 ervoor
# 2708 mechanische
# 2709 2:38
# 2710 post-taxfreetijdperk
# 2711 Andersdenkenden
# 2712 bange
# 2713 milieuminister
# 2714 óó
# 2715 dreef
# 2716 hoofdletter
# 2717 OKC
# 2718 oeu
# 2719 Rozetruidrager
# 2720 lastig
# 2721 Merckx
# 2722 430
# 2723 Vlan
# 2724 UFO-
# 2725 extra
# 2726 achterblijven
# 2727 uze
# 2728 Ridders
# 2729 Achthonderd
# 2730 f3
# 2731 uzz
# 2732 Isaac
# 2733 huisvestings-
# 2734 ontwerpers
# 2735 taxfreebedrijven
# 2736 moeizaam
# 2737 Dies
# 2738 Diep
# 2739 Dijck
# 2740 regel
# 2741 regen
# 2742 Tijdig
# 2743 volstrekt
# 2744 ontvangen
# 2745 verguld-bronzen
# 2746 extra's
# 2747 specerijen
# 2748 ibi
# 2749 skaters
# 2750 Teambuilding
# 2751 verbonden
# 2752 ouderwets
# 2753 trant
# 2754
# ERT
# 2755 Rieneke
# 2756 didn't
# 2757 hijskraan
# 2758 Wulf
# 2759 chic
# 2760 ERH
# 2761 Ex-bondscoach
# 2762 ERK
# 2763 Dillerin
# 2764 recente
# 2765 Geyter
# 2766 Boven
# 2767 f-
# 2768 startten
# 2769 opstaande
# 2770 geldschieters
# 2771 product
# 2772 kaneelkoppen
# 2773 lab-medewerkers
# 2774 Heineken
# 2775 geprutst
# 2776 Freddy's
# 2777 Martin
# 2778 Model
# 2779 blijkt
# 2780 streelden
# 2781 koelbloedigst
# 2782 toegeslagen
# 2783 Radio
# 2784 gemiddeld
# 2785 Ru
# 2786 Rw
# 2787 Jaz
# 2788 Jay
# 2789 Jav
# 2790 Jaw
# 2791 Jat
# 2792 Jau
# 2793 Vlaanderen
# 2794 Fed
# 2795 Jap
# 2796 aantrekkelijk
# 2797 Jan
# 2798 Re
# 2799 doorhebben
# 2800 Jam
# 2801 Jaj
# 2802 Ra
# 2803 Jai
# 2804 Ro
# 2805 Jab
# 2806 Ri
# 2807 Jaa
# 2808 RT
# 2809 RU
# 2810 smeren
# 2811 RW
# 2812 RS
# 2813 ledenlijst
# 2814 Fea
# 2815 RX
# 2816 RD
# 2817 soi
# 2818 RG
# 2819 RA
# 2820 Japanse
# 2821 RL
# 2822 RM
# 2823 RO
# 2824 RK
# 2825 nom
# 2826 non
# 2827 tv-reeks
# 2828 noi
# 2829 R2
# 2830 klikenwin
# 2831 nod
# 2832 noe
# 2833 nog
# 2834 nob
# 2835 opgekocht
# 2836 nox
# 2837 kunsthogescholen
# 2838 not
# 2839 nou
# 2840 nov
# 2841 now
# 2842 nop
# 2843 nor
# 2844 nos
# 2845 slimme
# 2846 VRT-televisiezenders
# 2847 waartoe
# 2848 Hollywood
# 2849 Brouwerij
# 2850 ingediend
# 2851 onbestuurbaar
# 2852 CVP-politici
# 2853 aanmaakt
# 2854 verregaande
# 2855 vertolking
# 2856 blokkade
# 2857 haalde
# 2858 labyrintisch
# 2859 tegenkomen
# 2860 Rü
# 2861 Museum
# 2862 hymne
# 2863 Myrto
# 2864 volksheld
# 2865 replay
# 2866 franc
# 2867 .40
# 2868 miljoenen
# 2869 Passel
# 2870 772.27.25
# 2871 Eefje
# 2872 tegendraadse
# 2873 draaicirkel
# 2874 zeventig
# 2875 plechtig
# 2876 51s
# 2877 volkje
# 2878 concurrentie
# 2879 reusachtige
# 2880 oude
# 2881 Guggenheim-museum
# 2882 komedie
# 2883 verzorging
# 2884 PRL
# 2885 opgegaan
# 2886 woning
# 2887 triomfantelijke
# 2888 519
# 2889 Erik
# 2890 Nees
# 2891 511
# 2892 fd
# 2893 515
# 2894 actiever
# 2895 verwelkomen
# 2896 McLaren-rijder
# 2897 faillissementen
# 2898 onderdanen
# 2899 courante
# 2900 garanderen
# 2901 evenmin
# 2902 staatsvorm
# 2903 ring
# 2904 staatsbedreigend
# 2905 crematies
# 2906 Vervaecke
# 2907 Zog
# 2908 effectieve
# 2909 olijfgroen
# 2910 verminderen
# 2911 toenmalig
# 2912 Gewest
# 2913 obelisken
# 2914 platvorm
# 2915 strengen
# 2916 huldigt
# 2917 pnt
# 2918 geraniums
# 2919 internetrevolutie
# 2920 pne
# 2921 benzinemotor
# 2922 Indiase
# 2923 wereldorde
# 2924 gerechtelijk
# 2925 Marcos
# 2926 lokt
# 2927 Faulkner
# 2928 politiemensen
# 2929 1.400
# 2930 vinnige
# 2931 1:46
# 2932 volledig
# 2933 Off
# 2934 speelkans
# 2935 koffie
# 2936 magistraal
# 2937 talrijk
# 2938 synthese
# 2939 Ofw
# 2940 blazerssectie
# 2941 documentaire
# 2942 rekende
# 2943 kitschgehalte
# 2944 waarschuwen
# 2945 gesleuteld
# 2946 staatsbedrijf
# 2947 mri
# 2948 gecharterde
# 2949 eigenaar
# 2950 Wec
# 2951 Web
# 2952 Wea
# 2953 Weg
# 2954 bevindt
# 2955 Wee
# 2956 Wed
# 2957 Wek
# 2958 Wei
# 2959 Wen
# 2960 Wem
# 2961 Wel
# 2962 Wes
# 2963 ongelimiteerd
# 2964 zwart
# 2965 Wet
# 2966 Wez
# 2967 Wey
# 2968 HSB
# 2969 Woman
# 2970 daar
# 2971 geëvenaard
# 2972 Manneke
# 2973 daad
# 2974 Aanvankelijk
# 2975 kloeg
# 2976 HST
# 2977 zegezeker
# 2978 verlegen
# 2979 Luther
# 2980 muntcrisissen
# 2981 handwuivende
# 2982 ,5
# 2983 voer
# 2984 Brumagne
# 2985 Lohest
# 2986 panelen
# 2987 opnameprojecten
# 2988 omzoomd
# 2989 opzwepende
# 2990 hoed
# 2991 miserie
# 2992 hoef
# 2993 glooiingen
# 2994 Tractebel-aandeel
# 2995 steunen
# 2996 hoek
# 2997 jaarcijfers
# 2998 EMP
# 2999 MIS
# 3000 erop
# 3001 Jongewaard
# 3002 bijval
# 3003 gaatjes
# 3004 gezondheidsnorm
# 3005 vinkeniers
# 3006 mobilisering
# 3007 hartverscheurende
# 3008 informatietechnologie
# 3009 Team
# 3010 reservestukken
# 3011 Afschaffing
# 3012 realiteit
# 3013 afdoen
# 3014 betwiste
# 3015 EM.
# 3016 stukje
# 3017 evenwichtig
# 3018 151
# 3019 '6
# 3020 jeans
# 3021 erbij
# 3022 extenso
# 3023 152
# 3024 Keuzemogelijkheden
# 3025 contratenoren
# 3026 hybride
# 3027 buckyballs
# 3028 '0
# 3029 d'hôte
# 3030 dictator
# 3031 rechtbank
# 3032 uitgegroeid
# 3033 flexibiliteit
# 3034 uitgelachen
# 3035 passeert
# 3036 Telekom
# 3037 lekkernijen
# 3038 zogenaamd
# 3039 Vincent
# 3040 Koninklijk
# 3041 weinig
# 3042 gefoefeld
# 3043 Zugic
# 3044 platgeminimaliseerde
# 3045 boutade
# 3046 aardkloot
# 3047 toestanden
# 3048 Fiji
# 3049 aardigheidje
# 3050 Garin
# 3051 suikerverkopers
# 3052 Pornutopia
# 3053 maandenlang
# 3054 stewardess
# 3055 doorsnee-Hollander
# 3056 Oscaruitreiking
# 3057 slager
# 3058 Vry
# 3059 aangekocht
# 3060 Vra
# 3061 Vre
# 3062 allerbelangrijkste
# 3063 Théophraste
# 3064 Vri
# 3065 Aphex
# 3066 Vro
# 3067 slagen
# 3068 Blowfish
# 3069 geheugen
# 3070 aanbiddelijke
# 3071 tranenspoor
# 3072 roddel
# 3073 ães
# 3074 hormonenboer
# 3075 schenen
# 3076 bediening
# 3077 voorraad
# 3078 binnenkort
# 3079 blokkeren
# 3080 groeperingen
# 3081 uitingen
# 3082 vingers
# 3083 Europees
# 3084 taxi
# 3085 nuttige
# 3086 Service
# 3087 Ghanese
# 3088 Zelfs
# 3089 blaadjes
# 3090 Touren
# 3091 uitgediept
# 3092 uitkwam
# 3093 prijskaartje
# 3094 Analyse
# 3095 behoeven
# 3096 verse
# 3097 evenwichtsstoornissen
# 3098 rechtstreekse
# 3099 ami
# 3100 amo
# 3101 ama
# 3102 selecteren
# 3103 amb
# 3104 ame
# 3105 amd
# 3106 pse
# 3107 psy
# 3108 Carremans
# 3109 stunt
# 3110 dito
# 3111 verzekeringsgroep
# 3112 amu
# 3113 amt
# 3114 Lusitaanse
# 3115 logboekitem
# 3116 vervelen
# 3117 zijscheut
# 3118 tweeën
# 3119 afvuren
# 3120 Ayrton
# 3121 Snel
# 3122 conclusie
# 3123 ontsierden
# 3124 automobilisten
# 3125 Tuinen
# 3126 Bond-films
# 3127 volksopstand
# 3128 cartografen
# 3129 danszaal
# 3130 Tjorvin
# 3131 Bergkamp-vermomming
# 3132 vergetelheid
# 3133 grijnst
# 3134 onbegrijpende
# 3135 amé
# 3136 .70
# 3137 .71
# 3138 formuleert
# 3139 officiëler
# 3140 afdrukken
# 3141 Leonardo
# 3142 voorzichtig
# 3143 gesofistikeerde
# 3144 meeslepende
# 3145 15d
# 3146 Ronde
# 3147 Kapoor
# 3148 fotostrips
# 3149 Kloosters
# 3150 afgaand
# 3151 bisdom
# 3152 gedoe
# 3153 Lg5
# 3154 slecht
# 3155 onverbloemde
# 3156 Kinemax
# 3157 Vandervost
# 3158 daglicht
# 3159 start
# 3160 reportage
# 3161 griezels
# 3162 vice-rector
# 3163 Cordelia
# 3164 know-how
# 3165 Mechelen
# 3166 verlaten
# 3167 daarmee
# 3168 Raf-zonder-Ronny-Disco
# 3169 Onbewust
# 3170 Aardbeienstraat
# 3171 illustrator
# 3172 voortgestuwd
# 3173 kinderen
# 3174 interlands
# 3175 regenstroom
# 3176 toeristische
# 3177 volkskunst
# 3178 IMF-geld
# 3179 Moskoviet
# 3180 fundamentele
# 3181 Yorkse
# 3182 bemiddelaars
# 3183 gaarde
# 3184 oprukte
# 3185 panikeren
# 3186 Ferdinand
# 3187 60.
# 3188 Professoren
# 3189 Brouckhof-Zuid
# 3190 VN-conferenties
# 3191 compensatie
# 3192 Vlamingen
# 3193 gepromoot
# 3194 poos
# 3195 ongewoon
# 3196 trekt
# 3197 Guimardstraat
# 3198 kinderbijslag
# 3199 bekampen
# 3200 VLD-voorzitter
# 3201 Smeets
# 3202 3FM
# 3203 asielzoeker
# 3204 nummers
# 3205 zekerheid
# 3206 pool
# 3207 hobbels
# 3208 studio
# 3209 Bry
# 3210 Begijnhof
# 3211 Bru
# 3212 laaien
# 3213 steunbalk
# 3214 Duitsland
# 3215 Bro
# 3216 Bri
# 3217 opwindende
# 3218 Bre
# 3219 Bra
# 3220 weleens
# 3221 k's
# 3222 productieverhogingen
# 3223 Tour-wildcard
# 3224 makelaars
# 3225 naargelang
# 3226 Turkse
# 3227 majestueuze
# 3228 oliereserves
# 3229 Thiebou
# 3230 beginperiode
# 3231 begon
# 3232 rijkswachters
# 3233 horror
# 3234 3,77
# 3235 nietwaar
# 3236 noodzakelijkerwijze
# 3237 participatie
# 3238 Deze
# 3239 aanwinsten
# 3240 áál
# 3241 deelname
# 3242 188.549
# 3243 pul
# 3244 GUA
# 3245 opdraaien
# 3246 welgemoed
# 3247 pum
# 3248 controversen
# 3249 dooft
# 3250 uitgever
# 3251 GUT
# 3252 pui
# 3253 Roofthooft
# 3254 Keyzer
# 3255 stadsbibliotheek
# 3256 gewoonte
# 3257 wordende
# 3258 anonimiteit
# 3259 populieren
# 3260 West-Vlaamse
# 3261 steenen
# 3262 geallieerden
# 3263 bereidt
# 3264 volstrekte
# 3265 gegijzeld
# 3266 lossen
# 3267 Odette
# 3268 Joao
# 3269 slaapcyclus
# 3270 plaatse
# 3271 verzekeringsmakelaar
# 3272 jri
# 3273 S.
# 3274 nevelen
# 3275 plaatst
# 3276 Palladio
# 3277 Padrnos
# 3278 gedraaf
# 3279 oeg
# 3280 afzonderlijke
# 3281 Raphaël
# 3282 compromitteren
# 3283 strijders
# 3284 Sy
# 3285 Sr
# 3286 Sq
# 3287 benadelen
# 3288 Sw
# 3289 Sv
# 3290 Su
# 3291 St
# 3292 Sk
# 3293 ballen
# 3294 Si
# 3295 Sh
# 3296 So
# 3297 Sn
# 3298 Sm
# 3299 Sl
# 3300 Sc
# 3301 18.990
# 3302 Sa
# 3303 Sf
# 3304 Se
# 3305 voorspellingen
# 3306 equipe
# 3307 SP
# 3308 SW
# 3309 SV
# 3310 ST
# 3311 ingewanden
# 3312 iedereen
# 3313 manmoedig
# 3314 SH
# 3315 SO
# 3316 SM
# 3317 SL
# 3318 SC
# 3319 SB
# 3320 SA
# 3321 Koninginnegalerij
# 3322 opgravingsmethoden
# 3323 SF
# 3324 SE
# 3325 SD
# 3326 740
# 3327 741
# 3328 IBM
# 3329 748
# 3330 eenheid
# 3331 dui
# 3332 Wegens
# 3333 ruzie
# 3334 kolonialen
# 3335 Inzet-lijst
# 3336 geassocieerd
# 3337 terugdacht
# 3338 telde
# 3339 huisvesting
# 3340 knuffels
# 3341 SBS-zenders
# 3342 Knack
# 3343 malcontenten
# 3344 Television
# 3345 vreugdekaravanen
# 3346 Homokoppels
# 3347 Sü
# 3348 koningin
# 3349 Sö
# 3350 Sé
# 3351 stuiten
# 3352 heuvel
# 3353 paradijselijke
# 3354 aandringen
# 3355 Mexico
# 3356 sensatiekrant
# 3357 eeuwige
# 3358 Lesire
# 3359 Morrisons
# 3360 ginder
# 3361 veroordeelde
# 3362 World-Information.org
# 3363 hooliganisme
# 3364 Atlas
# 3365 stukliep
# 3366 drukte
# 3367 tv-afdeling
# 3368 indijken
# 3369 cef
# 3370 specerijenrekje
# 3371 ced
# 3372 rwe
# 3373 petten
# 3374 cen
# 3375 gebogen
# 3376 cel
# 3377 cek
# 3378 adviesrapport
# 3379 verschilden
# 3380 ces
# 3381 cer
# 3382 Tap
# 3383 cey
# 3384 weleer
# 3385 Buñuel
# 3386 waarachter
# 3387 Serveer
# 3388 hotelkamer
# 3389 sportschoenen
# 3390 porties
# 3391 schoenmakers
# 3392 Stockhausen
# 3393 Beltug-criterium
# 3394 Netcenter
# 3395 gevoeligheid
# 3396 Guillaume
# 3397 luchtkussens
# 3398 gitaarsolo
# 3399 tafeltjes
# 3400 Farina
# 3401 7
# 3402 monovolumes
# 3403 stuurde
# 3404 betreffende
# 3405 vloekt
# 3406 Tal
# 3407 gekonfijte
# 3408 bovenhand
# 3409 dagvaarding
# 3410 Pingeon
# 3411 Simons
# 3412 onevenwicht
# 3413 Simone
# 3414 vrijwaren
# 3415 Bond-verhalen
# 3416 Akkoord
# 3417 Simoni
# 3418 onvoorstelbaar
# 3419 Handel
# 3420 persboycot
# 3421 literatuur
# 3422 Banksys-netwerk
# 3423 natuurlijk
# 3424 Steinbeck
# 3425 BN
# 3426 haarscherp
# 3427 genood
# 3428 grasduint
# 3429 station
# 3430 gelijkenissen
# 3431 genieten
# 3432 lichtpaarse
# 3433 Gerts
# 3434 M.
# 3435 Rechten
# 3436 trappen
# 3437 1919
# 3438 Steeds
# 3439 misselijk
# 3440 1911
# 3441 1910
# 3442 Machteld
# 3443 1912
# 3444 1915
# 3445 gekleurd
# 3446 hoeft
# 3447 afgeschilderd
# 3448 doorverkocht
# 3449 wonend
# 3450 celibataire
# 3451 industriële
# 3452 883
# 3453 betekenen
# 3454 oordeelde
# 3455 880
# 3456 885
# 3457 884
# 3458 gefortuneerde
# 3459 Poulenc
# 3460 kiezen
# 3461 kiezer
# 3462 Pena
# 3463 Ajo
# 3464 Aja
# 3465 duidelijker
# 3466 88-
# 3467 eigenaardige
# 3468 Voetbalgod
# 3469 verluidt
# 3470 verklaringen
# 3471 pensioendossier
# 3472 onontwarbaar
# 3473 .54
# 3474 uitgevoerd
# 3475 omvormen
# 3476 technicus
# 3477 kelders
# 3478 Chief
# 3479 concreet
# 3480 geflopte
# 3481 Kitoko
# 3482 kmo-zone
# 3483 viool
# 3484 deelnemende
# 3485 bzz
# 3486 tarotkaarten
# 3487 Callahan
# 3488 bouwsector
# 3489 teleurstelt
# 3490 Venture
# 3491 voorstander
# 3492 Zondag
# 3493 prutsen
# 3494 forfait
# 3495 °
# 3496 winkel-
# 3497 French
# 3498 gemeenschappen
# 3499 gewijd
# 3500 uitstippelen
# 3501 ymo
# 3502 Bonte
# 3503 aperitief
# 3504 overgeeft
# 3505 teweegbrengen
# 3506 draaibeurten
# 3507 mandaat
# 3508 Lc6
# 3509 Lc7
# 3510 Lc5
# 3511 Lc2
# 3512 Canjuers
# 3513 kleintjes
# 3514 Lc8
# 3515 kijkcijfers
# 3516 winkels
# 3517 wereldkampioen
# 3518 gemeenteambtenaren
# 3519 wolkendek
# 3520 sto
# 3521 Franco
# 3522 locale
# 3523 France
# 3524 toestelletje
# 3525 levensverwachting
# 3526 Mama
# 3527 dertigal
# 3528 Brasi
# 3529 hartenlust
# 3530 kortetermijngeldstromen
# 3531 gezelschap
# 3532 Mm
# 3533 schallen
# 3534 vervullen
# 3535 Tevens
# 3536 sprak
# 3537 Assche
# 3538 CDU'ers
# 3539 Isabelle
# 3540 stoep
# 3541 adr
# 3542 Mj
# 3543 televisielandschap
# 3544 Steve
# 3545 jawel
# 3546 Bruneel
# 3547 mausoleum
# 3548 blokrijden
# 3549 Massasport
# 3550 nóó
# 3551 Zelfstandigen
# 3552 telefoonmaatschappij
# 3553 Geminiani
# 3554 Portas
# 3555 tai-jilessen
# 3556 Clijsters
# 3557 leerkracht
# 3558 Angelsaksische
# 3559 N
# 3560 kunstmatige
# 3561 Donna
# 3562 Rahma
# 3563 Langzaam
# 3564 tragikomische
# 3565 richten
# 3566 Vanderplaetsen
# 3567 vliegangstige
# 3568 grootst
# 3569 Asmara
# 3570 ex-dancingportier
# 3571 luisteraars
# 3572 zakendoen
# 3573 frustraties
# 3574 Notre-Dame-des-Abeilles
# 3575 eenmaal
# 3576 verschilt
# 3577 senioren
# 3578 Eagles
# 3579 paaltjes
# 3580 Zbe
# 3581 stevige
# 3582 http://www.klikenwin.net
# 3583 -ji
# 3584 iedere
# 3585 Oprel
# 3586 ieders
# 3587 weigeren
# 3588 aangevoerd
# 3589 íét
# 3590 Edelsmeedkunst
# 3591 Nij
# 3592 vereffeningssystemen
# 3593 jouw
# 3594 lif
# 3595 overheidssteun
# 3596 Parijse
# 3597 003
# 3598 002
# 3599 001
# 3600 000
# 3601 voorprogramma
# 3602 005
# 3603 004
# 3604 Bleus
# 3605 fabrieken
# 3606 Ruimtelijke
# 3607 defensie
# 3608 jaarbasis
# 3609 lib
# 3610 zwart-wit
# 3611 oplaaide
# 3612 avonden
# 3613 lim
# 3614 krediet
# 3615 actrice
# 3616 lio
# 3617 fruitgeuzes
# 3618 rechts
# 3619 deppen
# 3620 camerawerk
# 3621 smaakmaker
# 3622 Tyler
# 3623 lik
# 3624 geïnteresseerd
# 3625 Már
# 3626 rijke
# 3627 Nix
# 3628 ee-
# 3629 Commodore
# 3630 geïntrigeerd
# 3631 duivels
# 3632 motieven
# 3633 Madeleine
# 3634 Rimmel
# 3635 Hierin
# 3636 eeu
# 3637 eet
# 3638 eep
# 3639 ees
# 3640 eer
# 3641 eem
# 3642 eel
# 3643 een
# 3644 tijdverdrijf
# 3645 eek
# 3646 Khudojnazarovs
# 3647 eed
# 3648 eeg
# 3649 eef
# 3650 zendtijd
# 3651 jeugd
# 3652 gespaard
# 3653 bouwprijzen
# 3654 blank-zwart
# 3655 economie
# 3656 âne
# 3657 verkettert
# 3658 prentjes
# 3659 bankrekening
# 3660 Engeland
# 3661 Ongenoegens
# 3662 vakbekwaamheid
# 3663 integratiesector
# 3664 Waterl(oo)
# 3665 Niet
# 3666 19-jarige
# 3667 aankloppen
# 3668 scherpe
# 3669 socialisten
# 3670 oplichter
# 3671 benzine
# 3672 Shalit
# 3673 Bill
# ...
# 33312 fac
# 33313 ticket
# 33314 faa
# 33315 fad
# 33316 ingenieur
# 33317 vennootschapsbelasting
# 33318 truien
# 33319 vacature
# 33320 Conclusie
# 33321 Eastbourne
# 33322 prins
# 33323 ondeelbaar
# 33324 tafereel
# 33325 verwijzing
# 33326 voortplantend
# 33327 defileren
# 33328 mmy
# 33329 slacht
# 33330 vaandelvlucht
# 33331 Voorbeeld
# 33332 bijgeknipte
# 33333 bejaardentehuis
# 33334 ozon
# 33335 bevorderen
# 33336 Susan
# 33337 sprookjesachtig
# 33338 wild
# 33339 uwé
# 33340 Gundy
# 33341 faç
# 33342 onderhandelde
# 33343 Communication
# 33344 doorgaat
# 33345 doorgaan
# 33346 Twijfel
# 33347 toneel
# 33348 afdronk
# 33349 plons
# 33350 ex-provincie
# 33351 EU-lidstaten
# 33352 onbekende
# 33353 Bocksberg
# 33354 smal
# 33355 Tussenspurten
# 33356 gespietste
# 33357 pretenties
# 33358 T-shirt
# 33359 branden
# 33360 Ken
# 33361 Ongetwijfeld
# 33362 overheersen
# 33363 ambitieus
# 33364 mad
# 33365 couscous
# 33366 overheerser
# 33367 gehuisvest
# 33368 verbijstering
# 33369 Toulouse
# 33370 Zelf
# 33371 verzinnebeeld
# 33372 avo
# 33373 Perles
# 33374 Moens
# 33375 grappig
# 33376 gerecupereerd
# 33377 Gebruik
# 33378 hogere
# 33379 rommelkruid
# 33380 Gelukkig
# 33381 enigszins
# 33382 Dresden
# 33383 5.6
# 33384 particulieren
# 33385 grensverleggend
# 33386 ex-winnares
# 33387 stemming
# 33388 Distributie-experts
# 33389 televisiebazen
# 33390 sandwich
# 33391 13.45Rechtstreeks
# 33392 Glo
# 33393 Gla
# 33394 Gle
# 33395 continentaal-casual
# 33396 bierliefhebbersvereniging
# 33397 verbitterd
# 33398 Glu
# 33399 gemerkt
# 33400 kleuters
# 33401 :40
# 33402 verwarrend
# 33403 :43
# 33404 atomen
# 33405 privileges
# 33406 besloten
# 33407 Och
# 33408 Ock
# 33409 Magique
# 33410 Goed
# 33411 Oca
# 33412 Oce
# 33413 Iedere
# 33414 oud-sporters
# 33415 revolutionaire
# 33416 Oct
# 33417 McLaren-Mercedes
# 33418 Marco
# 33419 March
# 33420 Rituitslag
# 33421 MIBA
# 33422 strekken
# 33423 78.613.63.07
# 33424 1-tycoon
# 33425 L
# 33426 07:7.500
# 33427 Ruggiu
# 33428 fenomenen
# 33429 blikt
# 33430 Raf
# 33431 Rad
# 33432 Rae
# 33433 Rab
# 33434 Rac
# 33435 grepen
# 33436 Ran
# 33437 Rao
# 33438 journalisten
# 33439 Ram
# 33440 ën
# 33441 Rah
# 33442 Rai
# 33443 Rav
# 33444 ër
# 33445 Léon
# 33446 Rau
# 33447 Rar
# 33448 vandaaruit
# 33449 Rap
# 33450 Sport
# 33451 Raz
# 33452 gravelcircuit
# 33453 kennis
# 33454 motiveerden
# 33455 Joseph
# 33456 stroom
# 33457 wegenwerker
# 33458 kopspel
# 33459 bouwheer
# 33460 rumoerige
# 33461 iza
# 33462 stevenen
# 33463 ize
# 33464 vlieg
# 33465 10.000
# 33466 izo
# 33467 Laken
# 33468 Leider
# 33469 Frankenstein
# 33470 Netscape
# 33471 Rossum-effect
# 33472 instabiliteit
# 33473 profileren
# 33474 jongetjes
# 33475 Egy
# 33476 tijdritkilometers
# 33477 Anelka's
# 33478 Vibert
# 33479 500.000
# 33480 ferrydiensten
# 33481 vastberadenheid
# 33482 3de
# 33483 least
# 33484 tegenstelling
# 33485 Nergens
# 33486 elegante
# 33487 censuur
# 33488 afstappen
# 33489 182
# 33490 script
# 33491 theaterrecensent
# 33492 privé-openluchtzwembad
# 33493 passen
# 33494 Paolo
# 33495 Dijon
# 33496 Paola
# 33497 Aquafin
# 33498 Raul
# 33499 TLE
# 33500 Parsani
# 33501 TLM
# 33502 Fantasievrouwen
# 33503 dans
# 33504 dank
# 33505 huisaltaartje
# 33506 wedstrijdritme
# 33507 ensaladas
# 33508 23.45
# 33509 Lxg6
# 33510 attractie
# 33511 radio's
# 33512 Staten
# 33513 ASEC
# 33514 wagenpark
# 33515 gala
# 33516 hoogst
# 33517 hoofdschuddend
# 33518 Faludi
# 33519 Brogniezstraat
# 33520 randapparatuur
# 33521 causeur
# 33522 0de
# 33523 pianist
# 33524 gewag
# 33525 zetelbekleding
# 33526 Giuseppe
# 33527 dochtermaatschappijen
# 33528 zegt
# 33529 1040
# 33530 Julien
# 33531 Concentra
# 33532 weergaf
# 33533 zege
# 33534 Julies
# 33535 verhoogde
# 33536 bedrieglijke
# 33537 JV
# 33538 JW
# 33539 JP
# 33540 JO
# 33541 JD
# 33542 JE
# 33543 JF
# 33544 JA
# 33545 JB
# 33546 JC
# 33547 provincie
# 33548 roetsjbaan
# 33549 Eenmaal
# 33550 tussendoor
# 33551 filosoof
# 33552 Ju
# 33553 royalty's
# 33554 Vorige
# 33555 Etxebarria
# 33556 Jo
# 33557 Ji
# 33558 Je
# 33559 Ja
# 33560 hip
# 33561 kleinen
# 33562 his
# 33563 hit
# 33564 allochtoon
# 33565 zomerwijnen
# 33566 rijkelijke
# 33567 relaxerend
# 33568 wortelen
# 33569 hic
# 33570 hid
# 33571 hie
# 33572 hig
# 33573 hij
# 33574 hil
# 33575 him
# 33576 hin
# 33577 voordeelticket
# 33578 flitsten
# 33579 J.
# 33580 diplomaten
# 33581 dossiers
# 33582 Thevenet
# 33583 avonturen
# 33584 arr
# 33585 ars
# 33586 art
# 33587 aru
# 33588 leeftijdgenoten
# 33589 ary
# 33590 ara
# 33591 arb
# 33592 matig
# 33593 ard
# 33594 teneur
# 33595 zitplaatsen
# 33596 arg
# 33597 ari
# 33598 ark
# 33599 arl
# 33600 arm
# 33601 arn
# 33602 aro
# 33603 Jü
# 33604 gewoond
# 33605 fortuin
# 33606 Bogaert
# 33607 meermaals
# 33608 Toblerone
# 33609 vond
# 33610 Commerzbank
# 33611 Maourine
# 33612 uitgebuit
# 33613 baanbrekende
# 33614 Stoofvlees
# 33615 D'H
# 33616 D'I
# 33617 Harder
# 33618 roepnaam
# 33619 D'U
# 33620 hië
# 33621 heksenverbrandingen
# 33622 c
# 33623 Daarom
# 33624 alatoire
# 33625 uitkeringstrekkers
# 33626 Hilde
# 33627 DelPiero
# 33628 gemeenteraadsverkiezingen
# 33629 contactgroep
# 33630 BDBH
# 33631 Argentijn
# 33632 aanwezig
# 33633 gevaren
# 33634 feestzaal
# 33635 verkeersbelasting
# 33636 maandelijks
# 33637 Kunda
# 33638 exemplaren
# 33639 zelfontplooiing
# 33640 aanwijzingen
# 33641 1.0078.000
# 33642 verkiest
# 33643 belemmeren
# 33644 contanten
# 33645 Cubanen
# 33646 Jean-François
# 33647 2361
# 33648 Fao
# 33649 fokken
# 33650 diezelfde
# 33651 onderzoeker
# 33652 Wellington-renbaan
# 33653 Ruud
# 33654 ruilhuis
# 33655 Fac
# 33656 verbergen
# 33657 verschrompelen
# 33658 zuurstof
# 33659 bespeur
# 33660 Fad
# 33661 pauselijke
# 33662 Fae
# 33663 alchemistische
# 33664 City
# 33665 riz
# 33666 rix
# 33667 Tit
# 33668 rit
# 33669 riu
# 33670 grens
# 33671 ris
# 33672 rip
# 33673 Til
# 33674 rio
# 33675 Tin
# 33676 rim
# 33677 rij
# 33678 rik
# 33679 Tij
# 33680 rii
# 33681 rif
# 33682 Tie
# 33683 rid
# 33684 Tig
# 33685 ric
# 33686 Tib
# 33687 ria
# 33688 mongoloïde
# 33689 undercoveragenten
# 33690 sleeptouw
# 33691 ingezongen
# 33692 drugsbaas
# 33693 wensten
# 33694 vrijlating
# 33695 Ila
# 33696 grandioze
# 33697 Ill
# 33698 voorkeur
# 33699 Ilj
# 33700 voorgangers
# 33701 Ili
# 33702 nieuwsberichten
# 33703 Françoise
# 33704 acteerprestaties
# 33705 Kipling
# 33706 actueel
# 33707 Simpel
# 33708 schetsboek
# 33709 vruchteloos
# 33710 bpm
# 33711 duivenhokken
# 33712 solide
# 33713 .J.
# 33714 legers
# 33715 onverschillig
# 33716 wonnen
# 33717 redelijk
# 33718 evenveel
# 33719 Porsche
# 33720 opgezet
# 33721 schemerige
# 33722 meespeelt
# 33723 El-Djerid
# 33724 trede
# 33725 pound-campagne
# 33726 pasgehuurde
# 33727 onstabiele
# 33728 exploitatie
# 33729 continenten
# 33730 245.39.80
# 33731 Borgheresi
# 33732 verwerken
# 33733 kast
# 33734 vrouwentoernooi
# 33735 670
# 33736 Curator
# 33737 Mantilla
# 33738 Juventus
# 33739 Universum
# 33740 poupe
# 33741 toegeeft
# 33742 spé
# 33743 beschrijven
# 33744 fronten
# 33745 N34
# 33746 uithalen
# 33747 dikwijls
# 33748 Weert
# 33749 Herrnberg
# 33750 raakten
# 33751 Channel
# 33752 beroepen
# 33753 inspraak
# 33754 vijftal
# 33755 uitbouwen
# 33756 anno
# 33757 opgebonden
# 33758 1521
# 33759 prof
# 33760 controleblad
# 33761 zzy
# 33762 Evenepoel
# 33763 zzo
# 33764 meerwaarde
# 33765 begeven
# 33766 zzi
# 33767 O
# 33768 Allaert
# 33769 strijdlustig
# 33770 gelijkwaardig
# 33771 zachtere
# 33772 alleen
# 33773 cinsaut
# 33774 gemakkelijker
# 33775 Fifth
# 33776 zelfstudiepakketten
# 33777 Groosman
# 33778 internetaansluiting
# 33779 afgestofte
# 33780 Christelijke
# 33781 Discotheek
# 33782 Everything
# 33783 5de
# 33784 Deacademische
# 33785 Cofidis
# 33786 bourbonrozen
# 33787 belastingen
# 33788 marktaandeel
# 33789 Magny-Cours
# 33790 artificieel
# 33791 vergoeding
# 33792 leerkrachten
# 33793 Aanpassen
# 33794 Vrijwel
# 33795 belangstelling
# 33796 wne
# 33797 antwoordt
# 33798 gevestigde
# 33799 overtuiging
# 33800 wns
# 33801 familie
# 33802 incarneert
# 33803 lambiekbier
# 33804 Piccoli
# 33805 Leon
# 33806 Thatcher
# 33807 3,47
# 33808 sacristie
# 33809 z
# 33810 Degremont
# 33811 Amazone
# 33812 kransje
# 33813 placht
# 33814 driejarig
# 33815 Hermes-valiesje
# 33816 Crabeels
# 33817 Huet
# 33818 zagevent
# 33819 voorafgaat
# 33820 notitieboekje
# 33821 arrogantie
# 33822 uitbreiden
# 33823 2de
# 33824 ontvreemdingen
# 33825 Geoffry
# 33826 Daarbij
# 33827 feodale
# 33828 fxe6
# 33829 diplomatieke
# 33830 toeristenhotels
# 33831 07:30.630
# 33832 verhaal
# 33833 Afrika-beleid
# 33834 drieduizend
# 33835 urk
# 33836 resideren
# 33837 afleggen
# 33838 Kriek
# 33839 weerstand
# 33840 231.56.53
# 33841 werkvloer
# 33842 medemenselijk
# 33843 labiel
# 33844 informatiestroom
# 33845 twijfel
# 33846 Ull
# 33847 tekenen
# 33848 afwezig
# 33849 veroordelen
# 33850 kluizenaar
# 33851 verloederde
# 33852 UAM
# 33853 toespraken
# 33854 Audi's
# 33855 wished
# 33856 SBS
# 33857 zwarter
# 33858 16.000
# 33859 710
# 33860 melding
# 33861 zwarten
# 33862 tutu
# 33863 LAN
# 33864 LAG
# 33865 Boer
# 33866 Boek
# 33867 bestrijding
# 33868 noten
# 33869 LAT
# 33870 Dupuis
# 33871 Steen
# 33872 LAS
# 33873 topman
# 33874 cfm
# 33875 rri
# 33876 rre
# 33877 13:14
# 33878 coördinatie
# 33879 rra
# 33880 rry
# 33881 vonden
# 33882 daarnaast
# 33883 voorgeschoteld
# 33884 distilleren
# 33885 Zaken
# 33886 Lino
# 33887 inboeten
# 33888 Line
# 33889 zelfmoord
# 33890 Metallica
# 33891 aankopen
# 33892 trelliswerk
# 33893 producenten
# 33894 geschillenbemiddeling
# 33895 mits
# 33896 Pacers
# 33897 Belgisch-Franse
# 33898 tekst
# 33899 afdalen
# 33900 Hardy
# 33901 blootgelegd
# 33902 revisionistische
# 33903 kledingstukken
# 33904 vrijwilligers
# 33905 Copeland
# 33906 onderwijzers
# 33907 Robert
# 33908 priester
# 33909 motor
# 33910 gestopt
# 33911 wisselwerking
# 33912 apothekers
# 33913 verbindingskanalen
# 33914 volksvertegenwoordiging
# 33915 bedrijfsleven
# 33916 triest
# 33917 Rocco
# 33918 subsidies
# 33919 onverbeterlijke
# 33920 beambte
# 33921 Foretz
# 33922 Oranje-ontnuchtering
# 33923 brochure
# 33924 alternatief
# 33925 opeisten
# 33926 raadpleegden
# 33927 NTS
# 33928 bruisende
# 33929 prepensioen
# 33930 Lemonnier
# 33931 50.669
# 33932 oesters
# 33933 crisiscommissaris
# 33934 tap
# 33935 tar
# 33936 tas
# 33937 onderzoekt
# 33938 scripties
# 33939 tax
# 33940 gekoppeld
# 33941 berust
# 33942 tad
# 33943 tae
# 33944 taf
# 33945 Gersi
# 33946 taa
# 33947 tab
# 33948 tac
# 33949 tal
# 33950 tam
# 33951 tan
# 33952 Totale
# 33953 tai
# 33954 tak
# 33955 doodden
# 33956 Fiets
# 33957 nobele
# 33958 Fieto
# 33959 Juvenil
# 33960 modebusiness
# 33961 tenminste
# 33962 Vijf
# 33963 kunsthistorische
# 33964 omgevormd
# 33965 milieubewegingen
# 33966 shops-in-shops
# 33967 autochtonen
# 33968 sculpturen
# 33969 boeken
# 33970 kerstening
# 33971 19,3
# 33972 19,1
# 33973 gehaald
# 33974 Jubelpark
# 33975 vertegenwoordigen
# 33976 achterloopt
# 33977 topmedewerkers
# 33978 vertegenwoordiger
# 33979 Kathedraal
# 33980 droomde
# 33981 Bird
# 33982 meningsuiting
# 33983 zinloos
# 33984 jazzconservatoria
# 33985 byt
# 33986 Dyr
# 33987 Dys
# 33988 bekendheid
# 33989 Dyn
# 33990 Nederlands
# 33991 bewegende
# 33992 Dye
# 33993 Dyc
# 33994 crash
# 33995 stilgehouden
# 33996 Nei
# 33997 manueel
# 33998 Europa-reis
# 33999 verlieten
# 34000 tijden
# 34001 Adam
# 34002 deuropening
# 34003 ijsje
# 34004 trad
# 34005 tram
# 34006 zekere
# 34007 trap
# 34008 brugje
# 34009 gedroogde
# 34010 Arts
# 34011 WRATH
# 34012 Neg
# 34013 Arte
# 34014 fabelachtig
# 34015 overkant
# 34016 omdat
# 34017 geopolitieke
# 34018 lederen
# 34019 opvragen
# 34020 tamtam
# 34021 blijken
# 34022 Castelo
# 34023 veegt
# 34024 betwijfelt
# 34025 wielrenners
# 34026 asceet
# 34027 overhandigt
# 34028 ontwerpproces
# 34029 dubieuze
# 34030 K'
# 34031 eenendertig
# 34032 grootschalige
# 34033 ramptoeristen
# 34034 K.
# 34035 weende
# 34036 verzwegen
# 34037 invullen
# 34038 droop
# 34039 Centre
# 34040 accent
# 34041 wekt
# 34042 droog
# 34043 53-jarige
# 34044 droom
# 34045 bekommernissen
# 34046 horecazaak
# 34047 amen
# 34048 Kb
# 34049 neerklappen
# 34050 Kg
# 34051 mensenrechtenschendingen
# 34052 Ke
# 34053 Kd
# 34054 Startupfailures
# 34055 Ki
# 34056 Kh
# 34057 Ko
# 34058 Kn
# 34059 Km
# 34060 Kl
# 34061 Ks
# 34062 Kr
# 34063 Kw
# 34064 Ku
# 34065 Kz
# 34066 gastronomisch
# 34067 Kx
# 34068 ijsemmer
# 34069 KC
# 34070 KB
# 34071 KA
# 34072 kolossale
# 34073 KF
# 34074 KE
# 34075 KD
# 34076 gecremeerd
# 34077 KN
# 34078 KS
# 34079 Tde2
# 34080 KP
# 34081 KU
# 34082 Keulen
# 34083 Te7
# 34084 wintermaanden
# 34085 Morozevitsj
# 34086 1.4
# 34087 1.5
# 34088 Nobelprijs
# 34089 1.7
# 34090 1.0
# 34091 1.2
# 34092 1.3
# 34093 1.9
# 34094 lijstje
# 34095 indexlid
# 34096 schittering
# 34097 afwerking
# 34098 Independent
# 34099 Tibau
# 34100 ontgoocheling
# 34101 knarsetandend
# 34102 serieus
# 34103 prangende
# 34104 Science
# 34105 godsdienstsociologie
# 34106 centra
# 34107 Titanic
# 34108 IZO
# 34109 Kö
# 34110 Tobin-taks
# 34111 Mercedes
# 34112 stofzuigerfabrikant
# 34113 Abraham
# 34114 Kü
# 34115 kwart-
# 34116 Bent
# 34117 videoscherm
# 34118 foldertjes
# 34119 fier
# 34120 logen
# 34121 denk
# 34122 vertegenwoordigers
# 34123 werkwijze
# 34124 Hostekint
# 34125 stijgen
# 34126 noodlot
# 34127 opgroeven
# 34128 bekomt
# 34129 Braeckman
# 34130 Swarte
# 34131 snel-Belgwet
# 34132 blijmoedige
# 34133 dossier-Vanherf
# 34134 verbouwing
# 34135 moet
# 34136 automaat
# 34137 kleingeestig
# 34138 communicatiemiddelen
# 34139 ontwikkelingshulp
# 34140 linguïstische
# 34141 Bengali
# 34142 Lleyton
# 34143 moed
# 34144 elkaars
# 34145 995
# 34146 994
# 34147 997
# 34148 996
# 34149 991
# 34150 990
# 34151 elftallen
# 34152 992
# 34153 zonnekasteel
# 34154 999
# 34155 998
# 34156 wordt
# 34157 liberalisering
# 34158 Hampshire-varkens
# 34159 indirecte
# 34160 kluns
# 34161 Tem
# 34162 NIH
# 34163 Postal
# 34164 viel
# 34165 draden
# 34166 racismebestrijding
# 34167 Sullivan
# 34168 actieve
# 34169 ingrijpendste
# 34170 NIG
# 34171 overtroffen
# 34172 Commissaris
# 34173 kitoko
# 34174 vier
# 34175 vies
# 34176 Mauro
# 34177 ebe
# 34178 hersenoperatie
# 34179 eba
# 34180 ebb
# 34181 bereikbaar
# 34182 Tijdschrift
# 34183 keert
# 34184 ebo
# 34185 gegaan
# 34186 ebt
# 34187 loodsen
# 34188 Amman
# 34189 033
# 34190 geholpen
# 34191 031
# 34192 eby
# 34193 035
# 34194 aanwending
# 34195 Habré-zaak
# 34196 hoorde
# 34197 luchtzuiveringsinstallaties
# 34198 filmploeg
# 34199 Meurs
# 34200 voorstellingen
# 34201 oorlogsindustrie
# 34202 briefjes
# 34203 voetbalwijsheid
# 34204 achterste
# 34205 zout
# 34206 woelde
# 34207 memento
# 34208 Zan
# 34209 Zal
# 34210 Zam
# 34211 Zak
# 34212 Zah
# 34213 Zai
# 34214 Ricordi
# 34215 Zab
# 34216 prominente
# 34217 Zaa
# 34218 Tagungszentrum
# 34219 Zav
# 34220 Zat
# 34221 Zap
# 34222 huiskamers
# 34223 dermatologen
# 34224 Groenen
# 34225 Magistraten
# 34226 Brick
# 34227 Verlies
# 34228 toemaatje
# 34229 bbe
# 34230 bba
# 34231 bby
# 34232 Komende
# 34233 omschrijft
# 34234 buitenparochie
# 34235 speeksel
# 34236 Montolio
# 34237 metaalslakken
# 34238 richt
# 34239 wilt
# 34240 privé-collecties
# 34241 regeringsbeslissing
# 34242 Peppone
# 34243 PLF
# 34244 26.475
# 34245 klimnummer
# 34246 oey
# 34247 page=http://www.mloz.be/nl/ies/brochures/br13.html
# 34248 voelbaar
# 34249 vóó
# 34250 voorgedaan
# 34251 duikt
# 34252 kucht
# 34253 achterlichten
# 34254 aangerekend
# 34255 rooskleurig
# 34256 Vensters
# 34257 verantwoorden
# 34258 Grauwe
# 34259 Afrika-instituut
# 34260 bovenste
# 34261 operationeel
# 34262 Snow
# 34263 verantwoorder
# 34264 firmament
# 34265 Nisi
# 34266 Janis
# 34267 synodale
# 34268 diploma
# 34269 interactiviteit
# 34270 rekent
# 34271 bepalingen
# 34272 doorschemeren
# 34273 vechter
# 34274 botsing
# 34275 uitgedrukt
# 34276 duimpje
# 34277 Ongeacht
# 34278 multiculturele
# 34279 nageslacht
# 34280 ARC
# 34281 ARD
# 34282 Kuti
# 34283 vertonen
# 34284 vechten
# 34285 pluimen
# 34286 uitmuntende
# 34287 2.250
# 34288 Kiplings
# 34289 Latijn
# 34290 Breast
# 34291 Tower
# 34292 merendeel
# 34293 Far
# 34294 Fas
# 34295 belissende
# 34296 sky
# 34297 Fat
# 34298 Fau
# 34299 synthesizerspeler
# 34300 bloemen
# 34301 Fai
# 34302 ska
# 34303 onderzochten
# 34304 Fal
# 34305 Fam
# 34306 Fab
# 34307 Tsvi
# 34308 ski
# 34309 Fag
# 34310 schilderijen
# 34311 wereldordening
# 34312 knop
# 34313 sf-verhaal
# 34314 nachts
# 34315 tweeëntwintig
# 34316 j's
# 34317 Fuller
# 34318 Personen
# 34319 primitieve
# 34320 11,
# 34321 11.
# 34322 115
# 34323 114
# 34324 117
# 34325 116
# 34326 111
# 34327 beproefde
# 34328 113
# 34329 112
# 34330 Jonathan
# 34331 119
# 34332 118
# 34333 gedood
# 34334 Singapore
# 34335 paradijs
# 34336 uitgave
# 34337 Verbeelding
# 34338 betalende
# 34339 sluw
# 34340 Noisetterozen
# 34341 Maelen
# 34342 Maud
# 34343 Driessens
# 34344 Vandamme
# 34345 aangevallen
# 34346 Willem
# 34347 fameuze
# 34348 Willen
# 34349 Collovati
# 34350 knippen
# 34351 bouwsels
# 34352 uitkomt
# 34353 elektronische
# 34354 slotte
# 34355 NTG-productie
# 34356 Châ
# 34357 Daartegenover
# 34358 Bobbie
# 34359 Corman
# 34360 stoottroepen
# 34361 liter-viercilinder
# 34362 vijfduizend
# 34363 gevoelstoestanden
# 34364 Chiefs
# 34365 kwikzilver
# 34366 ed
# 34367 aard
# 34368 Barragán-huis
# 34369 jury
# 34370 verwachtingen
# 34371 ingevroren
# 34372 Guadalajara
# 34373 Augereau
# 34374 buikpijn
# 34375 terugkijkend
# 34376 gelatine
# 34377 lve
# 34378 tentoongesteld
# 34379 aanbeden
# 34380 volksverraad
# 34381 lvo
# 34382 kwaliteitsreeks
# 34383 gesleept
# 34384 priemende
# 34385 wegcode
# 34386 toetssteen
# 34387 verhouding
# 34388 herbergen
# 34389 vermaarde
# 34390 kant
# 34391 Rabobank
# 34392 Caroline
# 34393 boos
# 34394 boot
# 34395 hoofdpersonage
# 34396 structuuroplossing
# 34397 boom
# 34398 Carolina
# 34399 bood
# 34400 schrijvers
# 34401 boog
# 34402 juni
# 34403 Korea's
# 34404 ís
# 34405 integratieproces
# 34406 stopverf
# 34407 Bengaalse
# 34408 betraande
# 34409 aldaar
# 34410 aanmaak
# 34411 Dover
# 34412 ía
# 34413 repertoire
# 34414 geïnformeerd
# 34415 oorlogstribunalen
# 34416 verdwijnen

# %% [markdown]
# ## Run a supervised SVM classifier over the training dataset

# %%
def feature_extraction(tagged_word, numed_features, sent):
    # undefined_features = {"pref1", "pref2", "pref3", "suf1", "suf2", "suf3", "undefined_pos", "regular_feature",
    #                   "undefined_word"}
    res = {}
    for method in ORT_methods:
        if method(tagged_word):
            res.update({numed_features[method.__name__]: 1})
    if sent[0] == tagged_word:
        res.update({numed_features['first_word']: 1})
    else:
        res.update({numed_features['not_first_word']: 1})
    if sent[-1] == tagged_word:
        res.update({numed_features['last_word']: 1})
    if tagged_word[0] in numed_features:
        res.update({numed_features[tagged_word[0]]: 1})
    else:
        res.update({numed_features['undefined_word']: 1})

    if tagged_word[1] in numed_features:
        res.update({numed_features[tagged_word[1]]: 1})
    else:
        res.update({numed_features['undefined_pos']: 1})

    suf1= tagged_word[0][-1]

    if suf1 in numed_features:
        res.update({numed_features[suf1]: 1})
    else:
        res.update({numed_features['suf1']: 1})
    pref1 = tagged_word[0][0]
    if pref1 in numed_features:
        res.update({numed_features[pref1]: 1})
    else:
        res.update({numed_features['pref1']: 1})

    if len(tagged_word[0]) > 1:
        suf2 = tagged_word[0][-2:len(tagged_word[0])]
        pref2 = tagged_word[0][0:2]
        if suf2 in numed_features:
            res.update({numed_features[suf2]: 1})
        else:
            res.update({numed_features['suf2']: 1})
        if pref2 in numed_features:
            res.update({numed_features[pref2]: 1})
        else:
            res.update({numed_features['pref2']: 1})
    if len(tagged_word[0]) > 2:
        suf3 = tagged_word[0][-3:len(tagged_word[0])]
        pref3 = tagged_word[0][0:3]
        if suf3 in numed_features:
            res.update({numed_features[suf3]: 1})
        else:
            res.update({numed_features['suf3']: 1})
        if pref3 in numed_features:
            res.update({numed_features[pref3]: 1})
        else:
            res.update({numed_features['pref3']: 1})
    return res

def prepear_train(train_data, numed_features, classes):
    res = []
    for sent in train_data:
        for tagged_word in sent:
            features = feature_extraction(tagged_word, numed_features, sent)
            res.append((features, classes[tagged_word[2]]))
            # import pdb
            # pdb.set_trace()
    return res

def get_classes(categories):
    """
    input: list of categories
    output: dict of classes
    """
    res = {}
    data = []
    for category in categories:
        data = data + conll2002.iob_sents(category)

    class_index = 0
    for sent in data:
        for tagged_word in sent:
            word = tagged_word[2]
            # import pdb
            # pdb.set_trace()
            if word not in res:
                res[word] = class_index
                class_index += 1
    return res

# %% [raw]
# Prepare Train Data:

# %%
classes = get_classes(['esp.train', 'esp.testa', 'esp.testb'])
print 'All classes', classes
raw_data = train_data
train_data = prepear_train(train_data, numed_features, classes)
train_data = train_data
print '---------'
print raw_data[0]
print train_data[0]
# Out:
# All classes {u'I-LOC': 7, u'B-ORG': 2, u'I-PER': 4, u'O': 1, u'I-MISC': 8, u'B-MISC': 5, u'I-ORG': 6, u'B-LOC': 0, u'B-PER': 3}
# ---------
# [(u'De', u'Art', u'O'), (u'tekst', u'N', u'O'), (u'van', u'Prep', u'O'), (u'het', u'Art', u'O'), (u'arrest', u'N', u'O'), (u'is', u'V', u'O'), (u'nog', u'Adv', u'O'), (u'niet', u'Adv', u'O'), (u'schriftelijk', u'Adj', u'O'), (u'beschikbaar', u'Adj', u'O'), (u'maar', u'Conj', u'O'), (u'het', u'Art', u'O'), (u'bericht', u'N', u'O'), (u'werd', u'V', u'O'), (u'alvast', u'Adv', u'O'), (u'bekendgemaakt', u'V', u'O'), (u'door', u'Prep', u'O'), (u'een', u'Art', u'O'), (u'communicatiebureau', u'N', u'O'), (u'dat', u'Conj', u'O'), (u'Floralux', u'N', u'B-ORG'), (u'inhuurde', u'V', u'O'), (u'.', u'Punc', u'O')]
# ({3761: 1, 19815: 1, 15366: 1, 7958: 1, 30839: 1, 4715: 1}, 1)

# %% [raw]
# Learn From Data (Build SVM Classifier):

# %%
from sklearn.svm import SVC
from nltk.classify import SklearnClassifier

classif = SklearnClassifier(SVC(C=50000, verbose=True)).train(train_data)
# Out:
# [LibSVM]

# %% [raw]
# Test Classifier:

# %%
test_data = conll2002.iob_sents('ned.testb')

real_tag_of_test = []
test_vectors = []
words = []
for sent in test_data:
    for tagged_word in sent:
#         import pdb; pdb.set_trace()
        real_tag_of_test.append(classes[tagged_word[2]])
        words.append(tagged_word[0])
        test_vectors.append(feature_extraction(tagged_word, numed_features, sent))
# print test

test_res = classif.classify_many(test_vectors)
# print len(test_res)
# print '-'*50
# print test_res
# print '-'*50
# print tag_of_test

# %% [markdown]
# ### Accuracy / Recall + Error Analysis

# %%
messures =  {x: {'fp':0, 'tp':0, 'fn':0} for x in classes.values()}
error_analysis = []

reverse_classes = {x:y for y,x in classes.iteritems()}

for real_label, perdicted_label, word in zip(real_tag_of_test, test_res, words):
    
    if real_label == perdicted_label:
       messures[real_label]['tp'] += 1
    else:
        messures[real_label]['fn'] += 1
        messures[perdicted_label]['fp'] += 1
        
        error_analysis.append((word, reverse_classes[real_label], reverse_classes[perdicted_label]))

print messures

for class_name, class_index in classes.iteritems():
    print class_name
    precision = float(messures[class_index]['tp']) / (messures[class_index]['tp'] + messures[class_index]['fp'])
    recall = float(messures[class_index]['tp']) / (messures[class_index]['tp'] + messures[class_index]['fn'])
    print 'Precision: ', precision 
    print 'Recall: ', recall
    print 'F-Measure: ', (2*precision*recall)/float(precision+recall)
    print '-'*50
    

print '*'*30, '(word, real, predicted)', '*'*30
for x in error_analysis:
    print x
# Out:
# {0: {'fp': 368, 'fn': 221, 'tp': 553}, 1: {'fp': 667, 'fn': 174, 'tp': 62943}, 2: {'fp': 267, 'fn': 486, 'tp': 396}, 3: {'fp': 526, 'fn': 353, 'tp': 745}, 4: {'fp': 379, 'fn': 389, 'tp': 418}, 5: {'fp': 258, 'fn': 444, 'tp': 743}, 6: {'fp': 78, 'fn': 351, 'tp': 200}, 7: {'fp': 59, 'fn': 26, 'tp': 23}, 8: {'fp': 159, 'fn': 317, 'tp': 93}}
# I-LOC
# Precision:  0.280487804878
# Recall:  0.469387755102
# F-Measure:  0.351145038168
# --------------------------------------------------
# B-ORG
# Precision:  0.597285067873
# Recall:  0.448979591837
# F-Measure:  0.512621359223
# --------------------------------------------------
# I-PER
# Precision:  0.524466750314
# Recall:  0.517967781908
# F-Measure:  0.521197007481
# --------------------------------------------------
# O
# Precision:  0.989514227323
# Recall:  0.997243214982
# F-Measure:  0.993363687296
# --------------------------------------------------
# I-MISC
# Precision:  0.369047619048
# Recall:  0.226829268293
# F-Measure:  0.280966767372
# --------------------------------------------------
# B-MISC
# Precision:  0.742257742258
# Recall:  0.625947767481
# F-Measure:  0.67915904936
# --------------------------------------------------
# I-ORG
# Precision:  0.719424460432
# Recall:  0.362976406534
# F-Measure:  0.482509047045
# --------------------------------------------------
# B-LOC
# Precision:  0.600434310532
# Recall:  0.714470284238
# F-Measure:  0.652507374631
# --------------------------------------------------
# B-PER
# Precision:  0.58615263572
# Recall:  0.678506375228
# F-Measure:  0.628957365977
# --------------------------------------------------
# ****************************** (word, real, predicted) ******************************
# (u'Der', u'B-PER', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'24', u'O', u'B-MISC')
# (u'Bosman-arrest', u'B-MISC', u'I-PER')
# (u'Blatter', u'I-PER', u'B-PER')
# (u'Beckenbauer', u'I-PER', u'B-PER')
# (u'Bayern', u'B-ORG', u'I-LOC')
# (u'M\xfcnchen', u'I-ORG', u'B-LOC')
# (u'Van', u'B-PER', u'O')
# (u'Osterloh', u'B-PER', u'O')
# (u'Davenport', u'I-PER', u'B-PER')
# (u'US', u'B-MISC', u'B-ORG')
# (u'Open', u'I-MISC', u'B-MISC')
# (u'Clijsters', u'B-PER', u'I-PER')
# (u'Monami-Van', u'B-PER', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'US', u'B-MISC', u'B-ORG')
# (u'Open', u'I-MISC', u'B-MISC')
# (u'Clijsters', u'B-PER', u'I-PER')
# (u'LDP', u'B-ORG', u'B-PER')
# (u'Coplo', u'B-PER', u'I-PER')
# (u"D'Hoop", u'I-PER', u'B-ORG')
# (u'FGTB', u'B-ORG', u'B-MISC')
# (u'Poortere', u'I-PER', u'B-LOC')
# (u'Poortere', u'I-PER', u'B-LOC')
# (u'Coplo', u'B-PER', u'I-PER')
# (u'LDP', u'B-ORG', u'B-PER')
# (u"D'Hoop", u'B-PER', u'B-ORG')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Arbeiders', u'O', u'B-MISC')
# (u'Domo', u'B-ORG', u'O')
# (u'LDP', u'B-ORG', u'B-PER')
# (u'Poortere', u'I-PER', u'B-LOC')
# (u'LDP', u'B-ORG', u'B-PER')
# (u'Balsan', u'B-ORG', u'I-PER')
# (u'Balsan', u'B-ORG', u'I-PER')
# (u"LDP's", u'B-MISC', u'B-PER')
# (u'Ch\xe2teauroux', u'B-LOC', u'B-PER')
# (u'Moeskroen', u'B-LOC', u'O')
# (u'LDP', u'B-ORG', u'B-PER')
# (u'Domo', u'B-ORG', u'I-MISC')
# (u'Louis', u'B-ORG', u'B-PER')
# (u'De', u'I-ORG', u'O')
# (u'Poortere', u'I-ORG', u'B-LOC')
# (u'LDP', u'B-ORG', u'B-PER')
# (u'Moeskroen', u'B-LOC', u'O')
# (u'Domo', u'B-ORG', u'I-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Centrale', u'I-ORG', u'B-ORG')
# (u'Bank', u'I-ORG', u'B-ORG')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Centrale', u'I-ORG', u'B-ORG')
# (u'Bank', u'I-ORG', u'B-ORG')
# (u'Scenario', u'O', u'B-PER')
# (u'Louis', u'B-ORG', u'B-PER')
# (u'De', u'I-ORG', u'O')
# (u'Poortere', u'I-ORG', u'B-LOC')
# (u'Center', u'B-ORG', u'I-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Wargnier', u'I-PER', u'B-PER')
# (u'Coninx', u'I-PER', u'B-ORG')
# (u'Doyle', u'I-PER', u'B-LOC')
# (u'Bross\xe9', u'I-PER', u'B-PER')
# (u'T.', u'I-PER', u'B-PER')
# (u'Shakespeare', u'I-PER', u'B-PER')
# (u'Titus', u'B-PER', u'B-MISC')
# (u'Andronicus', u'I-PER', u'B-PER')
# (u'Gothen', u'B-MISC', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Taymor', u'I-PER', u'B-LOC')
# (u'Disney-tekenfilm', u'B-MISC', u'O')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Lion', u'I-MISC', u'I-ORG')
# (u'King', u'I-MISC', u'I-PER')
# (u'Titus', u'B-PER', u'B-MISC')
# (u'Lavinia', u'B-PER', u'B-ORG')
# (u'Laura', u'B-PER', u'I-PER')
# (u'Tamora', u'B-PER', u'B-LOC')
# (u'Gothen', u'B-MISC', u'I-PER')
# (u'Tamora', u'B-PER', u'B-LOC')
# (u'Jessica', u'B-PER', u'I-PER')
# (u'Lange', u'I-PER', u'B-LOC')
# (u'Cumming', u'I-PER', u'B-ORG')
# (u'Hans', u'B-MISC', u'B-PER')
# (u'Zimmer', u'I-MISC', u'I-PER')
# (u'in', u'I-MISC', u'O')
# (u'Concert', u'I-MISC', u'B-PER')
# (u'Taymor', u'B-PER', u'O')
# (u'Goldenthal', u'B-PER', u'I-LOC')
# (u'Kuipke', u'B-LOC', u'B-ORG')
# (u'van', u'I-LOC', u'O')
# (u'Gent', u'I-LOC', u'B-LOC')
# (u'Shakespeare-verfilming', u'B-MISC', u'I-MISC')
# (u'Taymor', u'I-PER', u'B-LOC')
# (u'27ste', u'B-MISC', u'O')
# (u'Internationaal', u'I-MISC', u'O')
# (u'Filmfestival', u'I-MISC', u'B-PER')
# (u'van', u'I-MISC', u'O')
# (u'Gent', u'I-MISC', u'B-LOC')
# (u'Gladiator', u'B-MISC', u'B-ORG')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Lion', u'I-MISC', u'I-ORG')
# (u'King', u'I-MISC', u'I-PER')
# (u'Rainman', u'B-MISC', u'I-PER')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Thin', u'I-MISC', u'I-PER')
# (u'Red', u'I-MISC', u'B-ORG')
# (u'Line', u'I-MISC', u'B-PER')
# (u'Driving', u'B-MISC', u'O')
# (u'Miss', u'I-MISC', u'B-PER')
# (u'Daisy', u'I-MISC', u'I-PER')
# (u'Peacemaker', u'B-MISC', u'I-PER')
# (u'True', u'B-MISC', u'B-LOC')
# (u'Romance', u'I-MISC', u'B-LOC')
# (u'Prince', u'B-MISC', u'O')
# (u'of', u'I-MISC', u'O')
# (u'Egypt', u'I-MISC', u'B-LOC')
# (u'Elliot', u'B-PER', u'I-PER')
# (u'Goldenthal', u'I-PER', u'I-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Centra', u'B-MISC', u'B-LOC')
# (u'voor', u'I-MISC', u'O')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Vanderpoorten', u'I-PER', u'B-PER')
# (u'Beroepssecundair', u'B-MISC', u'B-LOC')
# (u'Onderwijs', u'I-MISC', u'B-ORG')
# (u'BSO', u'B-MISC', u'B-ORG')
# (u'de', u'I-PER', u'O')
# (u'De', u'B-ORG', u'O')
# (u'ICG', u'B-ORG', u'B-PER')
# (u'Internet', u'B-ORG', u'B-MISC')
# (u'Capital', u'I-ORG', u'B-LOC')
# (u'Sun', u'B-ORG', u'B-LOC')
# (u'Micro', u'I-ORG', u'B-PER')
# (u'De', u'I-ORG', u'O')
# (u'Maertelaere', u'I-ORG', u'I-PER')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Wilt', u'O', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Javier', u'B-PER', u'I-PER')
# (u'Pom\xe9s', u'I-PER', u'B-MISC')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Baskischtalige', u'B-MISC', u'I-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Di', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Di', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Di', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Rupo', u'I-PER', u'B-PER')
# (u'S', u'B-ORG', u'B-MISC')
# (u'&', u'I-ORG', u'O')
# (u'N', u'I-ORG', u'O')
# (u'Center', u'B-ORG', u'I-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'Peer', u'B-LOC', u'I-PER')
# (u'Lommel', u'B-LOC', u'B-PER')
# (u'Center', u'B-ORG', u'I-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'Center', u'B-ORG', u'I-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'DB', u'B-ORG', u'B-PER')
# (u'Capital', u'I-ORG', u'B-LOC')
# (u'Scottish', u'B-ORG', u'B-PER')
# (u'&', u'I-ORG', u'O')
# (u'Newcastle', u'I-ORG', u'B-LOC')
# (u'Center', u'B-ORG', u'I-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'Gran', u'B-ORG', u'I-PER')
# (u'Dorado', u'I-ORG', u'B-LOC')
# (u'Pierre', u'B-ORG', u'B-PER')
# (u'et', u'I-ORG', u'O')
# (u'Vacances', u'I-ORG', u'I-MISC')
# (u'Center', u'B-ORG', u'B-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'S', u'B-ORG', u'B-MISC')
# (u'&', u'I-ORG', u'O')
# (u'N.', u'I-ORG', u'B-PER')
# (u'Derksen', u'B-PER', u'I-PER')
# (u'Scottish', u'B-ORG', u'B-PER')
# (u'&', u'I-ORG', u'O')
# (u'Newcastle', u'I-ORG', u'B-LOC')
# (u'S', u'B-ORG', u'B-MISC')
# (u'&', u'I-ORG', u'O')
# (u'N', u'I-ORG', u'O')
# (u'Pierre', u'B-ORG', u'B-PER')
# (u'et', u'I-ORG', u'O')
# (u'Vacances', u'I-ORG', u'I-MISC')
# (u'DB', u'B-ORG', u'B-PER')
# (u'Capital', u'I-ORG', u'B-LOC')
# (u'Partners', u'I-ORG', u'B-MISC')
# (u'Deutsche', u'B-ORG', u'I-PER')
# (u'Bank', u'I-ORG', u'B-ORG')
# (u'S', u'B-ORG', u'B-MISC')
# (u'&', u'I-ORG', u'O')
# (u'N', u'I-ORG', u'O')
# (u'S', u'B-ORG', u'B-MISC')
# (u'&', u'I-ORG', u'O')
# (u'N', u'I-ORG', u'O')
# (u'Pontins', u'B-ORG', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Manor', u'B-ORG', u'B-PER')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'Pierre', u'B-ORG', u'B-PER')
# (u'et', u'I-ORG', u'O')
# (u'Vacances', u'I-ORG', u'I-MISC')
# (u'Center', u'B-ORG', u'I-LOC')
# (u'Parcs', u'I-ORG', u'B-MISC')
# (u'Kronenbourg', u'B-MISC', u'B-LOC')
# (u'Danone', u'B-ORG', u'B-PER')
# (u'Toerisme', u'B-MISC', u'B-ORG')
# (u'ROB-tv', u'B-ORG', u'B-MISC')
# (u'ROB-tv', u'B-ORG', u'B-MISC')
# (u'KORT', u'O', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Economie', u'B-MISC', u'B-ORG')
# (u'Gabri\xebls', u'I-PER', u'B-PER')
# (u'Lagast', u'I-PER', u'B-LOC')
# (u'Het', u'B-MISC', u'O')
# (u'Werklozen', u'O', u'B-MISC')
# (u'Biarritz', u'B-LOC', u'I-PER')
# (u'Dua', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Economie', u'B-MISC', u'B-ORG')
# (u'Picqu\xe9', u'I-PER', u'B-PER')
# (u'Luxemburg', u'B-LOC', u'I-LOC')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Lanotte', u'I-PER', u'B-ORG')
# (u'CL', u'B-PER', u'B-ORG')
# (u'Kamerlid', u'O', u'B-PER')
# (u'Leterme', u'I-PER', u'B-LOC')
# (u'Reynders', u'B-PER', u'O')
# (u'Reynders', u'B-PER', u'O')
# (u'Brugge-speler', u'I-MISC', u'B-MISC')
# (u'Milan', u'B-PER', u'B-LOC')
# (u'Lesnjak', u'I-PER', u'B-MISC')
# (u'Zedelgem', u'B-LOC', u'I-LOC')
# (u'Mortsel', u'B-LOC', u'I-PER')
# (u'Redoute', u'B-LOC', u'B-MISC')
# (u'Edmond', u'B-LOC', u'B-PER')
# (u'Thieffrylaan', u'I-LOC', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Terkamerenbos', u'B-LOC', u'I-MISC')
# (u'Het', u'B-MISC', u'O')
# (u'Mortsel', u'B-LOC', u'I-PER')
# (u'Speelplein', u'O', u'B-LOC')
# (u'Golf', u'I-MISC', u'B-ORG')
# (u'dealer', u'O', u'I-PER')
# (u'Dieven', u'O', u'B-ORG')
# (u'Lesnjak', u'B-PER', u'B-LOC')
# (u'Duffel', u'B-LOC', u'B-PER')
# (u'Huisvesting', u'B-ORG', u'O')
# (u'Woonnet', u'B-MISC', u'I-MISC')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Huisvestingsmaatschapij', u'I-ORG', u'B-LOC')
# (u'VHM', u'B-ORG', u'B-PER')
# (u'Woonnet', u'B-MISC', u'I-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Het', u'B-MISC', u'O')
# (u'Woonnet', u'B-MISC', u'I-MISC')
# (u'VHM', u'B-ORG', u'B-PER')
# (u"SHM's", u'O', u'B-ORG')
# (u"SKV's", u'O', u'B-ORG')
# (u'Woonnet', u'B-MISC', u'I-MISC')
# (u'Besix', u'B-ORG', u'B-PER')
# (u'Belgische', u'B-ORG', u'B-MISC')
# (u'Betonmaatschappij', u'I-ORG', u'B-ORG')
# (u'St\xe9phanne', u'I-PER', u'B-PER')
# (u'Smithkline', u'B-ORG', u'B-PER')
# (u'Beecham', u'I-ORG', u'B-LOC')
# (u'IBt', u'B-ORG', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Trends', u'B-ORG', u'B-MISC')
# (u'Dumolin', u'B-PER', u'I-PER')
# (u'Ruzie', u'O', u'B-PER')
# (u'baron', u'I-PER', u'O')
# (u'De', u'I-PER', u'O')
# (u'Meester', u'I-PER', u'B-LOC')
# (u'Leuven', u'I-ORG', u'B-LOC')
# (u'voor', u'I-ORG', u'O')
# (u'Belgische', u'I-ORG', u'B-ORG')
# (u'Ruzie', u'O', u'B-PER')
# (u'Dumolin', u'B-PER', u'I-PER')
# (u'Besix', u'B-ORG', u'I-PER')
# (u'Trends', u'B-ORG', u'B-MISC')
# (u'BBM', u'B-ORG', u'O')
# (u'Besix', u'B-ORG', u'I-PER')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Dumolin', u'B-PER', u'I-PER')
# (u'Tytgadt', u'B-PER', u'I-PER')
# (u'Stulemeijer', u'B-PER', u'I-PER')
# (u'Partners', u'I-ORG', u'B-MISC')
# (u'Besix', u'B-ORG', u'I-PER')
# (u'Zeeuws-', u'B-LOC', u'B-MISC')
# (u'Boezinge', u'B-LOC', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Natuurreservaten', u'B-ORG', u'O')
# (u'Universiteit', u'B-ORG', u'I-ORG')
# (u'Antwerpen', u'I-ORG', u'B-LOC')
# (u'Ruca', u'B-ORG', u'B-LOC')
# (u'De', u'B-ORG', u'I-PER')
# (u'Wielewaal', u'I-ORG', u'B-LOC')
# (u'Het', u'B-MISC', u'O')
# (u'Boezinge', u'B-LOC', u'I-PER')
# (u'Boezinge-dorp', u'B-LOC', u'B-MISC')
# (u'Boezinge', u'B-LOC', u'I-PER')
# (u'Lanotte', u'I-PER', u'B-ORG')
# (u'Begroting', u'B-ORG', u'I-MISC')
# (u'Lanotte', u'I-PER', u'B-ORG')
# (u'Lanotte', u'I-PER', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'De', u'I-PER', u'O')
# (u'State', u'B-MISC', u'I-ORG')
# (u'of', u'I-MISC', u'O')
# (u'Union', u'I-MISC', u'B-LOC')
# (u'Hoogervorst', u'I-PER', u'B-LOC')
# (u'Vande', u'B-PER', u'I-PER')
# (u'Lanotte', u'I-PER', u'B-ORG')
# (u'Vande', u'B-PER', u'I-PER')
# (u'Lanotte', u'I-PER', u'B-ORG')
# (u'UMTS-veiling', u'B-MISC', u'B-ORG')
# (u'Belgrado', u'B-LOC', u'O')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Joegoslavi\xeb-Tribunaal', u'B-ORG', u'B-LOC')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Milosevic', u'I-PER', u'B-PER')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Sainovic', u'I-PER', u'B-PER')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Gorica', u'B-PER', u'B-ORG')
# (u'Gajevic', u'I-PER', u'B-PER')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Verenigde', u'B-ORG', u'B-LOC')
# (u'Kosovo', u'B-LOC', u'B-PER')
# (u'Joegoslavi\xeb-Tribunaal', u'B-ORG', u'B-LOC')
# (u'VSK', u'B-ORG', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Kinderrechtencommissariaat', u'I-ORG', u'B-LOC')
# (u'VSK', u'B-ORG', u'B-LOC')
# (u'VSK', u'B-ORG', u'B-LOC')
# (u'VSK', u'B-ORG', u'B-LOC')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Scholierenkoepel', u'I-ORG', u'I-PER')
# (u'VSK', u'B-ORG', u'B-LOC')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Scholierenkoepel', u'I-ORG', u'I-PER')
# (u'VSK', u'B-ORG', u'B-LOC')
# (u'UMTS-capaciteit', u'B-MISC', u'B-ORG')
# (u'Goossens', u'B-PER', u'O')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Mobile', u'I-ORG', u'B-PER')
# (u'Goossens', u'B-PER', u'I-PER')
# (u'UMTS-licentie', u'B-MISC', u'B-ORG')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'Mobile', u'I-ORG', u'B-PER')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'Goossens', u'B-PER', u'O')
# (u'UMTS', u'B-MISC', u'B-PER')
# (u'Vodafone', u'B-ORG', u'I-LOC')
# (u'Mobile', u'I-ORG', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Krabb\xe9', u'I-PER', u'B-PER')
# (u'Het', u'B-LOC', u'B-MISC')
# (u'Nijenhuis', u'I-LOC', u'B-PER')
# (u'Heino', u'B-LOC', u'I-PER')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Discovery', u'I-MISC', u'I-PER')
# (u'of', u'I-MISC', u'O')
# (u'Heaven', u'I-MISC', u'I-ORG')
# (u'De', u'B-MISC', u'I-PER')
# (u'van', u'I-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'Hemel', u'I-MISC', u'B-PER')
# (u'De', u'B-MISC', u'I-PER')
# (u'van', u'I-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'Hemel', u'I-MISC', u'B-PER')
# (u'Mulisch', u'B-PER', u'I-PER')
# (u'Krabb\xe9', u'I-PER', u'B-PER')
# (u'Left', u'B-MISC', u'B-LOC')
# (u'Twee', u'B-MISC', u'O')
# (u'Koffers', u'I-MISC', u'I-PER')
# (u'Vol', u'I-MISC', u'B-LOC')
# (u'Krabb\xe9', u'I-PER', u'B-PER')
# (u'T.', u'I-PER', u'B-PER')
# (u'Mozes', u'B-PER', u'I-PER')
# (u'Mulisch', u'B-PER', u'I-PER')
# (u'De', u'B-MISC', u'O')
# (u'Aanslag', u'I-MISC', u'O')
# (u'Fons', u'B-PER', u'B-MISC')
# (u'Rademakers', u'I-PER', u'B-MISC')
# (u'Hoogste', u'B-MISC', u'I-MISC')
# (u'Tijd', u'I-MISC', u'I-ORG')
# (u'Twee', u'B-MISC', u'O')
# (u'vrouwen', u'I-MISC', u'O')
# (u'Sluizer', u'I-PER', u'B-PER')
# (u'Stephen', u'B-PER', u'I-PER')
# (u'Fry', u'I-PER', u'B-PER')
# (u'Oscar', u'B-MISC', u'B-PER')
# (u'Wilde-film', u'I-MISC', u'B-LOC')
# (u'Mulisch', u'B-PER', u'I-PER')
# (u'GIB', u'B-ORG', u'B-MISC')
# (u'Real', u'B-ORG', u'B-MISC')
# (u'EVS', u'B-ORG', u'B-LOC')
# (u'Quick', u'B-ORG', u'B-PER')
# (u'GIB', u'B-ORG', u'B-MISC')
# (u'GIB', u'B-ORG', u'B-MISC')
# (u'Paribas', u'I-ORG', u'O')
# (u'Ion', u'B-ORG', u'B-LOC')
# (u'Beam', u'I-ORG', u'B-PER')
# (u'Applications', u'I-ORG', u'B-MISC')
# (u'Systemat', u'B-ORG', u'I-ORG')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Cobepa', u'B-ORG', u'B-PER')
# (u'Paribas', u'I-ORG', u'O')
# (u'Cobepa', u'B-ORG', u'B-PER')
# (u'GIB-waarde', u'B-MISC', u'O')
# (u'Fidelity', u'B-ORG', u'I-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Defeyt', u'B-PER', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Commissie', u'B-ORG', u'I-ORG')
# (u'Brys', u'B-PER', u'I-PER')
# (u'Ruzie', u'O', u'B-PER')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Haemers', u'B-PER', u'I-PER')
# (u'RUCA-universiteit', u'B-ORG', u'B-LOC')
# (u'Want', u'O', u'I-ORG')
# (u'Sascha', u'B-PER', u'B-LOC')
# (u'Het', u'B-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Far', u'B-ORG', u'B-MISC')
# (u'West', u'I-ORG', u'I-PER')
# (u'Crew', u'I-ORG', u'B-LOC')
# (u'Bobohill', u'B-ORG', u'I-PER')
# (u'Soundsystem', u'I-ORG', u'B-LOC')
# (u'Fiji', u'B-ORG', u'B-LOC')
# (u'Sound', u'I-ORG', u'B-LOC')
# (u'Zion', u'B-ORG', u'B-LOC')
# (u'Train', u'I-ORG', u'B-MISC')
# (u'Soundsystem', u'I-ORG', u'B-LOC')
# (u'Hove', u'B-MISC', u'I-PER')
# (u'live', u'I-MISC', u'O')
# (u'Hove', u'B-MISC', u'I-PER')
# (u'live', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Hove', u'B-LOC', u'I-PER')
# (u'Hove', u'B-MISC', u'I-PER')
# (u'live', u'I-MISC', u'O')
# (u'Humb', u'B-ORG', u'B-MISC')
# (u'Starflam', u'B-ORG', u'O')
# (u'Mad', u'B-PER', u'B-MISC')
# (u'Professor', u'I-PER', u'O')
# (u'Think', u'B-ORG', u'O')
# (u'of', u'I-ORG', u'O')
# (u'One', u'I-ORG', u'B-PER')
# (u'Marrakech', u'B-ORG', u'I-PER')
# (u'Emballages', u'I-ORG', u'B-LOC')
# (u'Ensemble', u'I-ORG', u'B-PER')
# (u'Orishas', u'B-ORG', u'B-MISC')
# (u'Dibango', u'I-PER', u'B-PER')
# (u'Dirty', u'B-ORG', u'B-PER')
# (u'Beatniks', u'I-ORG', u'I-MISC')
# (u'Critici', u'O', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Euro', u'O', u'B-MISC')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Noels', u'I-PER', u'O')
# (u'Petercam', u'B-ORG', u'B-PER')
# (u'Gustav-Adolf', u'B-PER', u'B-ORG')
# (u'Horn', u'I-PER', u'B-PER')
# (u'DIW', u'B-ORG', u'B-MISC')
# (u'Instituut', u'I-ORG', u'B-ORG')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Centrale', u'I-ORG', u'B-ORG')
# (u'Bank', u'I-ORG', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Aung', u'B-PER', u'B-LOC')
# (u'San', u'I-PER', u'B-LOC')
# (u'Aung', u'B-MISC', u'B-LOC')
# (u'Sans', u'I-MISC', u'I-PER')
# (u'Dalla', u'B-LOC', u'B-PER')
# (u'Democratie', u'I-ORG', u'B-ORG')
# (u'Liga', u'I-ORG', u'B-PER')
# (u'Dalla', u'B-LOC', u'B-PER')
# (u'Aung', u'B-PER', u'B-LOC')
# (u'San', u'I-PER', u'B-LOC')
# (u'Suu', u'I-PER', u'B-PER')
# (u'Kyi', u'I-PER', u'B-PER')
# (u'Dalla', u'B-LOC', u'B-PER')
# (u'Aung', u'B-PER', u'B-LOC')
# (u'San', u'I-PER', u'B-LOC')
# (u'Daw', u'B-PER', u'I-MISC')
# (u'Suu', u'I-PER', u'B-PER')
# (u'Kyi', u'I-PER', u'B-PER')
# (u'Dalla', u'B-LOC', u'B-PER')
# (u'Birma', u'B-LOC', u'B-MISC')
# (u'Aung', u'B-PER', u'B-LOC')
# (u'San', u'I-PER', u'B-LOC')
# (u'Aung', u'B-PER', u'B-LOC')
# (u'San', u'I-PER', u'B-LOC')
# (u'Laos', u'B-LOC', u'B-MISC')
# (u'Daw', u'B-PER', u'I-MISC')
# (u'Suu', u'I-PER', u'B-PER')
# (u'Kyi', u'I-PER', u'B-PER')
# (u'Sarpachaun-buurt', u'B-LOC', u'B-MISC')
# (u'Brit', u'B-MISC', u'I-PER')
# (u'Aris', u'I-PER', u'B-ORG')
# (u'Birma', u'B-LOC', u'B-MISC')
# (u'Democratie', u'I-ORG', u'B-ORG')
# (u'Liga', u'I-ORG', u'B-PER')
# (u'Aung', u'B-PER', u'B-LOC')
# (u'San', u'I-PER', u'B-LOC')
# (u'Nasa', u'B-ORG', u'B-LOC')
# (u'van', u'I-MISC', u'O')
# (u'Veneti\xeb', u'I-MISC', u'B-LOC')
# (u'Space', u'B-MISC', u'I-MISC')
# (u'Cowboys', u'I-MISC', u'B-ORG')
# (u'Eastwood', u'I-PER', u'B-LOC')
# (u'Sharon', u'B-PER', u'I-PER')
# (u'Stone', u'I-PER', u'B-PER')
# (u'Gouden', u'B-MISC', u'I-PER')
# (u'Leeuw', u'I-MISC', u'I-PER')
# (u'Grazie', u'O', u'B-PER')
# (u'for', u'O', u'I-ORG')
# (u'Leone', u'B-LOC', u'I-MISC')
# (u'Eastwood', u'I-PER', u'B-LOC')
# (u'Leone', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Space', u'B-MISC', u'I-MISC')
# (u'Cowboys', u'I-MISC', u'B-ORG')
# (u'Koersk', u'B-MISC', u'I-PER')
# (u'Nasa', u'B-ORG', u'B-LOC')
# (u'Space', u'B-LOC', u'I-MISC')
# (u'Houston', u'B-PER', u'I-PER')
# (u'Filmfestival', u'B-MISC', u'B-PER')
# (u'van', u'I-MISC', u'O')
# (u'Veneti\xeb', u'I-MISC', u'B-LOC')
# (u'Clint', u'B-MISC', u'B-PER')
# (u'Eastwoods', u'I-MISC', u'B-LOC')
# (u'Space', u'B-MISC', u'I-MISC')
# (u'Cowboys', u'I-MISC', u'B-ORG')
# (u'Argwaan', u'O', u'B-MISC')
# (u'Cowboys', u'I-MISC', u'B-ORG')
# (u'T.', u'I-PER', u'B-PER')
# (u'Team', u'B-ORG', u'I-PER')
# (u'Daedalus', u'I-ORG', u'I-MISC')
# (u'The', u'B-MISC', u'B-ORG')
# (u'China', u'I-MISC', u'B-LOC')
# (u'Syndrome', u'I-MISC', u'B-ORG')
# (u'Three', u'B-LOC', u'B-PER')
# (u'Mile', u'I-LOC', u'B-LOC')
# (u'Harrisburg', u'B-LOC', u'I-LOC')
# (u'Ostankino-toren', u'B-LOC', u'B-MISC')
# (u'Nasa', u'B-ORG', u'B-LOC')
# (u'Ikon', u'B-MISC', u'B-LOC')
# (u'Nasa', u'B-ORG', u'B-LOC')
# (u'Space', u'B-MISC', u'I-MISC')
# (u'Cowboys', u'I-MISC', u'B-ORG')
# (u'Eastwood', u'I-PER', u'B-LOC')
# (u'57ste', u'B-MISC', u'O')
# (u'Filmfestival', u'I-MISC', u'B-PER')
# (u'van', u'I-MISC', u'O')
# (u'Veneti\xeb', u'I-MISC', u'B-LOC')
# (u'Corvin', u'I-PER', u'B-PER')
# (u'Eastwood', u'I-PER', u'B-LOC')
# (u'Ikon', u'B-MISC', u'B-LOC')
# (u'Skylab-satelliet', u'B-MISC', u'I-MISC')
# (u'Cowboys', u'I-MISC', u'B-ORG')
# (u'Eastwood', u'B-PER', u'B-LOC')
# (u'Lee', u'I-PER', u'B-PER')
# (u'Sutherland', u'I-PER', u'B-PER')
# (u'Vandewalle', u'B-PER', u'I-PER')
# (u'ING', u'B-ORG', u'B-MISC')
# (u'Luxemburg', u'B-LOC', u'I-LOC')
# (u'Vandewalle', u'B-PER', u'O')
# (u'Mensen', u'B-MISC', u'O')
# (u'Werk', u'O', u'B-MISC')
# (u'Vandewalle', u'B-PER', u'O')
# (u'ING', u'B-ORG', u'B-MISC')
# (u'ING', u'B-ORG', u'B-MISC')
# (u'ING-groep', u'B-ORG', u'B-MISC')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Nederlanden', u'I-ORG', u'I-LOC')
# (u'Postbank', u'B-ORG', u'O')
# (u'Vandewalle', u'B-PER', u'I-PER')
# (u'Tilmant', u'I-PER', u'I-ORG')
# (u'ING', u'B-ORG', u'B-MISC')
# (u'El-Guerrouj', u'B-PER', u'B-LOC')
# (u'Solberg-Hattestad', u'B-PER', u'B-ORG')
# (u'Leenaerts', u'I-PER', u'B-PER')
# (u'Van', u'I-MISC', u'I-PER')
# (u'Damme', u'I-MISC', u'I-PER')
# (u'Hicham', u'B-PER', u'I-PER')
# (u'El-Guerrouj', u'I-PER', u'B-LOC')
# (u'Solberg-Hattestad', u'I-PER', u'B-ORG')
# (u'Tatiana', u'B-PER', u'B-LOC')
# (u'Kotova', u'I-PER', u'B-PER')
# (u'Golden', u'B-MISC', u'I-PER')
# (u'League-meeting', u'I-MISC', u'B-MISC')
# (u'Golden', u'B-MISC', u'I-PER')
# (u'Golden', u'B-MISC', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Golden', u'B-MISC', u'I-PER')
# (u'League-meeting', u'I-MISC', u'B-MISC')
# (u'Gail', u'B-PER', u'I-MISC')
# (u'Van', u'I-MISC', u'I-PER')
# (u'Damme', u'I-MISC', u'I-PER')
# (u'Oslo', u'B-LOC', u'B-PER')
# (u'Monte', u'B-LOC', u'B-PER')
# (u'Carlo', u'I-LOC', u'B-PER')
# (u'Golden', u'B-MISC', u'I-PER')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'Atletiek', u'O', u'B-LOC')
# (u'Johnson', u'I-PER', u'B-PER')
# (u'PG', u'B-PER', u'B-ORG')
# (u'Goris', u'I-PER', u'B-ORG')
# (u'Milieu-inspectie', u'B-ORG', u'B-MISC')
# (u'Milieu-inspectie', u'B-ORG', u'B-MISC')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Milieuhandhavingsrapport', u'B-MISC', u'I-ORG')
# (u'Milieu-inspectie', u'B-ORG', u'B-MISC')
# (u'Coca', u'B-MISC', u'B-ORG')
# (u'Cola-crisis', u'I-MISC', u'B-MISC')
# (u'Coca', u'B-MISC', u'B-ORG')
# (u'Cola-incident', u'I-MISC', u'B-LOC')
# (u'Milieu-inspectie', u'B-ORG', u'B-MISC')
# (u'PCB', u'B-MISC', u'B-ORG')
# (u'Milieu-inspectie', u'B-ORG', u'B-MISC')
# (u'Het', u'B-MISC', u'O')
# (u'Ca\xefro', u'B-LOC', u'B-PER')
# (u'Arafat', u'B-PER', u'B-MISC')
# (u'Isra\xebl', u'B-LOC', u'I-PER')
# (u'Jeruzalem', u'B-LOC', u'B-PER')
# (u'Ehud', u'B-PER', u'I-PER')
# (u'Olmert', u'I-PER', u'B-PER')
# (u'Jeruzalem', u'B-LOC', u'B-PER')
# (u'Isra\xebl', u'B-LOC', u'I-PER')
# (u'Palestijnen', u'B-MISC', u'I-LOC')
# (u'Jeruzalem', u'B-LOC', u'B-PER')
# (u'Jeruzalem', u'B-LOC', u'B-PER')
# (u'Likoed', u'B-ORG', u'B-LOC')
# (u'Arafat', u'I-PER', u'B-MISC')
# (u'Ehud', u'B-PER', u'I-PER')
# (u'Barak', u'I-PER', u'B-PER')
# (u'Isra\xebl', u'B-LOC', u'I-PER')
# (u'Palestijnen', u'B-MISC', u'I-LOC')
# (u'Jeruzalem', u'B-LOC', u'B-PER')
# (u'Palestijnen', u'B-MISC', u'I-LOC')
# (u'Isra\xebl', u'B-LOC', u'I-PER')
# (u'Likoed-partij', u'B-ORG', u'B-LOC')
# (u'Isra\xebl', u'B-LOC', u'I-PER')
# (u'Palestijnen', u'B-MISC', u'I-LOC')
# (u'Palestijnse', u'B-ORG', u'B-MISC')
# (u'Bevrijdingsbeweging', u'I-ORG', u'I-MISC')
# (u'PLO', u'B-ORG', u'I-MISC')
# (u'Isra\xebl', u'B-LOC', u'B-PER')
# (u'Saath', u'I-PER', u'B-PER')
# (u'Verenigde', u'B-ORG', u'B-LOC')
# (u'Palestijnen', u'B-MISC', u'I-LOC')
# (u'Isra\xebl', u'B-LOC', u'I-PER')
# (u'Jeruzalem', u'B-LOC', u'B-PER')
# (u'Amr', u'B-PER', u'B-LOC')
# (u'Moussa', u'I-PER', u'B-ORG')
# (u'Clinton', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Jakarta', u'B-LOC', u'B-PER')
# (u'Habibie', u'B-PER', u'I-LOC')
# (u'Soeharto', u'B-PER', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Soeharto', u'B-PER', u'B-ORG')
# (u'Orde', u'I-MISC', u'B-LOC')
# (u"Soeharto's", u'B-MISC', u'B-ORG')
# (u'Soeharto', u'B-PER', u'B-ORG')
# (u'Hang', u'O', u'B-PER')
# (u'Soeharto', u'B-PER', u'B-ORG')
# (u'Bus', u'O', u'I-PER')
# (u'Maariv', u'B-ORG', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Franse', u'B-ORG', u'B-MISC')
# (u'Dienst', u'I-ORG', u'B-ORG')
# (u'voor', u'I-ORG', u'O')
# (u'de', u'I-ORG', u'O')
# (u'van', u'I-ORG', u'O')
# (u'Luchtvaartongevallen', u'I-ORG', u'B-PER')
# (u'BEA', u'B-ORG', u'B-PER')
# (u'Concorde', u'B-MISC', u'B-LOC')
# (u'Concorde', u'B-MISC', u'B-LOC')
# (u'Chabert', u'I-PER', u'B-PER')
# (u'Beersheba', u'B-LOC', u'B-PER')
# (u'Kanaaltunnel', u'B-LOC', u'B-ORG')
# (u'Zeebrugge', u'B-LOC', u'I-PER')
# (u'Kanaaltunnel', u'B-LOC', u'B-ORG')
# (u'Cherbourg', u'B-LOC', u'I-PER')
# (u'Duinkerke', u'B-LOC', u'I-MISC')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Kanaaltunnel', u'B-LOC', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Glavany', u'I-PER', u'I-ORG')
# (u'Ochtends', u'O', u'B-MISC')
# (u'Kanaaltunnel', u'B-LOC', u'B-ORG')
# (u'P', u'B-ORG', u'O')
# (u'&', u'I-ORG', u'O')
# (u'O-Stena', u'I-ORG', u'B-MISC')
# (u'Line', u'I-ORG', u'B-PER')
# (u'Galvany', u'I-PER', u'I-LOC')
# (u'Galvany', u'B-PER', u'I-LOC')
# (u'Fauchet', u'I-PER', u'B-PER')
# (u'Fonsnylaan', u'B-LOC', u'B-MISC')
# (u'Kuringen', u'B-LOC', u'O')
# (u'Halle-Ath', u'B-MISC', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Bouding', u'B-PER', u'O')
# (u'Schouppe', u'I-PER', u'B-PER')
# (u'Criminaliteit', u'O', u'I-PER')
# (u'Claus', u'I-PER', u'B-PER')
# (u'Denise', u'B-PER', u'B-LOC')
# (u'den', u'I-PER', u'O')
# (u'De', u'B-ORG', u'I-PER')
# (u'De', u'B-ORG', u'I-PER')
# (u'Nieuwe', u'I-ORG', u'B-MISC')
# (u'Gazet', u'I-ORG', u'I-PER')
# (u'Bertels', u'B-PER', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'De', u'B-ORG', u'I-PER')
# (u'Zondag', u'B-ORG', u'O')
# (u'Regionale', u'B-ORG', u'O')
# (u'Uitgeversgroep', u'I-ORG', u'O')
# (u'De', u'B-ORG', u'O')
# (u'De', u'B-MISC', u'I-PER')
# (u'Persgroep-dochter', u'I-MISC', u'B-MISC')
# (u'Hoste', u'I-ORG', u'I-PER')
# (u'Zondag', u'B-ORG', u'O')
# (u'Bertels', u'B-PER', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Antwerps', u'B-MISC', u'O')
# (u'Het', u'B-ORG', u'B-MISC')
# (u'Laatste', u'I-ORG', u'I-MISC')
# (u'Nieuws', u'I-ORG', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Partijen', u'O', u'I-PER')
# (u'Jef', u'B-PER', u'I-MISC')
# (u'Geysels', u'B-PER', u'I-PER')
# (u'Goossens', u'B-PER', u'I-PER')
# (u'Grote', u'O', u'B-MISC')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'Interzonaal', u'O', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'der', u'I-PER', u'O')
# (u'Vlist', u'I-PER', u'B-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Van', u'B-PER', u'I-PER')
# (u'Vlist', u'I-PER', u'B-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'pan-Europese', u'B-MISC', u'O')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Van', u'B-PER', u'I-PER')
# (u'der', u'I-PER', u'O')
# (u'Vlist', u'I-PER', u'B-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'der', u'I-PER', u'O')
# (u'Vlist', u'I-PER', u'B-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Eurosport', u'B-ORG', u'I-MISC')
# (u'Fraenen', u'I-PER', u'B-MISC')
# (u'Iveka', u'B-ORG', u'B-PER')
# (u'en', u'I-ORG', u'O')
# (u'Telekempo', u'I-ORG', u'B-ORG')
# (u'De', u'B-MISC', u'O')
# (u'Volders', u'I-MISC', u'I-ORG')
# (u'Toneelgroep', u'B-ORG', u'I-ORG')
# (u'Ceremonia', u'I-ORG', u'B-LOC')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Diep', u'B-MISC', u'O')
# (u'in', u'I-MISC', u'O')
# (u'het', u'I-MISC', u'O')
# (u'bos', u'I-MISC', u'O')
# (u'Stemmen', u'O', u'I-MISC')
# (u'Theaterfestival', u'B-MISC', u'O')
# (u'Thersitesprijs', u'B-MISC', u'O')
# (u'ter', u'I-ORG', u'O')
# (u'Bevordering', u'I-ORG', u'I-MISC')
# (u'van', u'I-ORG', u'O')
# (u'de', u'I-ORG', u'I-PER')
# (u'Theaterkritiek', u'I-ORG', u'O')
# (u'Ceremonia', u'B-ORG', u'B-LOC')
# (u'Ceremonia', u'B-ORG', u'B-LOC')
# (u'Kakkerlakken', u'B-MISC', u'B-LOC')
# (u'PA', u'B-PER', u'O')
# (u'deSingel', u'B-LOC', u'I-PER')
# (u'Regent', u'B-MISC', u'O')
# (u'en', u'I-MISC', u'O')
# (u'regentes', u'I-MISC', u'O')
# (u'Diep', u'B-MISC', u'O')
# (u'in', u'I-MISC', u'O')
# (u'het', u'I-MISC', u'O')
# (u'bos', u'I-MISC', u'O')
# (u'Het', u'B-ORG', u'O')
# (u'muziek', u'I-ORG', u'O')
# (u'Harst', u'I-PER', u'B-LOC')
# (u'Diep', u'B-MISC', u'O')
# (u'in', u'I-MISC', u'O')
# (u'het', u'I-MISC', u'O')
# (u'bos', u'I-MISC', u'O')
# (u'Het', u'B-ORG', u'O')
# (u'muziek', u'I-ORG', u'O')
# (u'Ceremonia', u'B-ORG', u'B-LOC')
# (u'Regent', u'B-MISC', u'O')
# (u'en', u'I-MISC', u'O')
# (u'regentes', u'I-MISC', u'O')
# (u'Toneelgroep', u'B-ORG', u'I-ORG')
# (u'Ceremonia', u'I-ORG', u'B-LOC')
# (u'Lod', u'B-ORG', u'I-ORG')
# (u'Gentenaar', u'B-MISC', u'I-MISC')
# (u'Ceremonia', u'B-ORG', u'B-LOC')
# (u'Critici', u'O', u'B-MISC')
# (u'De', u'I-PER', u'O')
# (u'De', u'B-PER', u'O')
# (u'De', u'I-PER', u'O')
# (u'Kakkerlakken', u'B-MISC', u'O')
# (u'Vadria', u'B-MISC', u'I-MISC')
# (u'De', u'B-PER', u'O')
# (u'Van', u'B-PER', u'I-PER')
# (u'Harst', u'I-PER', u'B-LOC')
# (u'Victoria', u'B-LOC', u'I-LOC')
# (u'Ceremonia', u'B-ORG', u'B-LOC')
# (u'PA', u'B-PER', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Thersitesprijs', u'B-MISC', u'O')
# (u'Theaterfestival', u'B-MISC', u'O')
# (u'De', u'B-PER', u'O')
# (u'Diep', u'B-MISC', u'O')
# (u'in', u'I-MISC', u'O')
# (u'het', u'I-MISC', u'O')
# (u'bos', u'I-MISC', u'O')
# (u'deSingel', u'B-LOC', u'I-PER')
# (u'De', u'B-PER', u'I-PER')
# (u'TSO', u'B-MISC', u'B-PER')
# (u'Oh', u'O', u'I-MISC')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Begrijp', u'O', u'B-LOC')
# (u'Vanderpoorten', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'2000', u'O', u'I-MISC')
# (u'Tijdens', u'O', u'I-PER')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Interuniversitaire', u'I-ORG', u'O')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'Bisschop', u'I-PER', u'I-MISC')
# (u'De', u'B-ORG', u'I-PER')
# (u'Belegger', u'I-ORG', u'I-PER')
# (u'Paepen', u'I-PER', u'B-LOC')
# (u'Actueel', u'B-ORG', u'B-MISC')
# (u'De', u'B-ORG', u'I-PER')
# (u'Wandelgangen', u'I-ORG', u'B-MISC')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'Bouveroux', u'I-PER', u'I-LOC')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'1', u'I-ORG', u'O')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'2000', u'O', u'I-MISC')
# (u'Leemans', u'I-PER', u'B-PER')
# (u'Gelijke', u'B-ORG', u'I-MISC')
# (u'Kansen', u'I-ORG', u'I-PER')
# (u'de', u'I-PER', u'O')
# (u'Wilde', u'I-PER', u'O')
# (u'De', u'B-LOC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Cleuvenbergen', u'I-PER', u'B-PER')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'2000', u'O', u'I-MISC')
# (u'2000', u'O', u'I-MISC')
# (u'Grouwels', u'B-PER', u'I-PER')
# (u'Zeven', u'O', u'I-MISC')
# (u'2000', u'O', u'I-MISC')
# (u'2000', u'O', u'I-MISC')
# (u'Moskovskii', u'B-ORG', u'B-PER')
# (u'Novosti', u'I-ORG', u'B-PER')
# (u'Michail', u'B-PER', u'I-MISC')
# (u'Gorbatsjov', u'I-PER', u'B-PER')
# (u'Komsomolskaja', u'B-ORG', u'B-PER')
# (u'Pravda', u'I-ORG', u'B-ORG')
# (u'Koersk', u'B-MISC', u'I-PER')
# (u'Ostankino-toren', u'B-LOC', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Ostankino', u'B-LOC', u'I-PER')
# (u'Ostankino', u'B-LOC', u'I-PER')
# (u'Cine', u'B-MISC', u'I-LOC')
# (u'Soiree', u'I-MISC', u'I-ORG')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'Hautekiet', u'I-PER', u'O')
# (u'Workshops', u'O', u'I-ORG')
# (u'De', u'B-LOC', u'I-PER')
# (u'Cinema', u'I-LOC', u'B-ORG')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'Barman', u'B-PER', u'I-PER')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'De', u'B-LOC', u'I-PER')
# (u'Cinema', u'I-LOC', u'B-ORG')
# (u'dEUS', u'B-ORG', u'I-LOC')
# (u'Dewaele', u'I-ORG', u'I-PER')
# (u'Beckenbauer', u'I-PER', u'B-PER')
# (u'Woody', u'B-PER', u'O')
# (u'De', u'B-ORG', u'I-PER')
# (u'Cole', u'B-PER', u'B-LOC')
# (u'Porter', u'I-PER', u'B-LOC')
# (u'Van', u'O', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Robbie', u'B-PER', u'B-MISC')
# (u'Strombeek', u'B-LOC', u'O')
# (u'Cercle', u'B-ORG', u'O')
# (u'Brugge', u'I-ORG', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Heusden', u'B-LOC', u'I-PER')
# (u'Luik', u'I-ORG', u'B-LOC')
# (u'Tienen', u'B-LOC', u'O')
# (u'Hekelgem', u'B-LOC', u'I-LOC')
# (u'Molenbeek', u'B-LOC', u'B-PER')
# (u'Dessel', u'B-ORG', u'I-PER')
# (u'Tienen', u'B-LOC', u'O')
# (u'Deinze', u'B-LOC', u'O')
# (u'Dessel', u'B-ORG', u'O')
# (u'Maasland2', u'B-ORG', u'O')
# (u'Luik', u'I-ORG', u'B-LOC')
# (u'Bergen', u'B-LOC', u'O')
# (u'Lommel', u'B-LOC', u'B-PER')
# (u'Bergen', u'B-LOC', u'O')
# (u'Heusden', u'B-LOC', u'I-PER')
# (u'Molenbeek', u'B-LOC', u'B-PER')
# (u'Maasland', u'B-LOC', u'B-PER')
# (u'Ingelmunster', u'B-LOC', u'O')
# (u'Deinze', u'B-LOC', u'I-PER')
# (u'Cercle', u'B-ORG', u'O')
# (u'Brugge', u'I-ORG', u'B-LOC')
# (u'Lommel', u'B-LOC', u'B-PER')
# (u'Strombeek', u'B-LOC', u'O')
# (u'Maasland', u'B-LOC', u'B-PER')
# (u'Ingelmunster', u'B-LOC', u'O')
# (u'Leuven', u'B-LOC', u'O')
# (u'SS', u'B-PER', u'B-ORG')
# (u'V.', u'I-PER', u'B-PER')
# (u'V.', u'I-PER', u'B-PER')
# (u'Het', u'B-MISC', u'O')
# (u'Jacobs', u'I-PER', u'B-PER')
# (u'V.', u'I-PER', u'B-PER')
# (u'Eindhoven', u'B-LOC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'V.', u'I-PER', u'B-PER')
# (u'Somers', u'I-PER', u'I-ORG')
# (u'Internationaal', u'B-ORG', u'O')
# (u'Olympisch', u'I-ORG', u'O')
# (u'Comit\xe9', u'I-ORG', u'B-ORG')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Bloedtests', u'O', u'B-MISC')
# (u'Grieks', u'B-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Athene', u'B-LOC', u'B-PER')
# (u'Eigen', u'I-PER', u'O')
# (u'Ambtenaren', u'O', u'I-MISC')
# (u'Nicaragua', u'B-LOC', u'B-PER')
# (u'Nigeria', u'B-LOC', u'B-PER')
# (u'Transparency', u'B-ORG', u'B-MISC')
# (u'International', u'I-ORG', u'B-ORG')
# (u'TI', u'B-ORG', u'O')
# (u'van', u'I-MISC', u'O')
# (u'Corruptie', u'I-MISC', u'I-ORG')
# (u'Perceptie', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Transparency', u'B-ORG', u'B-MISC')
# (u'TI', u'B-ORG', u'O')
# (u'voor', u'I-ORG', u'O')
# (u'reproductieve', u'I-ORG', u'O')
# (u'geneeskunde', u'I-ORG', u'O')
# (u'VUB', u'B-ORG', u'B-MISC')
# (u'Journal', u'B-ORG', u'I-ORG')
# (u'of', u'I-ORG', u'O')
# (u'Human', u'I-ORG', u'B-ORG')
# (u'Reproduction', u'I-ORG', u'I-LOC')
# (u'KID', u'B-MISC', u'I-ORG')
# (u'KID', u'B-MISC', u'I-ORG')
# (u'Het', u'B-MISC', u'O')
# (u'Journal', u'B-ORG', u'I-ORG')
# (u'of', u'I-ORG', u'O')
# (u'Human', u'I-ORG', u'B-ORG')
# (u'Reproduction', u'I-ORG', u'I-LOC')
# (u'De', u'B-ORG', u'O')
# (u'derden', u'O', u'I-PER')
# (u'derden', u'O', u'I-PER')
# (u'KID', u'B-MISC', u'I-ORG')
# (u'KID', u'B-MISC', u'I-ORG')
# (u'Surrey', u'B-LOC', u'B-PER')
# (u'KID', u'B-MISC', u'I-ORG')
# (u'KID', u'B-MISC', u'I-ORG')
# (u'VUB', u'B-ORG', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Mercury', u'I-PER', u'B-PER')
# (u'Salvador', u'B-LOC', u'B-PER')
# (u'Bahia', u'B-LOC', u'I-PER')
# (u'Sol', u'B-MISC', u'I-MISC')
# (u'da', u'I-MISC', u'I-PER')
# (u'liberdade', u'I-MISC', u'O')
# (u'Camping', u'B-MISC', u'O')
# (u'Casablanca', u'I-MISC', u'B-LOC')
# (u'1', u'I-ORG', u'O')
# (u'Centrum', u'B-LOC', u'B-ORG')
# (u'van', u'I-LOC', u'O')
# (u'Brussel', u'I-LOC', u'B-LOC')
# (u'2000', u'I-LOC', u'I-MISC')
# (u'Schrijvers', u'B-MISC', u'I-PER')
# (u'in', u'I-MISC', u'O')
# (u'steden', u'I-MISC', u'O')
# (u'Doyle', u'I-PER', u'B-LOC')
# (u'De', u'B-MISC', u'I-PER')
# (u'Quiz', u'I-MISC', u'I-PER')
# (u'van', u'I-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'Eeuw', u'I-MISC', u'B-LOC')
# (u'World', u'B-MISC', u'B-ORG')
# (u'Music', u'I-MISC', u'I-LOC')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Commitments', u'I-MISC', u'I-PER')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Snapper', u'I-MISC', u'I-PER')
# (u'The', u'B-MISC', u'B-ORG')
# (u'Van', u'I-MISC', u'I-PER')
# (u"L'amour", u'B-MISC', u'B-ORG')
# (u'de', u'I-MISC', u'O')
# (u'loin', u'I-MISC', u'O')
# (u'Kaija', u'B-PER', u'B-LOC')
# (u'Saariaho', u'I-PER', u'B-PER')
# (u'Amin', u'B-PER', u'I-PER')
# (u'Maalouf', u'I-PER', u'B-PER')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'1', u'I-ORG', u'O')
# (u'de', u'I-MISC', u'O')
# (u'Flandre', u'I-MISC', u'B-PER')
# (u'Markante', u'B-MISC', u'B-PER')
# (u'Vrouwenroute', u'I-MISC', u'B-MISC')
# (u'1', u'I-ORG', u'O')
# (u'De', u'B-MISC', u'O')
# (u'Kunstberg', u'I-MISC', u'B-LOC')
# (u'3', u'I-ORG', u'O')
# (u'De', u'B-MISC', u'O')
# (u'Zomerzuidkant', u'I-MISC', u'O')
# (u'1', u'I-ORG', u'O')
# (u'Voor', u'B-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'dag', u'I-MISC', u'O')
# (u'1', u'I-ORG', u'O')
# (u'Camping', u'B-MISC', u'O')
# (u'Casablanca', u'I-MISC', u'B-LOC')
# (u'Scofield', u'I-PER', u'B-PER')
# (u'Wallonie-Bruxelles', u'I-LOC', u'B-MISC')
# (u'Les', u'B-MISC', u'B-LOC')
# (u'premiers', u'I-MISC', u'O')
# (u'et', u'I-MISC', u'O')
# (u'les', u'I-MISC', u'O')
# (u'derniers', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Adriano', u'I-PER', u'B-PER')
# (u'Afrikaan', u'B-MISC', u'B-LOC')
# (u'Niger', u'B-LOC', u'I-PER')
# (u'WADA', u'B-ORG', u'B-MISC')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'2000', u'O', u'I-MISC')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Australisch', u'B-ORG', u'B-MISC')
# (u'Olympisch', u'I-ORG', u'O')
# (u'Comit\xe9', u'I-ORG', u'B-ORG')
# (u'Cairns', u'B-LOC', u'I-PER')
# (u'Collinelli', u'I-PER', u'B-ORG')
# (u'WADA', u'B-ORG', u'B-MISC')
# (u'Pound', u'I-PER', u'B-LOC')
# (u'Robbie', u'B-PER', u'B-MISC')
# (u'Eros-stichting', u'B-ORG', u'B-MISC')
# (u'Collinelli', u'B-PER', u'B-ORG')
# (u'Seksindustrie', u'O', u'B-PER')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Internationaal', u'B-ORG', u'O')
# (u'Olympisch', u'I-ORG', u'O')
# (u'Comit\xe9', u'I-ORG', u'B-ORG')
# (u'King', u'B-PER', u'O')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'WADA', u'B-ORG', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Spelen', u'B-MISC', u'I-MISC')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'Gianlucca', u'B-PER', u'O')
# (u'Pozzi', u'I-PER', u'B-PER')
# (u'Ruud', u'I-PER', u'B-PER')
# (u'Sjeng', u'B-PER', u'B-LOC')
# (u'Schalken', u'I-PER', u'B-PER')
# (u'Lars', u'B-PER', u'B-ORG')
# (u'Safin', u'I-PER', u'B-PER')
# (u'Guardiola', u'I-PER', u'B-PER')
# (u'Stefan', u'B-PER', u'I-PER')
# (u'Koubek', u'I-PER', u'B-PER')
# (u'Ignacio', u'I-PER', u'B-PER')
# (u'Norman', u'I-PER', u'B-PER')
# (u'Goldstein', u'I-PER', u'B-PER')
# (u'Pioline', u'I-PER', u'B-PER')
# (u'Sargis', u'B-PER', u'I-PER')
# (u'Sargsian', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'US', u'B-MISC', u'B-ORG')
# (u'Open', u'I-MISC', u'O')
# (u'Greg', u'B-PER', u'B-LOC')
# (u'Rusedski', u'I-PER', u'B-LOC')
# (u'Gustafsson', u'I-PER', u'B-PER')
# (u'Grosjean', u'I-PER', u'B-PER')
# (u'Kim', u'I-PER', u'B-PER')
# (u'Boogert', u'I-PER', u'B-PER')
# (u'Sugiyama', u'I-PER', u'B-PER')
# (u'Allison', u'B-PER', u'I-PER')
# (u'Irvin', u'I-PER', u'B-MISC')
# (u'Magui', u'B-PER', u'I-PER')
# (u'Serna', u'I-PER', u'B-PER')
# (u'Grande', u'I-PER', u'I-MISC')
# (u'Gersi', u'I-PER', u'B-PER')
# (u'Shaughnessy', u'I-PER', u'B-PER')
# (u'Nola', u'I-PER', u'B-PER')
# (u'Arantxa', u'B-PER', u'B-MISC')
# (u'Sanchez', u'I-PER', u'B-PER')
# (u'Sonya', u'B-PER', u'B-ORG')
# (u'Jeyaseelan', u'I-PER', u'B-PER')
# (u'Jennifer', u'B-PER', u'I-PER')
# (u'Capriati', u'I-PER', u'B-PER')
# (u'Nagyova', u'I-PER', u'B-PER')
# (u'Tauziat', u'I-PER', u'B-LOC')
# (u'Alejandra', u'I-PER', u'B-PER')
# (u'Vento', u'I-PER', u'B-PER')
# (u'Amanda', u'B-PER', u'B-LOC')
# (u'Coetzer', u'I-PER', u'B-PER')
# (u'Kandarr', u'I-PER', u'B-PER')
# (u'Lee', u'I-PER', u'B-PER')
# (u'Tai', u'O', u'B-PER')
# (u'Dawn', u'B-PER', u'I-MISC')
# (u'Tatiana', u'B-PER', u'B-LOC')
# (u'Kostanic', u'I-PER', u'B-PER')
# (u'Hingis', u'I-PER', u'B-PER')
# (u'Brandi', u'I-PER', u'B-PER')
# (u'Mary', u'B-PER', u'B-MISC')
# (u'Pierce', u'I-PER', u'B-PER')
# (u'Magdalena', u'B-PER', u'I-PER')
# (u'Maleeva', u'I-PER', u'B-PER')
# (u'Asagoe', u'I-PER', u'B-LOC')
# (u'Schnyder', u'I-PER', u'B-PER')
# (u'Elena', u'B-PER', u'B-ORG')
# (u'Dementieva', u'I-PER', u'B-PER')
# (u'Sylvia', u'B-PER', u'B-ORG')
# (u'Plischke', u'I-PER', u'B-PER')
# (u'Davenport', u'I-PER', u'B-PER')
# (u'Van', u'B-PER', u'I-PER')
# (u'Lisa', u'B-PER', u'I-MISC')
# (u'Raymond', u'I-PER', u'B-PER')
# (u'Dragomir', u'I-PER', u'B-PER')
# (u'Conchita', u'B-PER', u'B-ORG')
# (u'Martinez', u'I-PER', u'B-PER')
# (u'Antonia', u'I-PER', u'B-LOC')
# (u'Sanchez', u'I-PER', u'B-PER')
# (u'Lorenzo', u'I-PER', u'B-PER')
# (u'Prinosil', u'I-PER', u'B-PER')
# (u'Fromberg', u'I-PER', u'B-LOC')
# (u'Bastl', u'I-PER', u'B-PER')
# (u'Voinea', u'I-PER', u'B-MISC')
# (u'Hipfl', u'I-PER', u'B-PER')
# (u'Moya', u'I-PER', u'B-PER')
# (u'Tillstrom', u'I-PER', u'B-PER')
# (u'Slava', u'B-PER', u'B-ORG')
# (u'Dosedel', u'I-PER', u'B-PER')
# (u'Francisco', u'B-PER', u'I-LOC')
# (u'Clavet', u'I-PER', u'B-PER')
# (u'Safin', u'I-PER', u'B-PER')
# (u'Guardiola', u'I-PER', u'B-PER')
# (u'Attila', u'B-PER', u'B-ORG')
# (u'Savolt', u'I-PER', u'B-PER')
# (u'Gambill', u'I-PER', u'B-PER')
# (u'Mardy', u'B-PER', u'I-PER')
# (u'Fish', u'I-PER', u'I-MISC')
# (u'Agustin', u'B-PER', u'I-PER')
# (u'Calleri', u'I-PER', u'B-PER')
# (u'Kralert', u'I-PER', u'B-PER')
# (u'Henman', u'I-PER', u'B-PER')
# (u'Hewitt', u'I-PER', u'B-PER')
# (u'Boutter', u'I-PER', u'B-LOC')
# (u'Novak', u'I-PER', u'B-PER')
# (u'Bryon', u'B-PER', u'I-PER')
# (u'Black', u'I-PER', u'B-PER')
# (u'Vanderhaeghe', u'B-PER', u'I-PER')
# (u'Vanderhaeghe', u'B-PER', u'I-PER')
# (u'Vanderhaeghe', u'B-PER', u'I-PER')
# (u'Vanderhaeghe', u'B-PER', u'I-PER')
# (u'Moeskroen', u'B-LOC', u'O')
# (u'Rode', u'B-ORG', u'B-MISC')
# (u'Boksic', u'B-PER', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Vanderhaeghe', u'B-PER', u'I-PER')
# (u'Vanderhaeghe', u'B-PER', u'O')
# (u'Vanderhaeghe', u'B-PER', u'I-PER')
# (u'2002', u'I-MISC', u'O')
# (u'der', u'I-PER', u'O')
# (u'Elst', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Deville', u'B-PER', u'I-PER')
# (u'Geur', u'O', u'B-LOC')
# (u'Just', u'B-MISC', u'I-LOC')
# (u'around', u'I-MISC', u'O')
# (u'corner', u'I-MISC', u'O')
# (u'Foresight', u'B-ORG', u'B-MISC')
# (u'Handel', u'B-ORG', u'I-ORG')
# (u'en', u'I-ORG', u'O')
# (u'Industrie', u'I-ORG', u'B-MISC')
# (u'Deville', u'B-PER', u'I-PER')
# (u'Criminelen', u'O', u'I-PER')
# (u'Foresight', u'B-ORG', u'B-MISC')
# (u'Herritarrok', u'I-ORG', u'B-LOC')
# (u'Herri', u'B-ORG', u'I-PER')
# (u'Batasuna', u'I-ORG', u'B-MISC')
# (u'Herri', u'B-ORG', u'I-PER')
# (u'Batasuna', u'I-ORG', u'B-MISC')
# (u'Aznar', u'B-PER', u'B-LOC')
# (u'ETA-doelwit', u'B-MISC', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'etarras', u'B-MISC', u'O')
# (u'Javier', u'B-PER', u'I-PER')
# (u'Pom\xe9s', u'I-PER', u'B-MISC')
# (u'Pamplona', u'B-LOC', u'B-MISC')
# (u'Pom\xe9s', u'B-PER', u'B-MISC')
# (u'Javier', u'B-PER', u'I-PER')
# (u'Pom\xe9s', u'I-PER', u'B-MISC')
# (u'Baskischtalige', u'B-MISC', u'I-PER')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Javier', u'B-PER', u'I-PER')
# (u'Pom\xe9s', u'I-PER', u'B-MISC')
# (u'Navarrese', u'B-ORG', u'I-PER')
# (u'Volksunie', u'I-ORG', u'B-MISC')
# (u'Partido', u'B-ORG', u'I-LOC')
# (u'Popular', u'I-ORG', u'I-MISC')
# (u'Mar\xeda', u'I-PER', u'B-LOC')
# (u'Aznar', u'I-PER', u'B-LOC')
# (u'Pamplona', u'B-LOC', u'B-MISC')
# (u"Risico's", u'O', u'B-MISC')
# (u'Prodi', u'I-PER', u'B-PER')
# (u'Belfast', u'B-LOC', u'B-MISC')
# (u'Goede', u'B-MISC', u'I-LOC')
# (u'Vrijdag-akkoorden', u'I-MISC', u'B-MISC')
# (u'Europese', u'B-ORG', u'B-MISC')
# (u'Manuel', u'B-PER', u'I-PER')
# (u'Zum\xe1rraga', u'B-LOC', u'I-PER')
# (u'Ibarretxe', u'B-PER', u'B-ORG')
# (u'ld', u'B-PER', u'O')
# (u'ld', u'B-PER', u'O')
# (u'Dewael', u'I-PER', u'B-PER')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Leraars', u'O', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'arena', u'O', u'I-MISC')
# (u'Nederland', u'I-ORG', u'B-LOC')
# (u'TMF', u'B-MISC', u'B-ORG')
# (u'Ahoy', u'B-LOC', u'I-PER')
# (u"TMF's", u'B-MISC', u'B-ORG')
# (u'Castelain', u'I-PER', u'B-PER')
# (u'Soete', u'I-PER', u'B-ORG')
# (u'Zillion', u'B-LOC', u'B-MISC')
# (u'Soete', u'I-PER', u'B-ORG')
# (u'Studio', u'B-MISC', u'B-ORG')
# (u'Brussel-programma', u'I-MISC', u'B-MISC')
# (u'Stereokini', u'B-MISC', u'I-PER')
# (u'Flanders', u'B-LOC', u'B-MISC')
# (u'Expo', u'I-LOC', u'B-ORG')
# (u"K's", u'B-ORG', u'B-MISC')
# (u'Choice', u'I-ORG', u'I-MISC')
# (u'Donna', u'I-ORG', u'B-ORG')
# (u'Ronan', u'B-PER', u'B-MISC')
# (u'Keating', u'I-PER', u'B-LOC')
# (u'C', u'I-PER', u'B-MISC')
# (u'Milk', u'B-ORG', u'I-ORG')
# (u'Inc.', u'I-ORG', u'B-MISC')
# (u'TMF', u'B-MISC', u'B-ORG')
# (u'Awards', u'I-MISC', u'I-PER')
# (u'TMF', u'B-MISC', u'B-ORG')
# (u'Ronan', u'B-PER', u'I-PER')
# (u'Keating', u'I-PER', u'B-LOC')
# (u'Boyzone', u'B-ORG', u'I-PER')
# (u'TMF', u'B-MISC', u'B-ORG')
# (u'TMF', u'B-MISC', u'B-ORG')
# (u'Kimpe', u'I-PER', u'B-PER')
# (u'C', u'I-PER', u'B-MISC')
# (u'Milk', u'B-ORG', u'I-ORG')
# (u'Inc.', u'I-ORG', u'B-MISC')
# (u"K's", u'B-ORG', u'B-MISC')
# (u'Choice', u'I-ORG', u'I-MISC')
# (u'Ronan', u'B-PER', u'I-PER')
# (u'Keating', u'I-PER', u'B-LOC')
# (u'Boyzone', u'B-ORG', u'I-PER')
# (u'TMF', u'B-MISC', u'B-ORG')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'De', u'I-PER', u'O')
# (u'Kimpe', u'I-PER', u'B-PER')
# (u'Aardbei', u'I-PER', u'B-LOC')
# (u'van', u'I-PER', u'O')
# (u'Beervelde', u'I-PER', u'B-PER')
# (u'Appelprinses', u'B-PER', u'B-MISC')
# (u'Nationale', u'B-PER', u'B-ORG')
# (u'Bakkersfee', u'I-PER', u'I-LOC')
# (u'Stereokini', u'B-MISC', u'I-PER')
# (u'Brussel', u'I-ORG', u'B-LOC')
# (u'Goossens', u'B-PER', u'O')
# (u'Goossens', u'B-PER', u'I-PER')
# (u'IPO', u'B-MISC', u'B-ORG')
# (u'Goossens', u'B-PER', u'O')
# (u'2000', u'O', u'I-MISC')
# (u'Goossens', u'B-PER', u'I-PER')
# (u'Putten', u'I-PER', u'B-MISC')
# (u'Mobile', u'I-ORG', u'B-PER')
# (u'Gelukkig', u'O', u'B-MISC')
# (u'Goossens', u'B-PER', u'I-PER')
# (u'regering', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Goossens', u'B-PER', u'I-PER')
# (u'British', u'B-ORG', u'B-PER')
# (u'Telecom', u'I-ORG', u'B-ORG')
# (u'T\xe9l\xe9com', u'I-ORG', u'B-ORG')
# (u'De', u'B-MISC', u'O')
# (u'Morgen', u'I-MISC', u'I-ORG')
# (u'ADSB-consortium', u'B-ORG', u'B-MISC')
# (u'Berkenbos', u'B-LOC', u'B-PER')
# (u'Engin', u'B-PER', u'B-LOC')
# (u'\xd6zdemir', u'I-PER', u'B-LOC')
# (u'Heusden-Zolder', u'B-LOC', u'B-MISC')
# (u'Het', u'B-MISC', u'O')
# (u'Het', u'O', u'B-MISC')
# (u"''", u'O', u'B-LOC')
# (u'Berkenbos', u'B-LOC', u'B-PER')
# (u'Engin', u'B-PER', u'B-LOC')
# (u'\xd6zdemir', u'I-PER', u'B-LOC')
# (u'Berkenbos', u'B-LOC', u'B-PER')
# (u'Heusden', u'B-LOC', u'I-PER')
# (u'Alfons', u'B-PER', u'B-MISC')
# (u'Berkenbos', u'B-LOC', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Berkenbos', u'B-LOC', u'B-PER')
# (u'Berkenbos', u'B-LOC', u'B-PER')
# (u'Onderwijs', u'B-MISC', u'B-ORG')
# (u'in', u'I-MISC', u'O')
# (u'Eigen', u'I-MISC', u'O')
# (u'Taal', u'I-MISC', u'B-LOC')
# (u'en', u'I-MISC', u'O')
# (u'Cultuur', u'I-MISC', u'B-ORG')
# (u'OETC', u'B-MISC', u'B-ORG')
# (u'Vanbilsen', u'B-PER', u'I-PER')
# (u'Sydney', u'B-LOC', u'B-PER')
# (u'De', u'I-PER', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Theaterfestival-selectie', u'B-MISC', u'O')
# (u'Biedermann', u'B-PER', u'I-PER')
# (u'Van', u'B-PER', u'I-PER')
# (u'Toneel', u'B-ORG', u'B-MISC')
# (u'Dora', u'I-ORG', u'B-LOC')
# (u'Van', u'I-ORG', u'I-PER')
# (u'der', u'I-ORG', u'O')
# (u'Groen', u'I-ORG', u'B-PER')
# (u'Tekst', u'O', u'B-LOC')
# (u'Biedermann', u'B-MISC', u'I-PER')
# (u'und', u'I-MISC', u'O')
# (u'die', u'I-MISC', u'O')
# (u'Frisch', u'I-PER', u'I-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Frisch', u'B-PER', u'I-ORG')
# (u'Bal', u'B-MISC', u'B-PER')
# (u'van', u'I-MISC', u'O')
# (u'de', u'I-MISC', u'O')
# (u'pompiers', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Biedermann', u'B-MISC', u'B-PER')
# (u'und', u'I-MISC', u'O')
# (u'die', u'I-MISC', u'O')
# (u'Andorra', u'B-MISC', u'B-LOC')
# (u'Biedermann', u'B-PER', u'I-PER')
# (u'Frisch', u'I-PER', u'I-ORG')
# (u'Wachter', u'I-PER', u'B-LOC')
# (u'Riet', u'I-PER', u'I-MISC')
# (u'Eeghem', u'I-PER', u'B-LOC')
# (u'Biedermann', u'B-MISC', u'I-PER')
# (u'und', u'I-MISC', u'O')
# (u'die', u'I-MISC', u'O')
# (u'Ein', u'O', u'I-MISC')
# (u'Lehrst\xfcck', u'O', u'I-MISC')
# (u'Lehre', u'O', u'I-MISC')
# (u'Brecht', u'B-PER', u'B-LOC')
# (u'Frisch', u'B-PER', u'I-ORG')
# (u'Brecht', u'B-PER', u'B-LOC')
# (u'Zwitser', u'B-MISC', u'B-LOC')
# (u'Frisch', u'B-PER', u'I-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Vlaanderen', u'B-ORG', u'B-LOC')
# (u'2002-Merckx', u'I-ORG', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Nice', u'B-LOC', u'B-PER')
# (u'Beloften', u'O', u'B-MISC')
# (u'Paolini', u'B-PER', u'I-PER')
# (u'Mapei-Quick-Step', u'B-ORG', u'B-MISC')
# (u'Uefacup', u'B-MISC', u'I-ORG')
# (u'Lierse', u'B-ORG', u'B-MISC')
# (u'Hamilton', u'B-PER', u'B-LOC')
# (u'Armstrong', u'B-PER', u'I-PER')
# ...
# (u'Carabosse', u'B-ORG', u'B-PER')
# (u'Carabosse', u'B-ORG', u'B-PER')
# (u'Konijnenwei', u'B-LOC', u'I-LOC')
# (u'Singel', u'B-LOC', u'B-PER')
# (u'Zuid', u'I-LOC', u'I-MISC')
# (u'Konijnenwei', u'B-LOC', u'I-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Hasseltse', u'B-MISC', u'B-LOC')
# (u'Kabinet', u'O', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Definitieve', u'O', u'B-MISC')
# (u'Grote', u'O', u'B-MISC')
# (u'Michielssens', u'B-PER', u'I-PER')
# (u'PC', u'B-MISC', u'B-ORG')
# (u'/', u'I-MISC', u'O')
# (u'KD', u'I-MISC', u'B-PER')
# (u'Nu', u'O', u'B-PER')
# (u'ICT', u'O', u'B-ORG')
# (u'Michielssens', u'B-PER', u'I-PER')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'PMS-centra', u'B-MISC', u'B-LOC')
# (u'Statistiek', u'B-ORG', u'O')
# (u'secretariaat', u'I-ORG', u'O')
# (u'van', u'I-ORG', u'O')
# (u'het', u'I-ORG', u'O')
# (u'katholiek', u'I-ORG', u'O')
# (u'onderwijs', u'I-ORG', u'O')
# (u'VSKO', u'B-ORG', u'B-LOC')
# (u'Freinetscholen', u'B-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Freinetschool', u'B-MISC', u'O')
# (u'De', u'B-LOC', u'I-PER')
# (u'Sleutel', u'I-LOC', u'B-ORG')
# (u'Freinetonderwijs', u'B-MISC', u'O')
# (u'Freinetonderwijs', u'B-MISC', u'O')
# (u'Lemeire', u'B-PER', u'I-PER')
# (u'Freinetscholen', u'B-MISC', u'O')
# (u'Freinetscholen', u'B-MISC', u'O')
# (u'Freinetonderwijs', u'B-MISC', u'O')
# (u'Freinetscholen', u'B-MISC', u'O')
# (u'Stainthorp', u'B-PER', u'B-LOC')
# (u'Partners', u'B-ORG', u'B-MISC')
# (u'the', u'I-ORG', u'I-MISC')
# (u'Stationer', u'I-ORG', u'I-PER')
# (u'Stainthorp', u'B-PER', u'O')
# (u'Terug', u'O', u'B-LOC')
# (u'Rhona', u'B-PER', u'B-LOC')
# (u'Stainthorp', u'I-PER', u'B-LOC')
# (u'London', u'B-ORG', u'B-LOC')
# (u"University's", u'I-ORG', u'B-MISC')
# (u'Institute', u'I-ORG', u'B-ORG')
# (u'of', u'I-ORG', u'O')
# (u'Education', u'I-ORG', u'B-MISC')
# (u'Stainthorp', u'B-PER', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Stainthorp', u'B-PER', u'B-LOC')
# (u'Balpennen', u'O', u'B-MISC')
# (u'Stainthorp', u'B-PER', u'B-LOC')
# (u'Handwriting', u'B-ORG', u'I-ORG')
# (u'Interest', u'I-ORG', u'B-ORG')
# (u'Stompe', u'O', u'I-PER')
# (u'Taalkracht', u'B-MISC', u'O')
# (u'Tien', u'I-MISC', u'O')
# (u'Repetitio', u'O', u'B-PER')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Goebbels', u'B-PER', u'I-PER')
# (u'Hitlers', u'B-MISC', u'O')
# (u'Leerlingen', u'O', u'I-MISC')
# (u'Vlaamse', u'B-ORG', u'B-MISC')
# (u'Beweging', u'I-ORG', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Verbeeck', u'B-PER', u'I-PER')
# (u'Taalkracht', u'B-MISC', u'B-LOC')
# (u'Tien', u'I-MISC', u'O')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Blok-propaganda', u'I-MISC', u'B-MISC')
# (u'Verbeeck', u'B-PER', u'I-PER')
# (u'Atheneum', u'B-ORG', u'B-LOC')
# (u'Mortsel', u'I-ORG', u'I-PER')
# (u'Taalkracht', u'B-MISC', u'B-LOC')
# (u'Tien', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'I-PER')
# (u'Sikkel', u'I-ORG', u'B-PER')
# (u'Lesboek', u'O', u'B-MISC')
# (u'Verbeeck', u'B-PER', u'I-PER')
# (u'Ga', u'O', u'B-PER')
# (u'Taalkracht', u'B-MISC', u'O')
# (u'Tien', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'I-PER')
# (u'Sikkel', u'I-ORG', u'B-PER')
# (u'Malle', u'B-LOC', u'I-PER')
# (u'Verbeeck', u'B-PER', u'I-PER')
# (u'FIRST', u'B-MISC', u'B-ORG')
# (u'BLOOD', u'I-MISC', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Stallone', u'B-PER', u'B-ORG')
# (u'Stallones', u'B-MISC', u'I-MISC')
# (u'Ted', u'B-PER', u'B-LOC')
# (u'Kotcheff', u'I-PER', u'B-PER')
# (u'Stallone', u'I-PER', u'B-ORG')
# (u'Dennehy', u'I-PER', u'B-LOC')
# (u'Katrin', u'B-PER', u'I-PER')
# (u'Cartlidge', u'I-PER', u'I-MISC')
# (u'Benton', u'I-PER', u'B-PER')
# (u'Serkis', u'I-PER', u'B-PER')
# (u'La', u'B-ORG', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'CAREER', u'B-MISC', u'O')
# (u'GIRLS', u'I-MISC', u'O')
# (u'Cartlidge', u'I-PER', u'I-MISC')
# (u'Naked', u'B-MISC', u'B-LOC')
# (u'Hannah', u'B-PER', u'B-LOC')
# (u'Roy', u'B-PER', u'I-PER')
# (u'Scheider', u'I-PER', u'O')
# (u'Garry', u'I-PER', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'PRIJKT', u'O', u'B-ORG')
# (u'IN', u'O', u'I-MISC')
# (u'LIJSTJE', u'O', u'B-MISC')
# (u'KLASSIEKERS', u'O', u'B-MISC')
# (u'EN', u'O', u'B-MISC')
# (u'WERD', u'O', u'B-ORG')
# (u'OOK', u'O', u'B-ORG')
# (u'BEKROOND', u'O', u'B-PER')
# (u'DRIE', u'O', u'B-ORG')
# (u'BESTE', u'O', u'B-PER')
# (u'MUZIEK', u'O', u'B-MISC')
# (u'BESTE', u'O', u'B-PER')
# (u'EN', u'O', u'B-MISC')
# (u'BESTE', u'O', u'B-PER')
# (u'GELUID', u'O', u'I-ORG')
# (u'JAWS', u'B-MISC', u'B-PER')
# (u'Spielberg', u'B-PER', u'B-LOC')
# (u'Spielberg', u'B-PER', u'B-LOC')
# (u'Steven', u'B-PER', u'I-PER')
# (u'Spielberg', u'I-PER', u'B-LOC')
# (u'de', u'I-PER', u'O')
# (u'Schampelaere', u'I-PER', u'O')
# (u'Leve', u'O', u'I-MISC')
# (u'Sand', u'I-PER', u'B-LOC')
# (u'Pluym', u'B-PER', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Gevaert', u'I-PER', u'I-ORG')
# (u'Brigitte', u'B-PER', u'I-PER')
# (u'Becue', u'I-PER', u'I-MISC')
# (u'Ingeborg', u'B-PER', u'O')
# (u'Marx', u'I-PER', u'B-PER')
# (u'Moeder', u'B-PER', u'O')
# (u'Gods', u'I-PER', u'B-MISC')
# (u'Supporter', u'O', u'B-PER')
# (u'van', u'I-PER', u'O')
# (u'madame', u'B-PER', u'O')
# (u'de', u'I-PER', u'O')
# (u'Pompadour', u'I-PER', u'B-LOC')
# (u'Bront\xeb', u'B-ORG', u'B-LOC')
# (u'Sisters', u'I-ORG', u'I-PER')
# (u'West', u'B-LOC', u'I-PER')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Lanting', u'I-PER', u'I-ORG')
# (u'CV70', u'B-ORG', u'B-PER')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Sports', u'B-ORG', u'I-MISC')
# (u'Locker', u'I-ORG', u'I-PER')
# (u'Room', u'I-ORG', u'B-LOC')
# (u'Lanting', u'I-PER', u'I-ORG')
# (u'Guerra', u'B-PER', u'I-PER')
# (u'Guerra', u'B-PER', u'I-PER')
# (u'Los', u'B-LOC', u'O')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'SMOKEY', u'B-PER', u'B-MISC')
# (u'CHICO', u'I-PER', u'B-ORG')
# (u'Watts', u'B-PER', u'I-PER')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Loyola', u'B-ORG', u'B-PER')
# (u'Marymount', u'I-ORG', u'B-PER')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Nu', u'O', u'B-PER')
# (u'Chico', u'B-PER', u'B-LOC')
# (u'Burnett', u'I-PER', u'B-PER')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Creative', u'B-ORG', u'I-PER')
# (u'Hair', u'I-ORG', u'B-PER')
# (u'&', u'I-ORG', u'O')
# (u'Nails', u'I-ORG', u'O')
# (u'Design-zaak', u'I-ORG', u'B-MISC')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Boulevard', u'I-LOC', u'B-LOC')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Guerra', u'B-PER', u'I-PER')
# (u'Zwarte', u'O', u'I-MISC')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Ortega', u'I-PER', u'B-PER')
# (u'Compton', u'B-LOC', u'B-ORG')
# (u'Boulevard', u'I-LOC', u'B-LOC')
# (u'Spanningen', u'O', u'B-MISC')
# (u'Mexicanen', u'B-MISC', u'I-MISC')
# (u'Chico', u'B-PER', u'B-LOC')
# (u'Martinez', u'I-PER', u'B-PER')
# (u'Chico', u'B-PER', u'B-LOC')
# (u'Lexus', u'B-MISC', u'B-LOC')
# (u'Tighe', u'I-PER', u'B-ORG')
# (u'Jeffs', u'B-MISC', u'I-PER')
# (u'Mississippi', u'B-LOC', u'B-PER')
# (u'New', u'B-MISC', u'B-LOC')
# (u'Fez-club', u'B-LOC', u'B-MISC')
# (u'Mary', u'B-PER', u'B-MISC')
# (u'Guibert', u'I-PER', u'B-PER')
# (u'Merri', u'B-PER', u'B-ORG')
# (u'Cyr', u'I-PER', u'B-LOC')
# (u'Sketches', u'B-MISC', u'I-MISC')
# (u'for', u'I-MISC', u'I-ORG')
# (u'My', u'I-MISC', u'B-MISC')
# (u'Sweetheart', u'I-MISC', u'I-PER')
# (u'White', u'I-MISC', u'B-MISC')
# (u'Boy', u'I-MISC', u'I-PER')
# (u'Live', u'B-MISC', u'I-MISC')
# (u'in', u'I-MISC', u'O')
# (u'Chicago', u'I-MISC', u'B-LOC')
# (u'verdronken', u'O', u'I-LOC')
# (u'Kamil', u'I-PER', u'B-LOC')
# (u'Zita', u'B-ORG', u'B-PER')
# (u'Swoon', u'I-ORG', u'I-PER')
# (u'Radiohead', u'B-ORG', u'B-MISC')
# (u'Oasis', u'B-ORG', u'I-PER')
# (u'Black', u'B-ORG', u'B-PER')
# (u'Grape', u'I-ORG', u'B-PER')
# (u'Muse', u'B-ORG', u'I-LOC')
# (u'Coldplay', u'B-ORG', u'B-PER')
# (u'Geneva', u'B-ORG', u'B-LOC')
# (u'of', u'I-ORG', u'O')
# (u'The', u'I-ORG', u'B-ORG')
# (u'Prayer', u'I-ORG', u'I-PER')
# (u'Boat', u'I-ORG', u'B-PER')
# (u'Tims', u'B-MISC', u'I-PER')
# (u'Jasmina', u'B-MISC', u'B-PER')
# (u'Fekovics', u'I-MISC', u'I-ORG')
# (u'Fekovic', u'I-PER', u'B-PER')
# (u'Buckley', u'B-PER', u'I-PER')
# (u'Memphis', u'B-LOC', u'B-MISC')
# (u'Buckley', u'B-PER', u'I-PER')
# (u'jr.', u'I-PER', u'O')
# (u'Goodbye', u'B-MISC', u'O')
# (u'Hello', u'I-MISC', u'B-PER')
# (u'filmdagen', u'I-MISC', u'O')
# (u'Goodbye', u'B-MISC', u'O')
# (u'Hello', u'I-MISC', u'B-PER')
# (u'Jeffs', u'B-MISC', u'I-PER')
# (u'Goodbye', u'B-MISC', u'I-PER')
# (u'Hello', u'I-MISC', u'B-PER')
# (u'Jasmina', u'B-PER', u'I-PER')
# (u'Fekovic', u'I-PER', u'B-PER')
# (u'Nighttown', u'B-LOC', u'I-PER')
# (u'Jeff', u'B-MISC', u'B-PER')
# (u'Buckley-herdenkingsdag', u'I-MISC', u'B-MISC')
# (u'Jasmina', u'B-PER', u'I-PER')
# (u'Fekovic', u'I-PER', u'B-PER')
# (u'Man', u'O', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Dewael', u'I-PER', u'B-PER')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Vanderpoorten', u'I-PER', u'B-PER')
# (u'den', u'I-PER', u'O')
# (u'Bossche', u'I-PER', u'B-MISC')
# (u'Vandenbroucke', u'I-PER', u'B-PER')
# (u'Vanderpoorten', u'I-PER', u'B-PER')
# (u'Deurne', u'B-LOC', u'I-PER')
# (u'Klopt', u'O', u'B-LOC')
# (u'Syndicale', u'I-MISC', u'B-ORG')
# (u'Cultuur', u'I-MISC', u'B-ORG')
# (u'Vlaams', u'B-MISC', u'B-ORG')
# (u'Boone', u'I-PER', u'B-PER')
# (u'ASO', u'B-MISC', u'B-ORG')
# (u'Vanderpoorten', u'I-PER', u'B-PER')
# (u'PMS', u'B-MISC', u'B-PER')
# (u"PMS'en", u'B-MISC', u'B-PER')
# (u"MST's", u'B-MISC', u'B-PER')
# (u'PMS-centra', u'B-MISC', u'B-LOC')
# (u"MST's", u'B-MISC', u'B-PER')
# (u'PMS-centra', u'B-MISC', u'B-LOC')
# (u"CLB's", u'B-MISC', u'B-ORG')
# (u'PMS-centra', u'B-MISC', u'B-LOC')
# (u"MST's", u'B-MISC', u'B-PER')
# (u"PMS'en", u'B-MISC', u'B-PER')
# (u'Vernieuwde', u'O', u'B-PER')
# (u'PMS', u'B-MISC', u'B-PER')
# (u"CLB's", u'B-MISC', u'B-ORG')
# (u'Catoire', u'I-PER', u'B-PER')
# (u'CLB', u'B-MISC', u'B-PER')
# (u'Cattoir', u'B-PER', u'B-LOC')
# (u'PMS-centra', u'B-MISC', u'B-LOC')
# (u"PMS'en", u'B-MISC', u'B-PER')
# (u"PMS'en", u'B-MISC', u'B-PER')
# (u"PMS'en", u'B-MISC', u'B-PER')
# (u'PMS', u'B-MISC', u'B-PER')
# (u"PMS'en", u'B-MISC', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'PMS', u'B-MISC', u'B-PER')
# (u'PMS-centra', u'B-MISC', u'B-LOC')
# (u'Schoolfobie', u'O', u'B-PER')
# (u'Stellamans', u'B-PER', u'I-PER')
# (u'Schoolfobie', u'O', u'B-PER')
# (u'Stellamans', u'B-PER', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Ouders', u'O', u'I-ORG')
# (u'Schoolfobie', u'O', u'B-PER')
# (u'Stellamans', u'B-PER', u'I-PER')
# (u'CGGZ-team', u'B-ORG', u'B-PER')
# (u'Ericsson', u'B-ORG', u'I-PER')
# (u'De', u'B-ORG', u'O')
# (u'Medisch', u'B-ORG', u'I-ORG')
# (u'Opvoedkundig', u'I-ORG', u'O')
# (u'Bureau', u'I-ORG', u'I-MISC')
# (u"Gsm's", u'O', u'B-MISC')
# (u'Flauwekul', u'O', u'B-PER')
# (u'Orfee', u'B-PER', u'B-MISC')
# (u'Callebert', u'I-PER', u'B-PER')
# (u'Geestelijke', u'I-ORG', u'B-ORG')
# (u'Gezondheidszorg', u'I-ORG', u'B-LOC')
# (u'CGGZ', u'B-ORG', u'B-PER')
# (u'voor', u'I-ORG', u'O')
# (u'begeleiding', u'I-ORG', u'O')
# (u'van', u'I-ORG', u'O')
# (u'seropositieve', u'I-ORG', u'O')
# (u'kinderen', u'I-ORG', u'O')
# (u',', u'I-ORG', u'O')
# (u'hun', u'I-ORG', u'O')
# (u'familie', u'I-ORG', u'O')
# (u'en', u'I-ORG', u'O')
# (u'de', u'I-ORG', u'O')
# (u'omgeving', u'I-ORG', u'O')
# (u'Paola', u'I-LOC', u'B-PER')
# (u'Kinderziekenhuis', u'I-LOC', u'I-PER')
# (u'GOS', u'B-LOC', u'B-PER')
# (u'Storm', u'I-MISC', u'B-LOC')
# (u'De', u'B-ORG', u'O')
# (u'Cambodja', u'B-LOC', u'B-PER')
# (u'Birma', u'B-LOC', u'B-MISC')
# (u'Epidemie', u'O', u'B-ORG')
# (u'Cambodja', u'B-LOC', u'B-PER')
# (u'HIV', u'B-MISC', u'O')
# (u'HIV-virus', u'B-MISC', u'B-LOC')
# (u'Storm', u'I-MISC', u'B-LOC')
# (u'sub-Saharisch', u'B-MISC', u'O')
# (u'Botswana', u'B-LOC', u'I-PER')
# (u'Peter', u'I-PER', u'B-PER')
# (u'Cara\xefben', u'B-LOC', u'I-MISC')
# (u'Botswana', u'B-LOC', u'I-PER')
# (u'de', u'O', u'I-PER')
# (u'Yamaha', u'B-ORG', u'B-PER')
# (u'500', u'I-MISC', u'O')
# (u'Tmax', u'I-MISC', u'B-PER')
# (u'Tmax', u'B-MISC', u'B-PER')
# (u'500', u'I-MISC', u'O')
# (u'YP', u'B-MISC', u'B-ORG')
# (u'250', u'I-MISC', u'O')
# (u'Majesty', u'I-MISC', u'B-PER')
# (u'Suzuki', u'B-ORG', u'B-PER')
# (u'LW', u'B-PER', u'B-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Yamaha', u'B-MISC', u'O')
# (u'Tmax', u'I-MISC', u'B-PER')
# (u'Tel', u'O', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'LW', u'B-PER', u'B-MISC')
# (u'Ifma', u'B-MISC', u'I-PER')
# (u'Intermot', u'B-MISC', u'B-ORG')
# (u'Intermot', u'B-MISC', u'B-ORG')
# (u'Intermot', u'B-MISC', u'B-ORG')
# (u'Adres', u'O', u'B-PER')
# (u'Messe', u'B-LOC', u'I-PER')
# (u'M\xfcnchen', u'I-LOC', u'B-LOC')
# (u'Messegel\xe4nde', u'B-LOC', u'I-PER')
# (u'Bulgari', u'B-ORG', u'I-PER')
# (u'Detroit', u'B-LOC', u'I-PER')
# (u'Cadillac', u'B-ORG', u'B-PER')
# (u'Kentucky', u'B-LOC', u'B-PER')
# (u'Allant\xe9', u'B-MISC', u'B-ORG')
# (u'Seville', u'B-MISC', u'I-MISC')
# (u'Jaguar', u'B-ORG', u'B-LOC')
# (u'Cadillac', u'B-ORG', u'B-PER')
# (u'Cadillac', u'B-ORG', u'B-PER')
# (u'Cadillac', u'B-ORG', u'B-PER')
# (u'Car', u'B-ORG', u'I-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Mercedes', u'B-MISC', u'B-ORG')
# (u'SL', u'I-MISC', u'B-ORG')
# (u'3-liter-V6', u'B-MISC', u'O')
# (u'Ford', u'B-MISC', u'I-PER')
# (u'Taurus', u'I-MISC', u'B-LOC')
# (u'Hessing', u'B-ORG', u'O')
# (u'De', u'B-ORG', u'O')
# (u'semi-cabrio', u'O', u'B-MISC')
# (u'Elise', u'I-MISC', u'B-PER')
# (u'Opel', u'B-ORG', u'O')
# (u'Opel', u'B-MISC', u'O')
# (u'Speedster', u'I-MISC', u'B-LOC')
# (u'Opel-ontwerp', u'B-MISC', u'I-MISC')
# (u'Speedster', u'I-MISC', u'B-LOC')
# (u'Speedster', u'B-MISC', u'B-LOC')
# (u'Speedster', u'B-MISC', u'B-LOC')
# (u'Toyota', u'B-MISC', u'B-ORG')
# (u'MR', u'I-MISC', u'B-PER')
# (u'Astra', u'B-MISC', u'B-LOC')
# (u'Coup\xe9', u'I-MISC', u'B-PER')
# (u'De', u'B-ORG', u'O')
# (u'Hethel', u'B-LOC', u'B-MISC')
# (u'Opel', u'B-ORG', u'O')
# (u'Lotus', u'B-ORG', u'B-MISC')
# (u'2,2-liter-CDI-diesel', u'B-MISC', u'I-MISC')
# (u'flashy', u'O', u'I-MISC')
# (u'BMW', u'B-MISC', u'B-ORG')
# (u'3-serie', u'I-MISC', u'O')
# (u'SLK', u'B-MISC', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Groter', u'O', u'B-LOC')
# (u'de', u'O', u'I-PER')
# (u'Lemay', u'B-LOC', u'B-PER')
# (u'Doornik', u'B-LOC', u'O')
# (u'Soms', u'O', u'I-MISC')
# (u'Stichting', u'B-ORG', u'O')
# (u'Grard', u'I-ORG', u'B-PER')
# (u'Parmentier', u'B-PER', u'I-PER')
# (u'Parmentier', u'B-PER', u'O')
# (u'Stichting', u'B-ORG', u'O')
# (u'George', u'I-ORG', u'B-PER')
# (u'Grard', u'I-ORG', u'B-PER')
# (u'Gijverinkhove', u'B-LOC', u'O')
# (u'Gijverinkhove', u'B-LOC', u'I-PER')
# (u'Grard', u'I-PER', u'B-PER')
# (u'Soignies', u'B-LOC', u'I-ORG')
# (u'Balegemse', u'B-LOC', u'B-MISC')
# (u'steengroeve', u'I-LOC', u'O')
# (u'EB', u'B-PER', u'B-ORG')
# (u'De', u'B-ORG', u'O')
# (u'Stichting', u'B-ORG', u'O')
# (u'George', u'I-ORG', u'B-PER')
# (u'Grard', u'I-ORG', u'I-PER')
# (u'Stichting', u'B-ORG', u'O')
# (u'George', u'I-ORG', u'B-PER')
# (u'Grard', u'I-ORG', u'B-PER')
# (u'EB', u'B-PER', u'B-ORG')
# (u'Audresselles', u'B-LOC', u'B-MISC')
# (u'Stichting', u'B-ORG', u'O')
# (u'Grard', u'I-ORG', u'B-PER')
# (u'Parmentier', u'B-PER', u'I-PER')
# (u'Ontmoeting', u'B-MISC', u'O')
# (u'George', u'I-MISC', u'B-PER')
# (u'Grard-Johan', u'I-MISC', u'B-MISC')
# (u'Parmentier', u'I-MISC', u'O')
# (u'2000', u'O', u'I-MISC')
# (u'Stichting', u'B-ORG', u'O')
# (u'George', u'I-ORG', u'B-PER')
# (u'Grard', u'I-ORG', u'B-PER')
# (u'Gijverinkhove', u'B-LOC', u'B-MISC')
# (u'Parmentier', u'B-PER', u'I-PER')
# (u'Kawasaki', u'B-MISC', u'I-PER')
# (u'ZX', u'I-MISC', u'O')
# (u'9R', u'I-MISC', u'O')
# (u'Kawa', u'B-MISC', u'B-PER')
# (u'ABS-systeem', u'B-MISC', u'B-LOC')
# (u'9', u'I-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'Kawasaki', u'B-ORG', u'I-PER')
# (u'Achteraan', u'O', u'B-MISC')
# (u'Ninja', u'B-MISC', u'B-PER')
# (u'ZX', u'I-MISC', u'O')
# (u'9R', u'I-MISC', u'O')
# (u'Kawasaki', u'B-ORG', u'I-PER')
# (u'Kawasaki', u'B-ORG', u'I-PER')
# (u'Kawa', u'B-MISC', u'B-PER')
# (u'2000', u'O', u'I-MISC')
# (u'De', u'B-ORG', u'O')
# (u'Peugeot', u'B-ORG', u'I-PER')
# (u'Citro\xebn', u'B-ORG', u'I-LOC')
# (u'HDI', u'B-MISC', u'B-ORG')
# (u'dCi', u'B-MISC', u'O')
# (u'1,9-liter-dCi', u'B-MISC', u'O')
# (u'dCi', u'B-MISC', u'O')
# (u'Sc\xe9nic', u'B-MISC', u'B-PER')
# (u'RX4', u'B-MISC', u'B-ORG')
# (u'VW', u'B-ORG', u'B-MISC')
# (u"JTD's", u'B-MISC', u'B-ORG')
# (u'RX4', u'B-MISC', u'B-ORG')
# (u'Sc\xe9nic', u'B-MISC', u'B-PER')
# (u'Sc\xe9nic', u'B-MISC', u'B-PER')
# (u'RX4', u'I-MISC', u'B-ORG')
# (u'dCi', u'B-MISC', u'O')
# (u'Sc\xe9nic', u'B-MISC', u'B-PER')
# (u'dCi', u'B-MISC', u'O')
# (u'Peugeot', u'B-ORG', u'I-PER')
# (u'Passat', u'B-MISC', u'O')
# (u'De', u'B-ORG', u'O')
# (u'VW', u'B-ORG', u'B-MISC')
# (u'Volkswagen', u'B-MISC', u'O')
# (u'Passat', u'I-MISC', u'O')
# (u'Passat', u'B-MISC', u'O')
# (u'Volkswagen', u'B-ORG', u'O')
# (u'Citro\xebn', u'B-MISC', u'I-LOC')
# (u'Renault', u'B-MISC', u'B-ORG')
# (u'Laguna', u'I-MISC', u'B-MISC')
# (u'Ford', u'B-MISC', u'I-PER')
# (u'Mondeo', u'I-MISC', u'B-PER')

# %% [raw]
# Confusion Matrix:

# %%
from nltk import confusionmatrix

print classes
print(confusionmatrix.ConfusionMatrix(real_tag_of_test, test_res))
# Out:
# {u'I-LOC': 7, u'B-ORG': 2, u'I-PER': 4, u'O': 1, u'I-MISC': 8, u'B-MISC': 5, u'I-ORG': 6, u'B-LOC': 0, u'B-PER': 3}
#   |     0     1     2     3     4     5     6     7     8 |
# --+-------------------------------------------------------+
# 0 |  <553>   24    25    76    50    28     1    12     5 |
# 1 |    13<62943>   15    43    18    35     8     2    40 |
# 2 |    53   173  <396>   63    40    88    20    16    33 |
# 3 |    60    43    41  <745>  164    19     3     8    15 |
# 4 |    64    44    26   207  <418>   23     8     4    13 |
# 5 |    57   122    98    62    52  <743>   11     9    33 |
# 6 |    69   125    37    42    27    29  <200>    4    18 |
# 7 |     7     3     4     4     2     3     1   <23>    2 |
# 8 |    45   133    21    29    26    33    26     4   <93>|
# --+-------------------------------------------------------+
# (row = reference; col = test)

# %% [markdown]
# # Error Analysis

# %%
import json
from collections import defaultdict

d = open("error_analysis.txt", 'rb').readlines()
k = [eval(x) for x in d]
print classes

d = {}
for c in classes.keys():
    m = [x for x in k if x[1] == c]
    d[c] = m

print 'Creating Files with error analysis for each label (look in current folder)'    

for k,v in d.iteritems():
    f = open(k + '.txt', 'wb')
    for x in v:
            f.write(json.dumps(x))
            f.write('\r\n')
    f.close()

print
print 'calculating number of "silly mistakes" (I-Label instead if B-Label etc..)'
count = defaultdict(lambda: 1)
for k, v in d.iteritems():
    if k == 'O':
        continue
    for i in v:
        if i[1][2:] == i[2][2:]:
            count[k] += 1
print count

for k in d.keys():
#     print 'X', len(d[k]), count[k]
    print k, float(count[k])/len(d[k])
# Out:
# {u'I-LOC': 7, u'B-ORG': 2, u'I-PER': 4, u'O': 1, u'I-MISC': 8, u'B-MISC': 5, u'I-ORG': 6, u'B-LOC': 0, u'B-PER': 3}
# Creating Files with error analysis for each label (look in current folder)
# calculating number of "silly mistakes" (I-Label instead if B-Label etc..)
# defaultdict(<function <lambda> at 0x00000000208F04A8>, {u'I-LOC': 8, u'B-ORG': 21, u'I-PER': 208, u'B-PER': 165, u'I-MISC': 34, u'B-MISC': 34, u'I-ORG': 38, u'B-LOC': 13})
# I-LOC 0.307692307692
# B-ORG 0.0432098765432
# O 0.00574712643678
# I-PER 0.53470437018
# I-MISC 0.107255520505
# B-MISC 0.0765765765766
# I-ORG 0.108262108262
# B-LOC 0.0588235294118
# B-PER 0.467422096317

# %% [markdown]
# #### As we can see, 50% of the error in the 'PER' Label are just confusion between 'I-' and 'B-'.
# It's also high in 'LOC' label

# %% [raw]
# Thoughts:
#
# 1) There are many 'Errors' which aren't really errors, for example we predict B-LOC, instead of I-LOC.
#    Maybe we should add the previous tag to the feature extraction and it will help with the I and B confusion.
#
# 2) It's probably better to use dictionaries for locations, there are many lists of known cities/countries and it's finite.

# %% [markdown]
# # Optimizing SVM parameters

# %% [markdown]
# ### Optimizing 'C' parameter

# %% [markdown]
# <img src="pictures/svm_c.png" />

# %%
# conll2002.iob_sents()
from nltk.classify import SklearnClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC

classes = get_classes(['esp.train', 'esp.testa', 'esp.testb'])
print "classes :", classes

train_data = conll2002.iob_sents('ned.train')
numed_features = feature_creator(train_data)
train_data = prepear_train(train_data, numed_features, classes)
print len(train_data)
train_data = train_data[0:30000]

# from sklearn.feature_extraction import DictVectorizer
# v = DictVectorizer(sparse=True)
# list_of_features = []
# for item in train_data:
#     import pdb
#     pdb.set_trace()
#     list_of_features.append(item[0])
# X = v.fit_transform(list_of_features)
# print X
c_range = range(-2, 20)
for c in c_range:
    print "C is ", c
    classif = SklearnClassifier(SVC(C=2**c, verbose=False)).train(train_data)
    test_data = conll2002.iob_sents('ned.testa')
    test_data = test_data
    # print test_data
    tag_of_test = []
    test = []
    words = []
    not_o_tags = []
    for sent in test_data:
        for tagged_word in sent:
            tag_of_test.append(classes[tagged_word[2]])
            words.append(tagged_word[0])
            if tagged_word[2] != 'O':
                not_o_tags.append(tagged_word[2])
            test.append(feature_extraction(tagged_word, numed_features, sent))
    # print test

    res = classif.classify_many(test)
    # print len(res)
    # print res
    # print tag_of_test
    error_count = 0
    for item in zip(tag_of_test, res, words):
        if (item[0] != item[1]):
            #print item
            # import pdb
            # pdb.set_trace()
            error_count += 1
    print " erro count: ", error_count
    print "amount of not Os is: ", len(not_o_tags)
    #print not_o_tags
# Out:
# classes : {u'I-LOC': 7, u'B-ORG': 2, u'I-PER': 4, u'O': 1, u'I-MISC': 8, u'B-MISC': 5, u'I-ORG': 6, u'B-LOC': 0, u'B-PER': 3}
# Length Of Features:
#  34417
# 202644
# C is
#  -2
#  erro count:
#  3714
# amount of not Os is:  3714
# C is  -1
#  erro count:
#  3714
# amount of not Os is:  3714
# C is  0
#  erro count:
#  3714
# amount of not Os is:  3714
# C is  1
#  erro count:
#  3714
# amount of not Os is:  3714
# C is  2
#  erro count:
#  3714
# amount of not Os is:  3714
# C is  3
#  erro count:
#  3636
# amount of not Os is:  3714
# C is  4
#  erro count:
#  2982
# amount of not Os is:  3714
# C is  5
#  erro count:
#  2899
# amount of not Os is:  3714
# C is  6
#  erro count:
#  2633
# amount of not Os is:  3714
# C is  7
#  erro count:
#  2405
# amount of not Os is:  3714
# C is  8
#  erro count:
#  2288
# amount of not Os is:  3714
# C is  9
#  erro count:
#  2175
# amount of not Os is:  3714
# C is  10
#  erro count:
#  2136
# amount of not Os is:  3714
# C is  11
#  erro count:
#  2133
# amount of not Os is:  3714
# C is  12
#  erro count:
#  2165
# amount of not Os is:  3714
# C is  13
#  erro count:
#  2203
# amount of not Os is:  3714
# C is  14
#  erro count:
#  2219
# amount of not Os is:  3714
# C is  15
#  erro count:
#  2244
# amount of not Os is:  3714
# C is  16
#  erro count:
#  2272
# amount of not Os is:  3714
# C is  17
#  erro count:
#  2274
# amount of not Os is:  3714
# C is  18
#  erro count:
#  2276
# amount of not Os is:  3714
# C is  19
#  erro count:
#  2276
# amount of not Os is:  3714

# %% [markdown]
# #### Best C in 2^11
